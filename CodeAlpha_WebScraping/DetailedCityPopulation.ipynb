# %% [markdown]
# # Task 1 : WEB SCRAPING

# %% [markdown]
# ### Importing packages

# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %% [markdown]
# ### Scraping the webpage data

# %%
url = "https://www.citypopulation.de/en/nepal/mun/admin/"

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head itemscope="" itemtype="https://schema.org/WebPage">
# <meta charset="utf-8"/>
# <meta content="Nepal: Municipal Division (Districts and Local Units) with population statistics, charts and maps." itemprop="description" name="description"/>
# <title itemprop="name">Nepal: Municipal Division (Districts and Local Units) - Population Statistics, Charts and Map</title>
# <meta content="Thomas Brinkhoff: City Population, http://www.citypopulation.de" itemprop="author" name="author"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="http://creativecommons.org/licenses/by/4.0/" itemprop="license" rel="licence"/>
# <script>var pagemode = 'adminpage'; var pagecat = 'admin'; var isAdmin = true; var pageid = 'nepal-mun-admin'; var pagelang = 'en'; var pagelabel = "Municipal Division"; var popDate = 'C 2021-11-25'; var popcolnum  = 3; var start_x = 84.132; var start_y = 28.398; var start_level = 7; var swap_width = 1560; var hor_percent = 45; var vert_percent = 37; var swap = 'true'; var mapcopyright = 'National Geographic Information Infrastructure Division, Nepal.'; var objid = ''; var objtype = ''; var startmap = 'street'; var lev_num = 2; var edit_mode = ''; var placeLocale = 'ne'; var nativeName = true; var wikiFromWD = false</script>
# <script src="/js/countries/nepal.js"></script>
# <script src="/jquery/jquery-3.7.1.min.js"></script>
# <script src="/js/cp_data_m.js"></script>
# <script src="/js/cp_phpbase_v3.js"></script>
# <script>load_resources()</script>
# <script src="/js/cp_menu.js"></script>
# <style>
# article#admtable { top: 37%; }
# div#admmap { height: 37%; }
# @media all and (min-width: 1560px) {
# 	article#admtable { top: 26px; left: calc(180px + 45%); }
# 	div#admmap { height: auto; bottom: -1px; width: 45% }
# 	header.admpage { left: calc(180px + 45%) }
# 	div#headline { left: calc(162px + 45%) }
# }
# </style>
# </head>
# <body itemscope="" itemtype="http://schema.org/Country" onload="init_data(); start_maps()">
# <script>writeMenu('en','adminpage','nepal-mun-admin','')</script>
# <div class="mobiadv">
# <script>show_mobiadv();</script>
# </div>
# <div class="hor" id="headline">
# <div id="orient">
# <a href="/">Home</a> → <span itemprop="containedIn" itemscope="" itemtype="http://schema.org/Continent"><a href="/en/asia/" itemprop="url"><span itemprop="name">Asia</span></a></span> → <span itemprop="containedIn" itemscope="" itemtype="http://schema.org/Country"><a href="/en/nepal/" itemprop="url"><span itemprop="name">Nepal</span></a></span>
# </div>
# <div id="social">
# <div class="changelang"><a href="javascript:cp.changePageLang('en','de')"><img alt="" src="/images/icons/de.svg" title="Deutsch"/></a></div>
# </div>
# </div>
# <div class="info" id="inforowdiv" style="display:none"></div>
# <article class="cpage swapped" id="admtable">
# <header class="admpage">
# <a href="javascript:openMap()"><img alt="Show Map" id="smap" src="/images/smaps/nepal-cities.png" title="Show Map"/></a>
# <h1><a href="/en/nepal/"><span itemprop="name">Nepal</span></a>: <span class="smalltext">Municipal Division</span></h1>
# </header>
# <script>handleArticleResize()</script>
# <section id="adminareas">
# <h2><span class="noviz">Contents: </span>Districts and Local Units</h2>
# <p>The population of the districts and local units – i.e. metropolises <em>(mahanagarpalika)</em>, sub-metropolises <em>(upamahanagarpalika)</em>, municipalities <em>(nagarpalika)</em> and rural municiplaties <em>(gaunpalika)</em> – by census years.</p>
# <p class="small noprint" id="adlist">The <img alt="Details" class="infoicon" src="/images/icons/separate_wb.svg"/> icon links to further information about a selected division including its population structure (gender, age groups, age distribution, citizenhip, place of birth, literacy (a5+)).</p>
# <table class="data" id="tl">
# <colgroup><col data-width="0"/><col data-width="0"/><col data-width="575"/><col data-width="705"/><col data-width="445"/><col data-width="380"/><col data-width="0"/><col style="visibility:collapse"/></colgroup>
# <thead>
# <tr><th class="rname" data-coltype="name" onclick="javascript:sort('tl',0,false)"><a href="javascript:sort('tl',0,false)">Name</a></th><th class="rstatus" data-coltype="status" onclick="javascript:sort('tl',1,false)"><a href="javascript:sort('tl',1,false)">Status</a></th><th class="rnative" data-coltype="othername" onclick="javascript:sort('tl',2,false)"><a href="javascript:sort('tl',2,false)">Transcription</a></th><th class="rnative" data-coltype="othername" onclick="javascript:sort('tl',3,false)"><a href="javascript:sort('tl',3,false)">Native</a></th><th class="rpop" data-coldate="2001-05-28" data-colhead="C 2001-05-28" data-coltype="pop" onclick="javascript:sort('tl',4,true)"><a href="javascript:sort('tl',4,true)">Population</a><br/><span class="unit">Census<br/>2001-05-28</span></th><th class="rpop" data-coldate="2011-06-22" data-colhead="C 2011-06-22" data-coltype="pop" onclick="javascript:sort('tl',5,true)"><a href="javascript:sort('tl',5,true)">Population</a><br/><span class="unit">Census<br/>2011-06-22</span></th><th class="rpop" data-coldate="2021-11-25" data-colhead="C 2021-11-25" data-coltype="pop" onclick="javascript:sort('tl',6,true)"><a href="javascript:sort('tl',6,true)">Population</a><br/><span class="unit">Census<br/>2021-11-25</span></th><th class="sc" data-coltype="other"></th></tr>
# </thead>
# <tbody class="admin1">
# <tr class="rname" itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('69')"><td class="rname" data-area="1680" data-density="136.2214" data-wd="Q28426" data-wiki="Achham District" id="i69"><a href="javascript:sym('69')"><span itemprop="name">Achham</span></a></td><td class="rstatus">District</td><td class="rnative"><span itemprop="name">Achāma</span></td><td class="rnative"><span itemprop="name">अछाम जिल्ला</span></td><td class="rpop">231,285</td><td class="rpop">257,477</td><td class="rpop">228,852</td><td class="sc"><a href="/en/nepal/mun/admin/69__achham/" itemprop="url">→</a></td></tr>
# </tbody>
# <tbody class="admin2">
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6901')"><td class="rname" data-area="58.263" data-density="232.0341" data-wd="Q65396816" data-wiki="Bannigadi Jayagad Rural Municipality" id="i6901"><a href="javascript:sym('6901')"><span itemprop="name">Bannigadhi Jaygadh</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Bānnigaḍhī Jayagaḍha</span></td><td class="rnative"><span itemprop="name">बान्निगढी जयगढ गाउँपालिका</span></td><td class="rpop">17,102</td><td class="rpop">17,426</td><td class="rpop">13,519</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6901__bannigadhi_jaygadh/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6902')"><td class="rname" data-area="182.16" data-density="119.0217" data-wd="Q65410259" data-wiki="Chaurpati Rural Municipality" id="i6902"><a href="javascript:sym('6902')"><span itemprop="name">Chaurpati</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Caurapāṭī</span></td><td class="rnative"><span itemprop="name">चौरपाटी गाउँपालिका</span></td><td class="rpop">23,323</td><td class="rpop">25,215</td><td class="rpop">21,681</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6902__chaurpati/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6903')"><td class="rname" data-area="227.88" data-density="96.5333" data-wd="Q97167770" data-wiki="Dhakari Rural Municipality" id="i6903"><a href="javascript:sym('6903')"><span itemprop="name">Dhakari</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Ḍhakārī</span></td><td class="rnative"><span itemprop="name">ढकारी गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">21,570</td><td class="rpop">21,998</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6903__dhakari/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6904')"><td class="rname" data-area="120.78" data-density="174.1348" data-wd="Q21064753" data-wiki="Kamalbazar" id="i6904"><a href="javascript:sym('6904')"><span itemprop="name">Kamalbazar</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Kamalabajāra</span></td><td class="rnative"><span itemprop="name">कमलबजार नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">23,770</td><td class="rpop">21,032</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6904__kamalbazar/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6999')"><td class="rname" data-area="38.806" data-wd="Q2625399" data-wiki="Khaptad National Park" id="i6999"><a href="javascript:sym('6999')"><span itemprop="name">Khaptad National Park</span></a></td><td class="rstatus">National Park</td><td class="rnative"><span itemprop="name">Khaptaḍa Rāṣṭriya Nikuñja</span></td><td class="rnative"><span itemprop="name">खप्तड राष्ट्रिय निकुञ्ज</span></td><td class="rpop">0</td><td class="rpop">0</td><td class="rpop">0</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6999__khaptad_national_park/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6905')"><td class="rname" data-area="220.14" data-density="120.6369" data-wd="Q2481200" data-wiki="Mangalsen" id="i6905"><a href="javascript:sym('6905')"><span itemprop="name">Mangalsen</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Maṅgalasēna</span></td><td class="rnative"><span itemprop="name">मंगलसेन नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">33,191</td><td class="rpop">26,557</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6905__mangalsen/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6906')"><td class="rname" data-area="134.78" data-density="169.0533" data-wd="Q65410566" data-wiki="Mellekh Rural Municipality" id="i6906"><a href="javascript:sym('6906')"><span itemprop="name">Mellekh</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Mēllēkha</span></td><td class="rnative"><span itemprop="name">मेल्लेख गाउँपालिका</span></td><td class="rpop">21,219</td><td class="rpop">24,728</td><td class="rpop">22,785</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6906__mellekh/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6907')"><td class="rname" data-area="147.75" data-density="176.5685" data-wd="Q65410424" data-wiki="Panchadewal Binayak" id="i6907"><a href="javascript:sym('6907')"><span itemprop="name">Panchadewal Binayak</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Pañcadēvala Vināyaka</span></td><td class="rnative"><span itemprop="name">पञ्चदेवल विनायक नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">27,495</td><td class="rpop">26,088</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6907__panchadewal_binayak/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6908')"><td class="rname" data-area="173.33" data-density="136.1565" data-wd="Q65410585" data-wiki="Ramaroshan Rural Municipality" id="i6908"><a href="javascript:sym('6908')"><span itemprop="name">Ramaroshan</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Rāmārōśana</span></td><td class="rnative"><span itemprop="name">रामारोशन गाउँपालिका</span></td><td class="rpop">20,749</td><td class="rpop">25,172</td><td class="rpop">23,600</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6908__ramaroshan/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6909')"><td class="rname" data-area="166.71" data-density="155.3056" data-wd="Q7418908" data-wiki="Sanphebagar" id="i6909"><a href="javascript:sym('6909')"><span itemprop="name">Sanphebagar</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Sā̃phēbagara</span></td><td class="rnative"><span itemprop="name">साँफेबगर नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">34,128</td><td class="rpop">25,891</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6909__sanphebagar/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6910')"><td class="rname" data-area="232.07" data-density="105.8905" data-wd="Q65410357" data-wiki="Turmakhand Rural Municipality" id="i6910"><a href="javascript:sym('6910')"><span itemprop="name">Turmakhad</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Turmākhā̃da</span></td><td class="rnative"><span itemprop="name">तुर्माखाँद गाउँपालिका</span></td><td class="rpop">21,520</td><td class="rpop">24,782</td><td class="rpop">24,574</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6910__turmakhad/" itemprop="url">→</a></td></tr>
# </tbody>
# <tbody class="admin1">
# <tr class="rname" itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('51')"><td class="rname" data-area="1193" data-density="148.4376" data-wd="Q28432" data-wiki="Arghakhanchi District" id="i51"><a href="javascript:sym('51')"><span itemprop="name">Arghakhanchi</span></a></td><td class="rstatus">District</td><td class="rnative"><span itemprop="name">Arghākhā̃cī</span></td><td class="rnative"><span itemprop="name">अर्घाखाँची जिल्ला</span></td><td class="rpop">208,391</td><td class="rpop">197,632</td><td class="rpop">177,086</td><td class="sc"><a href="/en/nepal/mun/admin/51__arghakhanchi/" itemprop="url">→</a></td></tr>
# </tbody>
# <tbody class="admin2">
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5101')"><td class="rname" data-area="159.13" data-density="177.1633" data-wd="Q86751431" data-wiki="Bhumikasthan" id="i5101"><a href="javascript:sym('5101')"><span itemprop="name">Bhumikasthan</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Bhūmikāsthāna</span></td><td class="rnative"><span itemprop="name">भूमिकास्थान नगरपालिका</span></td><td class="rpop">35,250</td><td class="rpop">32,640</td><td class="rpop">28,192</td><td class="sc"><a href="/en/nepal/mun/admin/arghakhanchi/5101__bhumikasthan/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5102')"><td class="rname" data-area="87.622" data-density="246.639" data-wd="Q33062078" data-wiki="Chhatradev Rural Municipality" id="i5102"><a href="javascript:sym('5102')"><span itemprop="name">Chhatradev</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Chatradēva</span></td><td class="rnative"><span itemprop="name">छत्रदेव गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">25,343</td><td class="rpop">21,611</td><td class="sc"><a href="/en/nepal/mun/admin/arghakhanchi/5102__chhatradev/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5103')"><td class="rname" data-area="101.06" data-density="238.967" data-wd="Q105063736" data-wiki="Malarani Rural Municipality" id="i5103"><a href="javascript:sym('5103')"><span itemprop="name">Malarani</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Mālārānī</span></td><td class="rnative"><span itemprop="name">मालारानी गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">28,044</td><td class="rpop">24,150</td><td class="sc"><a href="/en/nepal/mun/admin/arghakhanchi/5103__malarani/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5104')"><td class="rname" data-area="151.43" data-density="147.2033" data-wd="Q31767293" data-wiki="Panini Rural Municipality" id="i5104"><a href="javascript:sym('5104')"><span itemprop="name">Panini</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Pāṇinī</span></td><td class="rnative"><span itemprop="name">पाणिनी गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">26,432</td><td class="rpop">22,291</td><td class="sc"><a href="/en/nepal/mun/admin/arghakhanchi/5104__panini/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5105')"><td class="rname" data-area="129.42" data-density="328.3264" data-wd="Q3091584" data-wiki="Sandhikharka" id="i5105"><a href="javascript:sym('5105')"><span itemprop="name">Sandhikharka</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Sandhikharka</span></td><td class="rnative"><span itemprop="name">सन्धिखर्क नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">41,772</td><td class="rpop">42,492</td><td class="sc"><a href="/en/nepal/mun/admin/arghakhanchi/5105__sandhikharka/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5106')"><td class="rname" data-area="610.41" data-density="61.747" data-wd="Q104863134" data-wiki="Sitganga" id="i5106"><a href="javascript:sym('5106')"><span itemprop="name">Shitaganga</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Śitagaṅgā</span></td><td class="rnative"><span itemprop="name">शितगंगा नगरपालिका</span></td><td class="rpop">44,679</td><td class="rpop">43,401</td><td class="rpop">37,691</td><td class="sc"><a href="/en/nepal/mun/admin/arghakhanchi/5106__shitaganga/" itemprop="url">→</a></td></tr>
# </tbody>
# <tbody class="admin1">
# <tr class="rname" itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('45')"><td class="rname" data-area="1784" data-density="139.6923" data-wd="Q28162" data-wiki="Baglung District" id="i45"><a href="javascript:sym('45')"><span itemprop="name">Baglung</span></a></td><td class="rstatus">District</td><td class="rnative"><span itemprop="name">Bāgaluṅa</span></td><td class="rnative"><span itemprop="name">बागलुङ जिल्ला</span></td><td class="rpop">268,937</td><td class="rpop">268,613</td><td class="rpop">249,211</td><td class="sc"><a href="/en/nepal/mun/admin/45__baglung/" itemprop="url">→</a></td></tr>
# </tbody>
# <tbody class="admin2">
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4501')"><td class="rname" data-area="178.68" data-density="161.4003" data-wd="Q97175896" data-wiki="Badigad Rural Municipality" id="i4501"><a href="javascript:sym('4501')"><span itemprop="name">Badigad</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Vaḍigāḍa</span></td><td class="rnative"><span itemprop="name">वडिगाड गाउँपालिका</span></td><td class="rpop">29,618</td><td class="rpop">30,906</td><td class="rpop">28,839</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4501__badigad/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4502')"><td class="rname" data-area="98.905" data-density="567.2312" data-wd="Q1659597" data-wiki="Baglung" id="i4502"><a href="javascript:sym('4502')"><span itemprop="name">Baglung</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Bāgaluṅa</span></td><td class="rnative"><span itemprop="name">बागलुङ नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">59,192</td><td class="rpop">56,102</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4502__baglung/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4503')"><td class="rname" data-area="75.284" data-density="148.2121" data-wd="Q97175930" data-wiki="Bareng Rural Municipality" id="i4503"><a href="javascript:sym('4503')"><span itemprop="name">Bareng</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Varēṅa</span></td><td class="rnative"><span itemprop="name">वरेङ गाउँपालिका</span></td><td class="rpop">16,678</td><td class="rpop">14,511</td><td class="rpop">11,158</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4503__bareng/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4504')"><td class="rname" data-area="222.85" data-density="134.9248" data-wd="Q5269781" data-wiki="Dhorpatan" id="i4504"><a href="javascript:sym('4504')"><span itemprop="name">Dhorpatan</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Ḍhōrapāṭana</span></td><td class="rnative"><span itemprop="name">ढोरपाटन नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">26,438</td><td class="rpop">30,068</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4504__dhorpatan/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4599')"><td class="rname" data-area="312.13" data-wd="Q5269784" data-wiki="Dhorpatan Hunting Reserve" id="i4599"><a href="javascript:sym('4599')"><span itemprop="name">Dhorpatan Hunting Reserve</span></a></td><td class="rstatus">Hunting Reserve</td><td class="rnative"><span itemprop="name">Ḍhōrapāṭana Śikāra Ārakṣa</span></td><td class="rnative"><span itemprop="name">ढोरपाटन शिकार आरक्ष</span></td><td class="rpop">0</td><td class="rpop">0</td><td class="rpop">0</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4599__dhorpatan_hunting_reserve/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4505')"><td class="rname" data-area="194.39" data-density="157.3538" data-wd="Q25110677" data-wiki="Galkot" id="i4505"><a href="javascript:sym('4505')"><span itemprop="name">Galkot</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Galkōṭa</span></td><td class="rnative"><span itemprop="name">गल्कोट नगरपालिका</span></td><td class="rpop">35,893</td><td class="rpop">33,330</td><td class="rpop">30,588</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4505__galkot/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4506')"><td class="rname" data-area="118.71" data-density="207.4636" data-wd="Q97176332" data-wiki="Jaimini Municipality" id="i4506"><a href="javascript:sym('4506')"><span itemprop="name">Jaimini</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Jaiminī</span></td><td class="rnative"><span itemprop="name">जैमिनी नगरपालिका</span></td><td class="rpop">36,392</td><td class="rpop">32,069</td><td class="rpop">24,628</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4506__jaimini/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4507')"><td class="rname" data-area="82.881" data-density="271.7873" data-wd="Q33094981" data-wiki="Khathekhola Rural Municipality" id="i4507"><a href="javascript:sym('4507')"><span itemprop="name">Kathekhola</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Kāṭhēkhōlā</span></td><td class="rnative"><span itemprop="name">काठेखोला गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">26,174</td><td class="rpop">22,526</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4507__kathekhola/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4508')"><td class="rname" data-area="244.37" data-density="94.6065" data-wd="Q33097194" data-wiki="Nisikhola Rural Municipality" id="i4508"><a href="javascript:sym('4508')"><span itemprop="name">Nisikhola</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Nisīkhōlā</span></td><td class="rnative"><span itemprop="name">निसीखोला गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">23,325</td><td class="rpop">23,119</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4508__nisikhola/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4509')"><td class="rname" data-area="178.02" data-density="56.0724" data-wd="Q33096141" data-wiki="Taman Khola Rural Municipality" id="i4509"><a href="javascript:sym('4509')"><span itemprop="name">Taman Khola</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Tamānakhōlā</span></td><td class="rnative"><span itemprop="name">तमानखोला गाउँपालिका</span></td><td class="rpop">11,103</td><td class="rpop">10,659</td><td class="rpop">9,982</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4509__taman_khola/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4510')"><td class="rname" data-area="129.53" data-density="78.1286" data-wd="Q33096718" data-wiki="Tara Khola Rural Municipality" id="i4510"><a href="javascript:sym('4510')"><span itemprop="name">Tara Khola</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Tārākhōlā</span></td><td class="rnative"><span itemprop="name">ताराखोला गाउँपालिका</span></td><td class="rpop">12,754</td><td class="rpop">12,009</td><td class="rpop">10,120</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4510__tara_khola/" itemprop="url">→</a></td></tr>
# </tbody>
# <tbody class="admin1">
# <tr class="rname" itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('74')"><td class="rname" data-area="1519" data-density="159.4187" data-wd="Q28076" data-wiki="Baitadi District" id="i74"><a href="javascript:sym('74')"><span itemprop="name">Baitadi</span></a></td><td class="rstatus">District</td><td class="rnative"><span itemprop="name">Baitaḍī</span></td><td class="rnative"><span itemprop="name">बैतडी जिल्ला</span></td><td class="rpop">234,418</td><td class="rpop">250,898</td><td class="rpop">242,157</td><td class="sc"><a href="/en/nepal/mun/admin/74__baitadi/" itemprop="url">→</a></td></tr>
# </tbody>
# <tbody class="admin2">
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7401')"><td class="rname" data-area="135.15" data-density="233.5701" data-wd="Q1564243" data-wiki="Dasharathchand" id="i7401"><a href="javascript:sym('7401')"><span itemprop="name">Dasharathchand</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Daśarathacanda</span></td><td class="rnative"><span itemprop="name">दशरथचन्द नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">35,211</td><td class="rpop">31,567</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7401__dasharathchand/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7402')"><td class="rname" data-area="125.27" data-density="183.332" data-wd="Q97167778" data-wiki="Dilashaini Rural Municipality" id="i7402"><a href="javascript:sym('7402')"><span itemprop="name">Dilashaini</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Ḍilāśainī</span></td><td class="rnative"><span itemprop="name">डिलाशैनी गाउँपालिका</span></td><td class="rpop">21,198</td><td class="rpop">22,924</td><td class="rpop">22,966</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7402__dilashaini/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7403')"><td class="rname" data-area="126.38" data-density="182.8137" data-wd="Q97167787" data-wiki="Dogdakedar Rural Municipality" id="i7403"><a href="javascript:sym('7403')"><span itemprop="name">Dogdakedar</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Dōgaḍākēdāra</span></td><td class="rnative"><span itemprop="name">दोगडाकेदार गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">24,632</td><td class="rpop">23,104</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7403__dogdakedar/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7404')"><td class="rname" data-area="119.7" data-density="172.5815" data-wd="Q3414856" data-wiki="Melauli" id="i7404"><a href="javascript:sym('7404')"><span itemprop="name">Melauli</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Mēlaulī</span></td><td class="rnative"><span itemprop="name">मेलौली नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">22,545</td><td class="rpop">20,658</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7404__melauli/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7405')"><td class="rname" data-area="120.41" data-density="147.795" data-wd="Q97168679" data-wiki="Pancheshwar Rural Municipality" id="i7405"><a href="javascript:sym('7405')"><span itemprop="name">Pancheshwar</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Pañcēśvara</span></td><td class="rnative"><span itemprop="name">पञ्चेश्वर गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">18,766</td><td class="rpop">17,796</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7405__pancheshwar/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7406')"><td class="rname" data-area="219.26" data-density="133.312" data-wd="Q6628057" data-wiki="Patan, Baitadi" id="i7406"><a href="javascript:sym('7406')"><span itemprop="name">Patan</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Pāṭana</span></td><td class="rnative"><span itemprop="name">पाटन नगरपालिका</span></td><td class="rpop">29,250</td><td class="rpop">30,456</td><td class="rpop">29,230</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7406__patan/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7407')"><td class="rname" data-area="198.52" data-density="192.832" data-wd="Q85795056" data-wiki="Purchaudi" id="i7407"><a href="javascript:sym('7407')"><span itemprop="name">Purchaudi</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Purcauḍī</span></td><td class="rnative"><span itemprop="name">पुर्चौडी नगरपालिका</span></td><td class="rpop">34,374</td><td class="rpop">39,190</td><td class="rpop">38,281</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7407__purchaudi/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7408')"><td class="rname" data-area="81.654" data-density="221.2261" data-wd="Q97160493" data-wiki="Shivanath Rural Municipality" id="i7408"><a href="javascript:sym('7408')"><span itemprop="name">Shivanath</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Śivanātha</span></td><td class="rnative"><span itemprop="name">शिवनाथ गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">17,115</td><td class="rpop">18,064</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7408__shivanath/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7409')"><td class="rname" data-area="245.44" data-density="88.8771" data-wd="Q97169178" data-wiki="Sigas Rural Municipality" id="i7409"><a href="javascript:sym('7409')"><span itemprop="name">Sigas</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Sigāsa</span></td><td class="rnative"><span itemprop="name">सिगास गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">21,510</td><td class="rpop">21,814</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7409__sigas/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7410')"><td class="rname" data-area="124.52" data-density="144.1134" data-wd="Q97160603" data-wiki="Surnaya Rural Municipality" id="i7410"><a href="javascript:sym('7410')"><span itemprop="name">Surnaya</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Surnayā</span></td><td class="rnative"><span itemprop="name">सुर्नया गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">18,549</td><td class="rpop">17,945</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7410__surnaya/" itemprop="url">→</a></td></tr>
# </tbody>
# <tbody class="admin1">
# <tr class="rname" itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('68')"><td class="rname" data-area="3422" data-density="55.2557" data-wd="Q28592" data-wiki="Bajhang District" id="i68"><a href="javascript:sym('68')"><span itemprop="name">Bajhang</span></a></td><td class="rstatus">District</td><td class="rnative"><span itemprop="name">Bajhāṅa</span></td><td class="rnative"><span itemprop="name">बझाङ जिल्ला</span></td><td class="rpop">167,026</td><td class="rpop">195,159</td><td class="rpop">189,085</td><td class="sc"><a href="/en/nepal/mun/admin/68__bajhang/" itemprop="url">→</a></td></tr>
# </tbody>
# <tbody class="admin2">
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6801')"><td class="rname" data-area="86.148" data-density="206.7605" data-wd="Q97159457" data-wiki="Bitthadchir Rural Municipality" id="i6801"><a href="javascript:sym('6801')"><span itemprop="name">Bitthadchir</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Vitthaḍacira</span></td><td class="rnative"><span itemprop="name">वित्थडचिर गाउँपालिका</span></td><td class="rpop">14,164</td><td class="rpop">17,163</td><td class="rpop">17,812</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6801__bitthadchir/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6802')"><td class="rname" data-area="447.58" data-density="75.544" data-wd="Q85749520" data-wiki="Bungal Municipality" id="i6802"><a href="javascript:sym('6802')"><span itemprop="name">Bungal</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Buṅgala</span></td><td class="rnative"><span itemprop="name">बुंगल नगरपालिका</span></td><td class="rpop">27,284</td><td class="rpop">33,224</td><td class="rpop">33,812</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6802__bungal/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6803')"><td class="rname" data-area="116.34" data-density="124.4112" data-wd="Q97159466" data-wiki="Chhabis Pathibhera Rural Municipality" id="i6803"><a href="javascript:sym('6803')"><span itemprop="name">Chhabispathibhera</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Chabisapāthibhērā</span></td><td class="rnative"><span itemprop="name">छबिसपाथिभेरा गाउँपालिका</span></td><td class="rpop">14,569</td><td class="rpop">16,296</td><td class="rpop">14,474</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6803__chhabispathibhera/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6804')"><td class="rname" data-area="61.834" data-density="183.0385" data-wd="Q97159479" data-wiki="Durgathali Rural Municipality" id="i6804"><a href="javascript:sym('6804')"><span itemprop="name">Durgathali</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Durgāthalī</span></td><td class="rnative"><span itemprop="name">दुर्गाथली गाउँपालिका</span></td><td class="rpop">12,022</td><td class="rpop">12,980</td><td class="rpop">11,318</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6804__durgathali/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6805')"><td class="rname" data-area="166.79" data-density="131.5007" data-wd="Q17870386" data-wiki="Jayaprithvi" id="i6805"><a href="javascript:sym('6805')"><span itemprop="name">Jaya Prithvi</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Jayapr̥thvī</span></td><td class="rnative"><span itemprop="name">जयपृथ्वी नगरपालिका</span></td><td class="rpop">19,093</td><td class="rpop">22,553</td><td class="rpop">21,933</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6805__jaya_prithvi/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6807')"><td class="rname" data-area="113.91" data-density="187.0951" data-wd="Q97159736" data-wiki="Kedarsyu Rural Municipality" id="i6807"><a href="javascript:sym('6807')"><span itemprop="name">Kedarsyu</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Kēdārasyũ</span></td><td class="rnative"><span itemprop="name">केदारस्युँ गाउँपालिका</span></td><td class="rpop">18,490</td><td class="rpop">21,316</td><td class="rpop">21,312</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6807__kedarsyu/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6808')"><td class="rname" data-area="113.52" data-density="118.2082" data-wd="Q97159467" data-wiki="Khaptadchhanna Rural Municipality" id="i6808"><a href="javascript:sym('6808')"><span itemprop="name">Khaptadchhanna</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Khaptaḍachānnā</span></td><td class="rnative"><span itemprop="name">खप्तडछान्ना गाउँपालिका</span></td><td class="rpop">15,715</td><td class="rpop">15,903</td><td class="rpop">13,419</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6808__khaptadchhanna/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6899')"><td class="rname" data-area="70.111" data-wd="Q2625399" data-wiki="Khaptad National Park" id="i6899"><a href="javascript:sym('6899')"><span itemprop="name">Khaptad National Park</span></a></td><td class="rstatus">National Park</td><td class="rnative"><span itemprop="name">Khaptaḍa Rāṣṭriya Nikuñja</span></td><td class="rnative"><span itemprop="name">खप्तड राष्ट्रिय निकुञ्ज</span></td><td class="rpop">0</td><td class="rpop">0</td><td class="rpop">0</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6899__khaptad_national_park/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6809')"><td class="rname" data-area="109.24" data-density="121.4299" data-wd="Q97160022" data-wiki="Masta Rural Municipality" id="i6809"><a href="javascript:sym('6809')"><span itemprop="name">Masta</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Maṣṭā</span></td><td class="rnative"><span itemprop="name">मष्टा गाउँपालिका</span></td><td class="rpop">12,114</td><td class="rpop">14,951</td><td class="rpop">13,265</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6809__masta/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6806')"><td class="rname" data-area="1467.3" data-density="1.789" data-wd="Q97160472" data-wiki="Saipal Rural Municipality" id="i6806"><a href="javascript:sym('6806')"><span itemprop="name">Saipal</span></a> [<span itemprop="name">Kanda</span>]</td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Sāipāla</span></td><td class="rnative"><span itemprop="name">साइपाल गाउँपालिका</span></td><td class="rpop">1,715</td><td class="rpop">2,193</td><td class="rpop">2,625</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6806__saipal/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6810')"><td class="rname" data-area="270.8" data-density="40.9232" data-wd="Q97160592" data-wiki="Surma Rural Municipality" id="i6810"><a href="javascript:sym('6810')"><span itemprop="name">Surma</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Sūrmā</span></td><td class="rnative"><span itemprop="name">सूर्मा गाउँपालिका</span></td><td class="rpop">6,523</td><td class="rpop">9,033</td><td class="rpop">11,082</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6810__surma/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6811')"><td class="rname" data-area="335.26" data-density="34.955" data-wd="Q97160669" data-wiki="Talkot Rural Municipality" id="i6811"><a href="javascript:sym('6811')"><span itemprop="name">Talkot</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Talakōṭa</span></td><td class="rnative"><span itemprop="name">तलकोट गाउँपालिका</span></td><td class="rpop">9,130</td><td class="rpop">11,569</td><td class="rpop">11,719</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6811__talkot/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6812')"><td class="rname" data-area="105.51" data-density="151.2463" data-wd="Q97160692" data-wiki="Thalara Rural Municipality" id="i6812"><a href="javascript:sym('6812')"><span itemprop="name">Thalara</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Thalārā</span></td><td class="rnative"><span itemprop="name">थलारा गाउँपालिका</span></td><td class="rpop">16,028</td><td class="rpop">17,978</td><td class="rpop">15,958</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6812__thalara/" itemprop="url">→</a></td></tr>
# </tbody>
# <tbody class="admin1">
# <tr class="rname" itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('67')"><td class="rname" data-area="2188" data-density="63.3103" data-wd="Q28071" data-wiki="Bajura District" id="i67"><a href="javascript:sym('67')"><span itemprop="name">Bajura</span></a></td><td class="rstatus">District</td><td class="rnative"><span itemprop="name">Bājurā</span></td><td class="rnative"><span itemprop="name">बाजुरा जिल्ला</span></td><td class="rpop">108,781</td><td class="rpop">134,912</td><td class="rpop">138,523</td><td class="sc"><a href="/en/nepal/mun/admin/67__bajura/" itemprop="url">→</a></td></tr>
# </tbody>
# <tbody class="admin2">
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6701')"><td class="rname" data-area="276" data-density="66.7174" data-wd="Q20822699" data-wiki="Badimalika" id="i6701"><a href="javascript:sym('6701')"><span itemprop="name">Badimalika</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Baḍīmālikā</span></td><td class="rnative"><span itemprop="name">बडीमालिका नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">17,259</td><td class="rpop">18,414</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6701__badimalika/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6702')"><td class="rname" data-area="59.196" data-density="340.9859" data-wd="Q3414084" data-wiki="Budhiganga" id="i6702"><a href="javascript:sym('6702')"><span itemprop="name">Budhiganga</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Buḍhīgaṅgā</span></td><td class="rnative"><span itemprop="name">बुढीगंगा नगरपालिका</span></td><td class="rpop">18,697</td><td class="rpop">21,700</td><td class="rpop">20,185</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6702__budhiganga/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6703')"><td class="rname" data-area="232.48" data-density="86.3386" data-wd="Q85749365" data-wiki="Budhinanda" id="i6703"><a href="javascript:sym('6703')"><span itemprop="name">Budhinanda</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Buḍhīnandā</span></td><td class="rnative"><span itemprop="name">बुढीनन्दा नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">18,883</td><td class="rpop">20,072</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6703__budhinanda/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6704')"><td class="rname" data-area="127.52" data-density="151.4037" data-wd="Q85751855" data-wiki="Chhededaha Rural Municipality" id="i6704"><a href="javascript:sym('6704')"><span itemprop="name">Chhededaha</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Chēḍēdaha</span></td><td class="rnative"><span itemprop="name">छेडेदह गाउँपालिका</span></td><td class="rpop">15,812</td><td class="rpop">18,741</td><td class="rpop">19,307</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6704__chhededaha/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6705')"><td class="rname" data-area="314.66" data-density="28.3258" data-wd="Q85762841" data-wiki="Gaumul Rural Municipality" id="i6705"><a href="javascript:sym('6705')"><span itemprop="name">Gaumul</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Gaumula</span></td><td class="rnative"><span itemprop="name">गौमुल गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">8,515</td><td class="rpop">8,913</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6705__gaumul/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6706')"><td class="rname" data-area="830.33" data-density="12.4155" data-wd="Q65410742" data-wiki="Himali Rural Municipality" id="i6706"><a href="javascript:sym('6706')"><span itemprop="name">Himali</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Himālī</span></td><td class="rnative"><span itemprop="name">हिमाली गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">9,229</td><td class="rpop">10,309</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6706__himali/" itemprop="url">→</a></td></tr>
# ...
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('1404')"><td class="rname" data-area="204.08" data-density="99.5884" data-wd="Q30301465" data-wiki="Rautamai Rural Municipality" id="i1404"><a href="javascript:sym('1404')"><span itemprop="name">Rautamai</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Rautāmāī</span></td><td class="rnative"><span itemprop="name">रौतामाई गाउँपालिका</span></td><td class="rpop">23,113</td><td class="rpop">23,481</td><td class="rpop">20,324</td><td class="sc"><a href="/en/nepal/mun/admin/udayapur/1404__rautamai/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('1406')"><td class="rname" data-area="119.11" data-density="112.0309" data-wd="Q30301455" data-wiki="Tapli Rural Municipality" id="i1406"><a href="javascript:sym('1406')"><span itemprop="name">Tapli</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Tāplī</span></td><td class="rnative"><span itemprop="name">ताप्ली गाउँपालिका</span></td><td class="rpop">14,643</td><td class="rpop">14,567</td><td class="rpop">13,344</td><td class="sc"><a href="/en/nepal/mun/admin/udayapur/1406__tapli/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('1407')"><td class="rname" data-area="547.44" data-density="187.6461" data-wd="Q1457919" data-wiki="Triyuga Municipality" id="i1407"><a href="javascript:sym('1407')"><span itemprop="name">Triyuga</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Triyugā</span></td><td class="rnative"><span itemprop="name">त्रियुगा नगरपालिका</span></td><td class="rpop">71,131</td><td class="rpop">88,967</td><td class="rpop">102,725</td><td class="sc"><a href="/en/nepal/mun/admin/udayapur/1407__triyuga/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('1408')"><td class="rname" data-area="269.51" data-density="107.3281" data-wd="Q30301446" data-wiki="Udayapurgadhi Rural Municipality" id="i1408"><a href="javascript:sym('1408')"><span itemprop="name">Udayapurgadhi</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Udayapuragaḍhī</span></td><td class="rnative"><span itemprop="name">उदयपुरगढी गाउँपालिका</span></td><td class="rpop">29,741</td><td class="rpop">30,780</td><td class="rpop">28,926</td><td class="sc"><a href="/en/nepal/mun/admin/udayapur/1408__udayapurgadhi/" itemprop="url">→</a></td></tr>
# </tbody>
# <tbody class="admin1">
# <tr class="rname" itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('54')"><td class="rname" data-area="1217" data-density="137.009" data-wd="Q53018063" data-wiki="Western Rukum District" id="i54"><a href="javascript:sym('54')"><span itemprop="name">West Rukum</span></a></td><td class="rstatus">District</td><td class="rnative"><span itemprop="name">Paścima Rukuma</span></td><td class="rnative"><span itemprop="name">पश्चिम रुकुम जिल्ला</span></td><td class="rpop">140,387</td><td class="rpop">155,383</td><td class="rpop">166,740</td><td class="sc"><a href="/en/nepal/mun/admin/54__west_rukum/" itemprop="url">→</a></td></tr>
# </tbody>
# <tbody class="admin2">
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5401')"><td class="rname" data-area="560.34" data-density="64.0986" data-wd="Q3423389" data-wiki="Aathbiskot" id="i5401"><a href="javascript:sym('5401')"><span itemprop="name">Aathbiskot</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Āṭhavisakōṭa</span></td><td class="rnative"><span itemprop="name">आठविसकोट नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">33,624</td><td class="rpop">35,917</td><td class="sc"><a href="/en/nepal/mun/admin/west_rukum/5401__aathbiskot/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5402')"><td class="rname" data-area="190.4" data-density="110.4674" data-wd="Q96373122" data-wiki="Banphikot Rural Municipality" id="i5402"><a href="javascript:sym('5402')"><span itemprop="name">Banphikot</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Bā̃phikōṭa</span></td><td class="rnative"><span itemprop="name">बाँफिकोट गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">18,696</td><td class="rpop">21,033</td><td class="sc"><a href="/en/nepal/mun/admin/west_rukum/5402__banphikot/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5403')"><td class="rname" data-area="107.36" data-density="269.7094" data-wd="Q3412638" data-wiki="Chaurjahari" id="i5403"><a href="javascript:sym('5403')"><span itemprop="name">Chaurjahari</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Caurajahārī</span></td><td class="rnative"><span itemprop="name">चौरजहारी नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">27,583</td><td class="rpop">28,956</td><td class="sc"><a href="/en/nepal/mun/admin/west_rukum/5403__chaurjahari/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5404')"><td class="rname" data-area="162.69" data-density="210.646" data-wd="Q3420064" data-wiki="Musikot, Western Rukum" id="i5404"><a href="javascript:sym('5404')"><span itemprop="name">Musikot</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Musikōṭa</span></td><td class="rnative"><span itemprop="name">मुसिकोट नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">33,882</td><td class="rpop">34,270</td><td class="sc"><a href="/en/nepal/mun/admin/west_rukum/5404__musikot/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5405')"><td class="rname" data-area="133.79" data-density="185.0587" data-wd="Q60765483" data-wiki="Sani Bheri Rural Municipality" id="i5405"><a href="javascript:sym('5405')"><span itemprop="name">Sani Bheri</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Sānī Bhērī</span></td><td class="rnative"><span itemprop="name">सानी भेरी गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">22,194</td><td class="rpop">24,759</td><td class="sc"><a href="/en/nepal/mun/admin/west_rukum/5405__sani_bheri/" itemprop="url">→</a></td></tr>
# <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5406')"><td class="rname" data-area="85.502" data-density="240.0529" data-wd="Q60766214" data-wiki="Triveni Rural Municipality, Western Rukum" id="i5406"><a href="javascript:sym('5406')"><span itemprop="name">Triveni</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Trivēṇī</span></td><td class="rnative"><span itemprop="name">त्रिवेणी गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">19,404</td><td class="rpop">20,525</td><td class="sc"><a href="/en/nepal/mun/admin/west_rukum/5406__triveni/" itemprop="url">→</a></td></tr>
# </tbody>
# <tbody class="admin0">
# <tr><td class="rname">Nepal</td><td class="rstatus">Federal Republic</td><td class="rnative"><span itemprop="name">Nēpāla</span></td><td class="rnative"><span itemprop="name">नेपाल</span></td><td class="rpop">23,151,423</td><td class="rpop">26,494,504</td><td class="rpop">29,164,578</td><td class="sc"></td></tr>
# </tbody>
# </table>
# </section>
# <section id="sourcesection">
# <p class="source"><strong>Source:</strong> Central Bureau of Statistics Nepal (web).</p>
# <p class="expl"><strong>Explanation:</strong> The local units became operational in May 2017. The 2021 population of local units exclude institional population.</p>
# </section>
# <hr id="hraddinfo"/>
# <section id="addinfos">
# <h3>Further information about the population structure:</h3>
# <div id="chartgrid">
# <section class="addinfo"><div class="addchart" id="addchart0"></div>
# <table class="data"><thead><tr><th colspan="2">Gender (C 2021)</th></tr></thead><tbody>
# <tr onclick="setMapMode('gender',cp.maps.GENDER_MODE)"><td><a href="javascript:setMapMode('gender',cp.maps.GENDER_MODE)">Males</a></td><td class="rpop">14,253,551</td></tr>
# <tr onclick="setMapMode('gender',cp.maps.GENDER_MODE)"><td><a href="javascript:setMapMode('gender',cp.maps.GENDER_MODE)">Females</a></td><td class="rpop">14,911,027</td></tr>
# </tbody></table></section>
# <section class="addinfo"><div class="addchart" id="addchart1"></div>
# <table class="data"><thead><tr><th colspan="2">Age Groups (C 2021)</th></tr></thead><tbody>
# <tr onclick="setUserMode('T00_14',0)"><td><a href="javascript:setUserMode('T00_14',0)">0-14 years</a></td><td class="rpop">8,115,575</td></tr>
# <tr onclick="setUserMode('T15_64',1)"><td><a href="javascript:setUserMode('T15_64',1)">15-64 years</a></td><td class="rpop">19,027,289</td></tr>
# <tr onclick="setMapMode('oldage',cp.maps.OLDAGE_MODE)"><td><a href="javascript:setMapMode('oldage',cp.maps.OLDAGE_MODE)">65+ years</a></td><td class="rpop">2,021,714</td></tr>
# </tbody></table></section>
# <section class="addinfo"><div class="addchart" id="addchart2"></div>
# <table class="data"><thead><tr><th colspan="2">Age Distribution (C 2021)</th></tr></thead><tbody>
# <tr onclick="setUserMode('T90_xx',0)"><td><a href="javascript:setUserMode('T90_xx',0)">90+ years</a></td><td class="rpop">47,640</td></tr>
# <tr onclick="setUserMode('T80_89',0)"><td><a href="javascript:setUserMode('T80_89',0)">80-89 years</a></td><td class="rpop">239,883</td></tr>
# <tr onclick="setUserMode('T70_79',0)"><td><a href="javascript:setUserMode('T70_79',0)">70-79 years</a></td><td class="rpop">962,573</td></tr>
# <tr onclick="setUserMode('T60_69',0)"><td><a href="javascript:setUserMode('T60_69',0)">60-69 years</a></td><td class="rpop">1,727,222</td></tr>
# <tr onclick="setUserMode('T50_59',0)"><td><a href="javascript:setUserMode('T50_59',0)">50-59 years</a></td><td class="rpop">2,489,796</td></tr>
# <tr onclick="setUserMode('T40_49',0)"><td><a href="javascript:setUserMode('T40_49',0)">40-49 years</a></td><td class="rpop">3,183,872</td></tr>
# <tr onclick="setUserMode('T30_39',0)"><td><a href="javascript:setUserMode('T30_39',0)">30-39 years</a></td><td class="rpop">4,189,204</td></tr>
# <tr onclick="setUserMode('T20_29',0)"><td><a href="javascript:setUserMode('T20_29',0)">20-29 years</a></td><td class="rpop">5,242,409</td></tr>
# <tr onclick="setUserMode('T10_19',0)"><td><a href="javascript:setUserMode('T10_19',0)">10-19 years</a></td><td class="rpop">5,876,269</td></tr>
# <tr onclick="setUserMode('T00_09',0)"><td><a href="javascript:setUserMode('T00_09',0)">0-9 years</a></td><td class="rpop">5,205,710</td></tr>
# </tbody></table></section>
# <section class="addinfo"><div class="addchart" id="addchart3"></div>
# <table class="data"><thead><tr><th colspan="2">Citizenhip (C 2021)</th></tr></thead><tbody>
# <tr onclick="setUserMode('N_NPL',0)"><td><a href="javascript:setUserMode('N_NPL',0)">Nepal</a></td><td class="rpop">29,027,171</td></tr>
# <tr onclick="setUserMode('N_IND',1)"><td><a href="javascript:setUserMode('N_IND',1)">India</a></td><td class="rpop">132,781</td></tr>
# <tr onclick="setUserMode('N_X',2)"><td><a href="javascript:setUserMode('N_X',2)">Other Citizenship</a></td><td class="rpop">4,437</td></tr>
# </tbody></table></section>
# <section class="addinfo"><div class="addchart" id="addchart4"></div>
# <table class="data"><thead><tr><th colspan="2">Place of Birth (C 2021)</th></tr></thead><tbody>
# <tr onclick="setUserMode('B_LOC',0)"><td><a href="javascript:setUserMode('B_LOC',0)">Same local unit</a></td><td class="rpop">20,117,395</td></tr>
# <tr onclick="setUserMode('B_DIS',1)"><td><a href="javascript:setUserMode('B_DIS',1)">Other local unit in same district</a></td><td class="rpop">2,612,713</td></tr>
# <tr onclick="setUserMode('B_NPL',2)"><td><a href="javascript:setUserMode('B_NPL',2)">Other district</a></td><td class="rpop">5,690,225</td></tr>
# <tr onclick="setUserMode('B_X',3)"><td><a href="javascript:setUserMode('B_X',3)">Other country</a></td><td class="rpop">734,663</td></tr>
# </tbody></table></section>
# <section class="addinfo"><div class="addchart" id="addchart5"></div>
# <table class="data"><thead><tr><th colspan="2">Literacy (A5+) (C 2021)</th></tr></thead><tbody>
# <tr onclick="setMapMode('literacy',cp.maps.LITERACY_MODE)"><td><a href="javascript:setMapMode('literacy',cp.maps.LITERACY_MODE)">Yes</a></td><td class="rpop">20,377,980</td></tr>
# <tr onclick="setMapMode('literacy',cp.maps.LITERACY_MODE)"><td><a href="javascript:setMapMode('literacy',cp.maps.LITERACY_MODE)">Only reading</a></td><td class="rpop">114,331</td></tr>
# <tr onclick="setMapMode('literacy',cp.maps.LITERACY_MODE)"><td><a href="javascript:setMapMode('literacy',cp.maps.LITERACY_MODE)">No</a></td><td class="rpop">6,223,061</td></tr>
# </tbody></table></section>
# </div>
# <script>var addChartData = [{"name":"Gender","type":"pie","format":"f0","data":[["Gender","Persons"],["Males",14253551],["Females",14911027]],"options":{"colors":["#36c","#dc3912"]}},
# {"name":"Age Groups","type":"pie","format":"f0","data":[["Age Groups","Persons"],["0-14 years",8115575],["15-64 years",19027289],["65+ years",2021714]],"options":{"colors":["#36c","#dc3912","#f90"]}},
# {"name":"Age Distribution","type":"pyramid","format":"f0","data":[["Age Distribution","Males","Females"],["90+ years",-20001,27639],["80-89 years",-115203,124680],["70-79 years",-463052,499521],["60-69 years",-845651,881571],["50-59 years",-1230052,1259744],["40-49 years",-1516018,1667854],["30-39 years",-1915907,2273297],["20-29 years",-2423260,2819149],["10-19 years",-2990477,2885792],["0-9 years",-2733930,2471780]]},
# {"name":"Citizenhip","type":"pie","format":"f0","data":[["Citizenhip","Persons"],["Nepal",29027171],["India",132781],["Other Citizenship",4437]],"options":{"colors":["#36c","#dc3912","#f90"]}},
# {"name":"Place of Birth","type":"pie","format":"f0","data":[["Place of Birth","Persons"],["Same local unit",20117395],["Other local unit in same district",2612713],["Other district",5690225],["Other country",734663]],"options":{"colors":["#36c","#dc3912","#f90","#109618"]}},
# {"name":"Literacy (A5+)","type":"pie","format":"f0","data":[["Literacy (A5+)","Persons"],["Yes",20377980],["Only reading",114331],["No",6223061]],"options":{"colors":["#36c","#f90","#dc3912"]}}]</script>
# </section>
# <script>var addMapData = ["genderM","genderF","ageX","ageX","ageO","nationalN","nationalX","nationalX","birthN","birthN","birthN","birthX","literacyY","literacyN","literacyN"]; var addMapMetadata = [{ "maptype":"genderM", "date":"C 2021-11-25" },{ "maptype":"ageX", "date":"C 2021-11-25" },{ "maptype":"nationalN", "date":"C 2021-11-25" },{ "maptype":"birthN", "date":"C 2021-11-25" },{ "maptype":"literacyY", "date":"C 2021-11-25" }]</script>
# <div class="mobiadv">
# <script>show_mobiadv()</script>
# </div>
# <div id="advhor">
# <script>show_adv('h');</script>
# </div>
# <script>writeFooter('2023-03-25')</script>
# </article>
# <div id="admmap" itemprop="geo" itemscope="" itemtype="http://schema.org/GeoCoordinates">
# <meta content="28.398" itemprop="latitude"/>
# <meta content="84.132" itemprop="longitude"/>
# <div id="mapcontainer">
# <div id="mapdiv">
# <div id="maplconrl"></div>
# <div id="maprconrl"></div>
# </div>
# </div>
# </div>
# <div id="alert"></div>
# <div id="helpdiv"></div>
# <div id="adv">
# <script>show_adv();</script>
# </div>
# <script>
# 	var startChartID = "NPL"; var startChartType = "adm0";
# 	var minlat = 26.348; var minlng = 80.06; var maxlat = 30.447; var maxlng = 88.204;
# 	var admCount = { "adm1": 77, "adm2": 773 };
# 	if (cp.getVizMode() == cp.VIZMODE_DESKTOP) cp.social.addSocial(false);
# </script>
# </body>
# </html>
# <!-- create time: 0.046689987182617 asia -->

# %% [markdown]
# ### Scraping the tabular informations

# %%
table = soup.find_all('table')

# %%
table
# Out:
# [<table class="data" id="tl">
#  <colgroup><col data-width="0"/><col data-width="0"/><col data-width="575"/><col data-width="705"/><col data-width="445"/><col data-width="380"/><col data-width="0"/><col style="visibility:collapse"/></colgroup>
#  <thead>
#  <tr><th class="rname" data-coltype="name" onclick="javascript:sort('tl',0,false)"><a href="javascript:sort('tl',0,false)">Name</a></th><th class="rstatus" data-coltype="status" onclick="javascript:sort('tl',1,false)"><a href="javascript:sort('tl',1,false)">Status</a></th><th class="rnative" data-coltype="othername" onclick="javascript:sort('tl',2,false)"><a href="javascript:sort('tl',2,false)">Transcription</a></th><th class="rnative" data-coltype="othername" onclick="javascript:sort('tl',3,false)"><a href="javascript:sort('tl',3,false)">Native</a></th><th class="rpop" data-coldate="2001-05-28" data-colhead="C 2001-05-28" data-coltype="pop" onclick="javascript:sort('tl',4,true)"><a href="javascript:sort('tl',4,true)">Population</a><br/><span class="unit">Census<br/>2001-05-28</span></th><th class="rpop" data-coldate="2011-06-22" data-colhead="C 2011-06-22" data-coltype="pop" onclick="javascript:sort('tl',5,true)"><a href="javascript:sort('tl',5,true)">Population</a><br/><span class="unit">Census<br/>2011-06-22</span></th><th class="rpop" data-coldate="2021-11-25" data-colhead="C 2021-11-25" data-coltype="pop" onclick="javascript:sort('tl',6,true)"><a href="javascript:sort('tl',6,true)">Population</a><br/><span class="unit">Census<br/>2021-11-25</span></th><th class="sc" data-coltype="other"></th></tr>
#  </thead>
#  <tbody class="admin1">
#  <tr class="rname" itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('69')"><td class="rname" data-area="1680" data-density="136.2214" data-wd="Q28426" data-wiki="Achham District" id="i69"><a href="javascript:sym('69')"><span itemprop="name">Achham</span></a></td><td class="rstatus">District</td><td class="rnative"><span itemprop="name">Achāma</span></td><td class="rnative"><span itemprop="name">अछाम जिल्ला</span></td><td class="rpop">231,285</td><td class="rpop">257,477</td><td class="rpop">228,852</td><td class="sc"><a href="/en/nepal/mun/admin/69__achham/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin2">
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6901')"><td class="rname" data-area="58.263" data-density="232.0341" data-wd="Q65396816" data-wiki="Bannigadi Jayagad Rural Municipality" id="i6901"><a href="javascript:sym('6901')"><span itemprop="name">Bannigadhi Jaygadh</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Bānnigaḍhī Jayagaḍha</span></td><td class="rnative"><span itemprop="name">बान्निगढी जयगढ गाउँपालिका</span></td><td class="rpop">17,102</td><td class="rpop">17,426</td><td class="rpop">13,519</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6901__bannigadhi_jaygadh/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6902')"><td class="rname" data-area="182.16" data-density="119.0217" data-wd="Q65410259" data-wiki="Chaurpati Rural Municipality" id="i6902"><a href="javascript:sym('6902')"><span itemprop="name">Chaurpati</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Caurapāṭī</span></td><td class="rnative"><span itemprop="name">चौरपाटी गाउँपालिका</span></td><td class="rpop">23,323</td><td class="rpop">25,215</td><td class="rpop">21,681</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6902__chaurpati/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6903')"><td class="rname" data-area="227.88" data-density="96.5333" data-wd="Q97167770" data-wiki="Dhakari Rural Municipality" id="i6903"><a href="javascript:sym('6903')"><span itemprop="name">Dhakari</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Ḍhakārī</span></td><td class="rnative"><span itemprop="name">ढकारी गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">21,570</td><td class="rpop">21,998</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6903__dhakari/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6904')"><td class="rname" data-area="120.78" data-density="174.1348" data-wd="Q21064753" data-wiki="Kamalbazar" id="i6904"><a href="javascript:sym('6904')"><span itemprop="name">Kamalbazar</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Kamalabajāra</span></td><td class="rnative"><span itemprop="name">कमलबजार नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">23,770</td><td class="rpop">21,032</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6904__kamalbazar/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6999')"><td class="rname" data-area="38.806" data-wd="Q2625399" data-wiki="Khaptad National Park" id="i6999"><a href="javascript:sym('6999')"><span itemprop="name">Khaptad National Park</span></a></td><td class="rstatus">National Park</td><td class="rnative"><span itemprop="name">Khaptaḍa Rāṣṭriya Nikuñja</span></td><td class="rnative"><span itemprop="name">खप्तड राष्ट्रिय निकुञ्ज</span></td><td class="rpop">0</td><td class="rpop">0</td><td class="rpop">0</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6999__khaptad_national_park/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6905')"><td class="rname" data-area="220.14" data-density="120.6369" data-wd="Q2481200" data-wiki="Mangalsen" id="i6905"><a href="javascript:sym('6905')"><span itemprop="name">Mangalsen</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Maṅgalasēna</span></td><td class="rnative"><span itemprop="name">मंगलसेन नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">33,191</td><td class="rpop">26,557</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6905__mangalsen/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6906')"><td class="rname" data-area="134.78" data-density="169.0533" data-wd="Q65410566" data-wiki="Mellekh Rural Municipality" id="i6906"><a href="javascript:sym('6906')"><span itemprop="name">Mellekh</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Mēllēkha</span></td><td class="rnative"><span itemprop="name">मेल्लेख गाउँपालिका</span></td><td class="rpop">21,219</td><td class="rpop">24,728</td><td class="rpop">22,785</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6906__mellekh/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6907')"><td class="rname" data-area="147.75" data-density="176.5685" data-wd="Q65410424" data-wiki="Panchadewal Binayak" id="i6907"><a href="javascript:sym('6907')"><span itemprop="name">Panchadewal Binayak</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Pañcadēvala Vināyaka</span></td><td class="rnative"><span itemprop="name">पञ्चदेवल विनायक नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">27,495</td><td class="rpop">26,088</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6907__panchadewal_binayak/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6908')"><td class="rname" data-area="173.33" data-density="136.1565" data-wd="Q65410585" data-wiki="Ramaroshan Rural Municipality" id="i6908"><a href="javascript:sym('6908')"><span itemprop="name">Ramaroshan</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Rāmārōśana</span></td><td class="rnative"><span itemprop="name">रामारोशन गाउँपालिका</span></td><td class="rpop">20,749</td><td class="rpop">25,172</td><td class="rpop">23,600</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6908__ramaroshan/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6909')"><td class="rname" data-area="166.71" data-density="155.3056" data-wd="Q7418908" data-wiki="Sanphebagar" id="i6909"><a href="javascript:sym('6909')"><span itemprop="name">Sanphebagar</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Sā̃phēbagara</span></td><td class="rnative"><span itemprop="name">साँफेबगर नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">34,128</td><td class="rpop">25,891</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6909__sanphebagar/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6910')"><td class="rname" data-area="232.07" data-density="105.8905" data-wd="Q65410357" data-wiki="Turmakhand Rural Municipality" id="i6910"><a href="javascript:sym('6910')"><span itemprop="name">Turmakhad</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Turmākhā̃da</span></td><td class="rnative"><span itemprop="name">तुर्माखाँद गाउँपालिका</span></td><td class="rpop">21,520</td><td class="rpop">24,782</td><td class="rpop">24,574</td><td class="sc"><a href="/en/nepal/mun/admin/achham/6910__turmakhad/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin1">
#  <tr class="rname" itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('51')"><td class="rname" data-area="1193" data-density="148.4376" data-wd="Q28432" data-wiki="Arghakhanchi District" id="i51"><a href="javascript:sym('51')"><span itemprop="name">Arghakhanchi</span></a></td><td class="rstatus">District</td><td class="rnative"><span itemprop="name">Arghākhā̃cī</span></td><td class="rnative"><span itemprop="name">अर्घाखाँची जिल्ला</span></td><td class="rpop">208,391</td><td class="rpop">197,632</td><td class="rpop">177,086</td><td class="sc"><a href="/en/nepal/mun/admin/51__arghakhanchi/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin2">
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5101')"><td class="rname" data-area="159.13" data-density="177.1633" data-wd="Q86751431" data-wiki="Bhumikasthan" id="i5101"><a href="javascript:sym('5101')"><span itemprop="name">Bhumikasthan</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Bhūmikāsthāna</span></td><td class="rnative"><span itemprop="name">भूमिकास्थान नगरपालिका</span></td><td class="rpop">35,250</td><td class="rpop">32,640</td><td class="rpop">28,192</td><td class="sc"><a href="/en/nepal/mun/admin/arghakhanchi/5101__bhumikasthan/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5102')"><td class="rname" data-area="87.622" data-density="246.639" data-wd="Q33062078" data-wiki="Chhatradev Rural Municipality" id="i5102"><a href="javascript:sym('5102')"><span itemprop="name">Chhatradev</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Chatradēva</span></td><td class="rnative"><span itemprop="name">छत्रदेव गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">25,343</td><td class="rpop">21,611</td><td class="sc"><a href="/en/nepal/mun/admin/arghakhanchi/5102__chhatradev/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5103')"><td class="rname" data-area="101.06" data-density="238.967" data-wd="Q105063736" data-wiki="Malarani Rural Municipality" id="i5103"><a href="javascript:sym('5103')"><span itemprop="name">Malarani</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Mālārānī</span></td><td class="rnative"><span itemprop="name">मालारानी गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">28,044</td><td class="rpop">24,150</td><td class="sc"><a href="/en/nepal/mun/admin/arghakhanchi/5103__malarani/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5104')"><td class="rname" data-area="151.43" data-density="147.2033" data-wd="Q31767293" data-wiki="Panini Rural Municipality" id="i5104"><a href="javascript:sym('5104')"><span itemprop="name">Panini</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Pāṇinī</span></td><td class="rnative"><span itemprop="name">पाणिनी गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">26,432</td><td class="rpop">22,291</td><td class="sc"><a href="/en/nepal/mun/admin/arghakhanchi/5104__panini/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5105')"><td class="rname" data-area="129.42" data-density="328.3264" data-wd="Q3091584" data-wiki="Sandhikharka" id="i5105"><a href="javascript:sym('5105')"><span itemprop="name">Sandhikharka</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Sandhikharka</span></td><td class="rnative"><span itemprop="name">सन्धिखर्क नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">41,772</td><td class="rpop">42,492</td><td class="sc"><a href="/en/nepal/mun/admin/arghakhanchi/5105__sandhikharka/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5106')"><td class="rname" data-area="610.41" data-density="61.747" data-wd="Q104863134" data-wiki="Sitganga" id="i5106"><a href="javascript:sym('5106')"><span itemprop="name">Shitaganga</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Śitagaṅgā</span></td><td class="rnative"><span itemprop="name">शितगंगा नगरपालिका</span></td><td class="rpop">44,679</td><td class="rpop">43,401</td><td class="rpop">37,691</td><td class="sc"><a href="/en/nepal/mun/admin/arghakhanchi/5106__shitaganga/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin1">
#  <tr class="rname" itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('45')"><td class="rname" data-area="1784" data-density="139.6923" data-wd="Q28162" data-wiki="Baglung District" id="i45"><a href="javascript:sym('45')"><span itemprop="name">Baglung</span></a></td><td class="rstatus">District</td><td class="rnative"><span itemprop="name">Bāgaluṅa</span></td><td class="rnative"><span itemprop="name">बागलुङ जिल्ला</span></td><td class="rpop">268,937</td><td class="rpop">268,613</td><td class="rpop">249,211</td><td class="sc"><a href="/en/nepal/mun/admin/45__baglung/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin2">
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4501')"><td class="rname" data-area="178.68" data-density="161.4003" data-wd="Q97175896" data-wiki="Badigad Rural Municipality" id="i4501"><a href="javascript:sym('4501')"><span itemprop="name">Badigad</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Vaḍigāḍa</span></td><td class="rnative"><span itemprop="name">वडिगाड गाउँपालिका</span></td><td class="rpop">29,618</td><td class="rpop">30,906</td><td class="rpop">28,839</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4501__badigad/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4502')"><td class="rname" data-area="98.905" data-density="567.2312" data-wd="Q1659597" data-wiki="Baglung" id="i4502"><a href="javascript:sym('4502')"><span itemprop="name">Baglung</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Bāgaluṅa</span></td><td class="rnative"><span itemprop="name">बागलुङ नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">59,192</td><td class="rpop">56,102</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4502__baglung/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4503')"><td class="rname" data-area="75.284" data-density="148.2121" data-wd="Q97175930" data-wiki="Bareng Rural Municipality" id="i4503"><a href="javascript:sym('4503')"><span itemprop="name">Bareng</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Varēṅa</span></td><td class="rnative"><span itemprop="name">वरेङ गाउँपालिका</span></td><td class="rpop">16,678</td><td class="rpop">14,511</td><td class="rpop">11,158</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4503__bareng/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4504')"><td class="rname" data-area="222.85" data-density="134.9248" data-wd="Q5269781" data-wiki="Dhorpatan" id="i4504"><a href="javascript:sym('4504')"><span itemprop="name">Dhorpatan</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Ḍhōrapāṭana</span></td><td class="rnative"><span itemprop="name">ढोरपाटन नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">26,438</td><td class="rpop">30,068</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4504__dhorpatan/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4599')"><td class="rname" data-area="312.13" data-wd="Q5269784" data-wiki="Dhorpatan Hunting Reserve" id="i4599"><a href="javascript:sym('4599')"><span itemprop="name">Dhorpatan Hunting Reserve</span></a></td><td class="rstatus">Hunting Reserve</td><td class="rnative"><span itemprop="name">Ḍhōrapāṭana Śikāra Ārakṣa</span></td><td class="rnative"><span itemprop="name">ढोरपाटन शिकार आरक्ष</span></td><td class="rpop">0</td><td class="rpop">0</td><td class="rpop">0</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4599__dhorpatan_hunting_reserve/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4505')"><td class="rname" data-area="194.39" data-density="157.3538" data-wd="Q25110677" data-wiki="Galkot" id="i4505"><a href="javascript:sym('4505')"><span itemprop="name">Galkot</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Galkōṭa</span></td><td class="rnative"><span itemprop="name">गल्कोट नगरपालिका</span></td><td class="rpop">35,893</td><td class="rpop">33,330</td><td class="rpop">30,588</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4505__galkot/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4506')"><td class="rname" data-area="118.71" data-density="207.4636" data-wd="Q97176332" data-wiki="Jaimini Municipality" id="i4506"><a href="javascript:sym('4506')"><span itemprop="name">Jaimini</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Jaiminī</span></td><td class="rnative"><span itemprop="name">जैमिनी नगरपालिका</span></td><td class="rpop">36,392</td><td class="rpop">32,069</td><td class="rpop">24,628</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4506__jaimini/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4507')"><td class="rname" data-area="82.881" data-density="271.7873" data-wd="Q33094981" data-wiki="Khathekhola Rural Municipality" id="i4507"><a href="javascript:sym('4507')"><span itemprop="name">Kathekhola</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Kāṭhēkhōlā</span></td><td class="rnative"><span itemprop="name">काठेखोला गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">26,174</td><td class="rpop">22,526</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4507__kathekhola/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4508')"><td class="rname" data-area="244.37" data-density="94.6065" data-wd="Q33097194" data-wiki="Nisikhola Rural Municipality" id="i4508"><a href="javascript:sym('4508')"><span itemprop="name">Nisikhola</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Nisīkhōlā</span></td><td class="rnative"><span itemprop="name">निसीखोला गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">23,325</td><td class="rpop">23,119</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4508__nisikhola/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4509')"><td class="rname" data-area="178.02" data-density="56.0724" data-wd="Q33096141" data-wiki="Taman Khola Rural Municipality" id="i4509"><a href="javascript:sym('4509')"><span itemprop="name">Taman Khola</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Tamānakhōlā</span></td><td class="rnative"><span itemprop="name">तमानखोला गाउँपालिका</span></td><td class="rpop">11,103</td><td class="rpop">10,659</td><td class="rpop">9,982</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4509__taman_khola/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('4510')"><td class="rname" data-area="129.53" data-density="78.1286" data-wd="Q33096718" data-wiki="Tara Khola Rural Municipality" id="i4510"><a href="javascript:sym('4510')"><span itemprop="name">Tara Khola</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Tārākhōlā</span></td><td class="rnative"><span itemprop="name">ताराखोला गाउँपालिका</span></td><td class="rpop">12,754</td><td class="rpop">12,009</td><td class="rpop">10,120</td><td class="sc"><a href="/en/nepal/mun/admin/baglung/4510__tara_khola/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin1">
#  <tr class="rname" itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('74')"><td class="rname" data-area="1519" data-density="159.4187" data-wd="Q28076" data-wiki="Baitadi District" id="i74"><a href="javascript:sym('74')"><span itemprop="name">Baitadi</span></a></td><td class="rstatus">District</td><td class="rnative"><span itemprop="name">Baitaḍī</span></td><td class="rnative"><span itemprop="name">बैतडी जिल्ला</span></td><td class="rpop">234,418</td><td class="rpop">250,898</td><td class="rpop">242,157</td><td class="sc"><a href="/en/nepal/mun/admin/74__baitadi/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin2">
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7401')"><td class="rname" data-area="135.15" data-density="233.5701" data-wd="Q1564243" data-wiki="Dasharathchand" id="i7401"><a href="javascript:sym('7401')"><span itemprop="name">Dasharathchand</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Daśarathacanda</span></td><td class="rnative"><span itemprop="name">दशरथचन्द नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">35,211</td><td class="rpop">31,567</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7401__dasharathchand/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7402')"><td class="rname" data-area="125.27" data-density="183.332" data-wd="Q97167778" data-wiki="Dilashaini Rural Municipality" id="i7402"><a href="javascript:sym('7402')"><span itemprop="name">Dilashaini</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Ḍilāśainī</span></td><td class="rnative"><span itemprop="name">डिलाशैनी गाउँपालिका</span></td><td class="rpop">21,198</td><td class="rpop">22,924</td><td class="rpop">22,966</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7402__dilashaini/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7403')"><td class="rname" data-area="126.38" data-density="182.8137" data-wd="Q97167787" data-wiki="Dogdakedar Rural Municipality" id="i7403"><a href="javascript:sym('7403')"><span itemprop="name">Dogdakedar</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Dōgaḍākēdāra</span></td><td class="rnative"><span itemprop="name">दोगडाकेदार गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">24,632</td><td class="rpop">23,104</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7403__dogdakedar/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7404')"><td class="rname" data-area="119.7" data-density="172.5815" data-wd="Q3414856" data-wiki="Melauli" id="i7404"><a href="javascript:sym('7404')"><span itemprop="name">Melauli</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Mēlaulī</span></td><td class="rnative"><span itemprop="name">मेलौली नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">22,545</td><td class="rpop">20,658</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7404__melauli/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7405')"><td class="rname" data-area="120.41" data-density="147.795" data-wd="Q97168679" data-wiki="Pancheshwar Rural Municipality" id="i7405"><a href="javascript:sym('7405')"><span itemprop="name">Pancheshwar</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Pañcēśvara</span></td><td class="rnative"><span itemprop="name">पञ्चेश्वर गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">18,766</td><td class="rpop">17,796</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7405__pancheshwar/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7406')"><td class="rname" data-area="219.26" data-density="133.312" data-wd="Q6628057" data-wiki="Patan, Baitadi" id="i7406"><a href="javascript:sym('7406')"><span itemprop="name">Patan</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Pāṭana</span></td><td class="rnative"><span itemprop="name">पाटन नगरपालिका</span></td><td class="rpop">29,250</td><td class="rpop">30,456</td><td class="rpop">29,230</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7406__patan/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7407')"><td class="rname" data-area="198.52" data-density="192.832" data-wd="Q85795056" data-wiki="Purchaudi" id="i7407"><a href="javascript:sym('7407')"><span itemprop="name">Purchaudi</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Purcauḍī</span></td><td class="rnative"><span itemprop="name">पुर्चौडी नगरपालिका</span></td><td class="rpop">34,374</td><td class="rpop">39,190</td><td class="rpop">38,281</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7407__purchaudi/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7408')"><td class="rname" data-area="81.654" data-density="221.2261" data-wd="Q97160493" data-wiki="Shivanath Rural Municipality" id="i7408"><a href="javascript:sym('7408')"><span itemprop="name">Shivanath</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Śivanātha</span></td><td class="rnative"><span itemprop="name">शिवनाथ गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">17,115</td><td class="rpop">18,064</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7408__shivanath/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7409')"><td class="rname" data-area="245.44" data-density="88.8771" data-wd="Q97169178" data-wiki="Sigas Rural Municipality" id="i7409"><a href="javascript:sym('7409')"><span itemprop="name">Sigas</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Sigāsa</span></td><td class="rnative"><span itemprop="name">सिगास गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">21,510</td><td class="rpop">21,814</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7409__sigas/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('7410')"><td class="rname" data-area="124.52" data-density="144.1134" data-wd="Q97160603" data-wiki="Surnaya Rural Municipality" id="i7410"><a href="javascript:sym('7410')"><span itemprop="name">Surnaya</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Surnayā</span></td><td class="rnative"><span itemprop="name">सुर्नया गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">18,549</td><td class="rpop">17,945</td><td class="sc"><a href="/en/nepal/mun/admin/baitadi/7410__surnaya/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin1">
#  <tr class="rname" itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('68')"><td class="rname" data-area="3422" data-density="55.2557" data-wd="Q28592" data-wiki="Bajhang District" id="i68"><a href="javascript:sym('68')"><span itemprop="name">Bajhang</span></a></td><td class="rstatus">District</td><td class="rnative"><span itemprop="name">Bajhāṅa</span></td><td class="rnative"><span itemprop="name">बझाङ जिल्ला</span></td><td class="rpop">167,026</td><td class="rpop">195,159</td><td class="rpop">189,085</td><td class="sc"><a href="/en/nepal/mun/admin/68__bajhang/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin2">
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6801')"><td class="rname" data-area="86.148" data-density="206.7605" data-wd="Q97159457" data-wiki="Bitthadchir Rural Municipality" id="i6801"><a href="javascript:sym('6801')"><span itemprop="name">Bitthadchir</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Vitthaḍacira</span></td><td class="rnative"><span itemprop="name">वित्थडचिर गाउँपालिका</span></td><td class="rpop">14,164</td><td class="rpop">17,163</td><td class="rpop">17,812</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6801__bitthadchir/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6802')"><td class="rname" data-area="447.58" data-density="75.544" data-wd="Q85749520" data-wiki="Bungal Municipality" id="i6802"><a href="javascript:sym('6802')"><span itemprop="name">Bungal</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Buṅgala</span></td><td class="rnative"><span itemprop="name">बुंगल नगरपालिका</span></td><td class="rpop">27,284</td><td class="rpop">33,224</td><td class="rpop">33,812</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6802__bungal/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6803')"><td class="rname" data-area="116.34" data-density="124.4112" data-wd="Q97159466" data-wiki="Chhabis Pathibhera Rural Municipality" id="i6803"><a href="javascript:sym('6803')"><span itemprop="name">Chhabispathibhera</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Chabisapāthibhērā</span></td><td class="rnative"><span itemprop="name">छबिसपाथिभेरा गाउँपालिका</span></td><td class="rpop">14,569</td><td class="rpop">16,296</td><td class="rpop">14,474</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6803__chhabispathibhera/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6804')"><td class="rname" data-area="61.834" data-density="183.0385" data-wd="Q97159479" data-wiki="Durgathali Rural Municipality" id="i6804"><a href="javascript:sym('6804')"><span itemprop="name">Durgathali</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Durgāthalī</span></td><td class="rnative"><span itemprop="name">दुर्गाथली गाउँपालिका</span></td><td class="rpop">12,022</td><td class="rpop">12,980</td><td class="rpop">11,318</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6804__durgathali/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6805')"><td class="rname" data-area="166.79" data-density="131.5007" data-wd="Q17870386" data-wiki="Jayaprithvi" id="i6805"><a href="javascript:sym('6805')"><span itemprop="name">Jaya Prithvi</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Jayapr̥thvī</span></td><td class="rnative"><span itemprop="name">जयपृथ्वी नगरपालिका</span></td><td class="rpop">19,093</td><td class="rpop">22,553</td><td class="rpop">21,933</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6805__jaya_prithvi/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6807')"><td class="rname" data-area="113.91" data-density="187.0951" data-wd="Q97159736" data-wiki="Kedarsyu Rural Municipality" id="i6807"><a href="javascript:sym('6807')"><span itemprop="name">Kedarsyu</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Kēdārasyũ</span></td><td class="rnative"><span itemprop="name">केदारस्युँ गाउँपालिका</span></td><td class="rpop">18,490</td><td class="rpop">21,316</td><td class="rpop">21,312</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6807__kedarsyu/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6808')"><td class="rname" data-area="113.52" data-density="118.2082" data-wd="Q97159467" data-wiki="Khaptadchhanna Rural Municipality" id="i6808"><a href="javascript:sym('6808')"><span itemprop="name">Khaptadchhanna</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Khaptaḍachānnā</span></td><td class="rnative"><span itemprop="name">खप्तडछान्ना गाउँपालिका</span></td><td class="rpop">15,715</td><td class="rpop">15,903</td><td class="rpop">13,419</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6808__khaptadchhanna/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6899')"><td class="rname" data-area="70.111" data-wd="Q2625399" data-wiki="Khaptad National Park" id="i6899"><a href="javascript:sym('6899')"><span itemprop="name">Khaptad National Park</span></a></td><td class="rstatus">National Park</td><td class="rnative"><span itemprop="name">Khaptaḍa Rāṣṭriya Nikuñja</span></td><td class="rnative"><span itemprop="name">खप्तड राष्ट्रिय निकुञ्ज</span></td><td class="rpop">0</td><td class="rpop">0</td><td class="rpop">0</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6899__khaptad_national_park/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6809')"><td class="rname" data-area="109.24" data-density="121.4299" data-wd="Q97160022" data-wiki="Masta Rural Municipality" id="i6809"><a href="javascript:sym('6809')"><span itemprop="name">Masta</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Maṣṭā</span></td><td class="rnative"><span itemprop="name">मष्टा गाउँपालिका</span></td><td class="rpop">12,114</td><td class="rpop">14,951</td><td class="rpop">13,265</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6809__masta/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6806')"><td class="rname" data-area="1467.3" data-density="1.789" data-wd="Q97160472" data-wiki="Saipal Rural Municipality" id="i6806"><a href="javascript:sym('6806')"><span itemprop="name">Saipal</span></a> [<span itemprop="name">Kanda</span>]</td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Sāipāla</span></td><td class="rnative"><span itemprop="name">साइपाल गाउँपालिका</span></td><td class="rpop">1,715</td><td class="rpop">2,193</td><td class="rpop">2,625</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6806__saipal/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6810')"><td class="rname" data-area="270.8" data-density="40.9232" data-wd="Q97160592" data-wiki="Surma Rural Municipality" id="i6810"><a href="javascript:sym('6810')"><span itemprop="name">Surma</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Sūrmā</span></td><td class="rnative"><span itemprop="name">सूर्मा गाउँपालिका</span></td><td class="rpop">6,523</td><td class="rpop">9,033</td><td class="rpop">11,082</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6810__surma/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6811')"><td class="rname" data-area="335.26" data-density="34.955" data-wd="Q97160669" data-wiki="Talkot Rural Municipality" id="i6811"><a href="javascript:sym('6811')"><span itemprop="name">Talkot</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Talakōṭa</span></td><td class="rnative"><span itemprop="name">तलकोट गाउँपालिका</span></td><td class="rpop">9,130</td><td class="rpop">11,569</td><td class="rpop">11,719</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6811__talkot/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6812')"><td class="rname" data-area="105.51" data-density="151.2463" data-wd="Q97160692" data-wiki="Thalara Rural Municipality" id="i6812"><a href="javascript:sym('6812')"><span itemprop="name">Thalara</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Thalārā</span></td><td class="rnative"><span itemprop="name">थलारा गाउँपालिका</span></td><td class="rpop">16,028</td><td class="rpop">17,978</td><td class="rpop">15,958</td><td class="sc"><a href="/en/nepal/mun/admin/bajhang/6812__thalara/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin1">
#  <tr class="rname" itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('67')"><td class="rname" data-area="2188" data-density="63.3103" data-wd="Q28071" data-wiki="Bajura District" id="i67"><a href="javascript:sym('67')"><span itemprop="name">Bajura</span></a></td><td class="rstatus">District</td><td class="rnative"><span itemprop="name">Bājurā</span></td><td class="rnative"><span itemprop="name">बाजुरा जिल्ला</span></td><td class="rpop">108,781</td><td class="rpop">134,912</td><td class="rpop">138,523</td><td class="sc"><a href="/en/nepal/mun/admin/67__bajura/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin2">
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6701')"><td class="rname" data-area="276" data-density="66.7174" data-wd="Q20822699" data-wiki="Badimalika" id="i6701"><a href="javascript:sym('6701')"><span itemprop="name">Badimalika</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Baḍīmālikā</span></td><td class="rnative"><span itemprop="name">बडीमालिका नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">17,259</td><td class="rpop">18,414</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6701__badimalika/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6702')"><td class="rname" data-area="59.196" data-density="340.9859" data-wd="Q3414084" data-wiki="Budhiganga" id="i6702"><a href="javascript:sym('6702')"><span itemprop="name">Budhiganga</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Buḍhīgaṅgā</span></td><td class="rnative"><span itemprop="name">बुढीगंगा नगरपालिका</span></td><td class="rpop">18,697</td><td class="rpop">21,700</td><td class="rpop">20,185</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6702__budhiganga/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6703')"><td class="rname" data-area="232.48" data-density="86.3386" data-wd="Q85749365" data-wiki="Budhinanda" id="i6703"><a href="javascript:sym('6703')"><span itemprop="name">Budhinanda</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Buḍhīnandā</span></td><td class="rnative"><span itemprop="name">बुढीनन्दा नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">18,883</td><td class="rpop">20,072</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6703__budhinanda/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6704')"><td class="rname" data-area="127.52" data-density="151.4037" data-wd="Q85751855" data-wiki="Chhededaha Rural Municipality" id="i6704"><a href="javascript:sym('6704')"><span itemprop="name">Chhededaha</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Chēḍēdaha</span></td><td class="rnative"><span itemprop="name">छेडेदह गाउँपालिका</span></td><td class="rpop">15,812</td><td class="rpop">18,741</td><td class="rpop">19,307</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6704__chhededaha/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6705')"><td class="rname" data-area="314.66" data-density="28.3258" data-wd="Q85762841" data-wiki="Gaumul Rural Municipality" id="i6705"><a href="javascript:sym('6705')"><span itemprop="name">Gaumul</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Gaumula</span></td><td class="rnative"><span itemprop="name">गौमुल गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">8,515</td><td class="rpop">8,913</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6705__gaumul/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6706')"><td class="rname" data-area="830.33" data-density="12.4155" data-wd="Q65410742" data-wiki="Himali Rural Municipality" id="i6706"><a href="javascript:sym('6706')"><span itemprop="name">Himali</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Himālī</span></td><td class="rnative"><span itemprop="name">हिमाली गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">9,229</td><td class="rpop">10,309</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6706__himali/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6707')"><td class="rname" data-area="171.72" data-density="59.1544" data-wd="Q97671542" data-wiki="Jagannath Rural Municipality" id="i6707"><a href="javascript:sym('6707')"><span itemprop="name">Jagannath</span></a> [<span itemprop="name">Pandav Gupha</span>]</td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Jagannātha</span></td><td class="rnative"><span itemprop="name">जगन्‍नाथ गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">9,432</td><td class="rpop">10,158</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6707__jagannath/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6799')"><td class="rname" data-area="7.5616" data-wd="Q2625399" data-wiki="Khaptad National Park" id="i6799"><a href="javascript:sym('6799')"><span itemprop="name">Khaptad National Park</span></a></td><td class="rstatus">National Park</td><td class="rnative"><span itemprop="name">Khaptaḍa Rāṣṭriya Nikuñja</span></td><td class="rnative"><span itemprop="name">खप्तड राष्ट्रिय निकुञ्ज</span></td><td class="rpop">0</td><td class="rpop">0</td><td class="rpop">0</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6799__khaptad_national_park/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6708')"><td class="rname" data-area="110.55" data-density="113.7585" data-wd="Q97671592" data-wiki="Swamikartik Khapar Rural Municipality" id="i6708"><a href="javascript:sym('6708')"><span itemprop="name">Swamikartik Khapar</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Svāmīkārtika Khāpara</span></td><td class="rnative"><span itemprop="name">स्वामीकार्तिक खापर गाउँपालिका</span></td><td class="rpop">10,889</td><td class="rpop">12,790</td><td class="rpop">12,576</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6708__swamikartik_khapar/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('6709')"><td class="rname" data-area="170.32" data-density="104.4974" data-wd="Q85810758" data-wiki="Triveni, Bajura" id="i6709"><a href="javascript:sym('6709')"><span itemprop="name">Triveni</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Trivēṇī</span></td><td class="rnative"><span itemprop="name">त्रिवेणी नगरपालिका</span></td><td class="rpop">14,938</td><td class="rpop">18,363</td><td class="rpop">17,798</td><td class="sc"><a href="/en/nepal/mun/admin/bajura/6709__triveni/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin1">
#  <tr class="rname" itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('57')"><td class="rname" data-area="2337" data-density="258.1061" data-wd="Q28447" data-wiki="Banke District" id="i57"><a href="javascript:sym('57')"><span itemprop="name">Banke</span></a></td><td class="rstatus">District</td><td class="rnative"><span itemprop="name">Bā̃kē</span></td><td class="rnative"><span itemprop="name">बाँके जिल्ला</span></td><td class="rpop">385,840</td><td class="rpop">491,313</td><td class="rpop">603,194</td><td class="sc"><a href="/en/nepal/mun/admin/57__banke/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin2">
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5701')"><td class="rname" data-area="141.68" data-density="490.3444" data-wd="Q97167583" data-wiki="Baijanath Rural Municipality" id="i5701"><a href="javascript:sym('5701')"><span itemprop="name">Baijanath</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Baijanātha</span></td><td class="rnative"><span itemprop="name">बैजनाथ गाउँपालिका</span></td><td class="rpop">45,481</td><td class="rpop">54,987</td><td class="rpop">69,472</td><td class="sc"><a href="/en/nepal/mun/admin/banke/5701__baijanath/" itemprop="url">→</a></td></tr>
# ...
#  </tbody>
#  <tbody class="admin2">
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('1401')"><td class="rname" data-area="339.34" data-density="150.4185" data-wd="Q31767037" data-wiki="Belaka Municipality" id="i1401"><a href="javascript:sym('1401')"><span itemprop="name">Belaka</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Bēlakā</span></td><td class="rnative"><span itemprop="name">बेलका नगरपालिका</span></td><td class="rpop">38,727</td><td class="rpop">42,450</td><td class="rpop">51,043</td><td class="sc"><a href="/en/nepal/mun/admin/udayapur/1401__belaka/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('1402')"><td class="rname" data-area="283.78" data-density="188.9879" data-wd="Q31767035" data-wiki="Chaudandigadhi Municipality" id="i1402"><a href="javascript:sym('1402')"><span itemprop="name">Chaudandigadhi</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Caudaṇḍīgaḍhī</span></td><td class="rnative"><span itemprop="name">चौदण्डीगढी नगरपालिका</span></td><td class="rpop">45,023</td><td class="rpop">48,750</td><td class="rpop">53,631</td><td class="sc"><a href="/en/nepal/mun/admin/udayapur/1402__chaudandigadhi/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('1403')"><td class="rname" data-area="424.89" data-density="140.0527" data-wd="Q2001663" data-wiki="Katari Municipality" id="i1403"><a href="javascript:sym('1403')"><span itemprop="name">Katari</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Kaṭārī</span></td><td class="rnative"><span itemprop="name">कटारी नगरपालिका</span></td><td class="rpop">50,505</td><td class="rpop">56,545</td><td class="rpop">59,507</td><td class="sc"><a href="/en/nepal/mun/admin/udayapur/1403__katari/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('1499')"><td class="rname" data-area="5.3852" data-wd="Q6433109" data-wiki="Koshi Tappu Wildlife Reserve" id="i1499"><a href="javascript:sym('1499')"><span itemprop="name">Koshi Tappu Wildlife Reserve</span></a></td><td class="rstatus">Wildlife Reserve</td><td class="rnative"><span itemprop="name">Kōśī Ṭappu Vanyajantu Ārakṣa</span></td><td class="rnative"><span itemprop="name">कोशी टप्पु वन्यजन्तु आरक्ष</span></td><td class="rpop">0</td><td class="rpop">0</td><td class="rpop">0</td><td class="sc"><a href="/en/nepal/mun/admin/udayapur/1499__koshi_tappu_wildlife_rese/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('1405')"><td class="rname" data-area="106.8" data-density="90.721" data-wd="Q30317099" data-wiki="Limchungbung Rural Municipality" id="i1405"><a href="javascript:sym('1405')"><span itemprop="name">Limchungbung</span></a> [<span itemprop="name">Sunkoshi</span>]</td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Limcuṅbuṅa</span></td><td class="rnative"><span itemprop="name">लिम्चुङ्बुङ गाउँपालिका</span></td><td class="rpop">13,800</td><td class="rpop">11,992</td><td class="rpop">9,689</td><td class="sc"><a href="/en/nepal/mun/admin/udayapur/1405__limchungbung/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('1404')"><td class="rname" data-area="204.08" data-density="99.5884" data-wd="Q30301465" data-wiki="Rautamai Rural Municipality" id="i1404"><a href="javascript:sym('1404')"><span itemprop="name">Rautamai</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Rautāmāī</span></td><td class="rnative"><span itemprop="name">रौतामाई गाउँपालिका</span></td><td class="rpop">23,113</td><td class="rpop">23,481</td><td class="rpop">20,324</td><td class="sc"><a href="/en/nepal/mun/admin/udayapur/1404__rautamai/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('1406')"><td class="rname" data-area="119.11" data-density="112.0309" data-wd="Q30301455" data-wiki="Tapli Rural Municipality" id="i1406"><a href="javascript:sym('1406')"><span itemprop="name">Tapli</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Tāplī</span></td><td class="rnative"><span itemprop="name">ताप्ली गाउँपालिका</span></td><td class="rpop">14,643</td><td class="rpop">14,567</td><td class="rpop">13,344</td><td class="sc"><a href="/en/nepal/mun/admin/udayapur/1406__tapli/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('1407')"><td class="rname" data-area="547.44" data-density="187.6461" data-wd="Q1457919" data-wiki="Triyuga Municipality" id="i1407"><a href="javascript:sym('1407')"><span itemprop="name">Triyuga</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Triyugā</span></td><td class="rnative"><span itemprop="name">त्रियुगा नगरपालिका</span></td><td class="rpop">71,131</td><td class="rpop">88,967</td><td class="rpop">102,725</td><td class="sc"><a href="/en/nepal/mun/admin/udayapur/1407__triyuga/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('1408')"><td class="rname" data-area="269.51" data-density="107.3281" data-wd="Q30301446" data-wiki="Udayapurgadhi Rural Municipality" id="i1408"><a href="javascript:sym('1408')"><span itemprop="name">Udayapurgadhi</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Udayapuragaḍhī</span></td><td class="rnative"><span itemprop="name">उदयपुरगढी गाउँपालिका</span></td><td class="rpop">29,741</td><td class="rpop">30,780</td><td class="rpop">28,926</td><td class="sc"><a href="/en/nepal/mun/admin/udayapur/1408__udayapurgadhi/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin1">
#  <tr class="rname" itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('54')"><td class="rname" data-area="1217" data-density="137.009" data-wd="Q53018063" data-wiki="Western Rukum District" id="i54"><a href="javascript:sym('54')"><span itemprop="name">West Rukum</span></a></td><td class="rstatus">District</td><td class="rnative"><span itemprop="name">Paścima Rukuma</span></td><td class="rnative"><span itemprop="name">पश्चिम रुकुम जिल्ला</span></td><td class="rpop">140,387</td><td class="rpop">155,383</td><td class="rpop">166,740</td><td class="sc"><a href="/en/nepal/mun/admin/54__west_rukum/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin2">
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5401')"><td class="rname" data-area="560.34" data-density="64.0986" data-wd="Q3423389" data-wiki="Aathbiskot" id="i5401"><a href="javascript:sym('5401')"><span itemprop="name">Aathbiskot</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Āṭhavisakōṭa</span></td><td class="rnative"><span itemprop="name">आठविसकोट नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">33,624</td><td class="rpop">35,917</td><td class="sc"><a href="/en/nepal/mun/admin/west_rukum/5401__aathbiskot/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5402')"><td class="rname" data-area="190.4" data-density="110.4674" data-wd="Q96373122" data-wiki="Banphikot Rural Municipality" id="i5402"><a href="javascript:sym('5402')"><span itemprop="name">Banphikot</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Bā̃phikōṭa</span></td><td class="rnative"><span itemprop="name">बाँफिकोट गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">18,696</td><td class="rpop">21,033</td><td class="sc"><a href="/en/nepal/mun/admin/west_rukum/5402__banphikot/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5403')"><td class="rname" data-area="107.36" data-density="269.7094" data-wd="Q3412638" data-wiki="Chaurjahari" id="i5403"><a href="javascript:sym('5403')"><span itemprop="name">Chaurjahari</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Caurajahārī</span></td><td class="rnative"><span itemprop="name">चौरजहारी नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">27,583</td><td class="rpop">28,956</td><td class="sc"><a href="/en/nepal/mun/admin/west_rukum/5403__chaurjahari/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5404')"><td class="rname" data-area="162.69" data-density="210.646" data-wd="Q3420064" data-wiki="Musikot, Western Rukum" id="i5404"><a href="javascript:sym('5404')"><span itemprop="name">Musikot</span></a></td><td class="rstatus">Municipality</td><td class="rnative"><span itemprop="name">Musikōṭa</span></td><td class="rnative"><span itemprop="name">मुसिकोट नगरपालिका</span></td><td class="rpop">...</td><td class="rpop">33,882</td><td class="rpop">34,270</td><td class="sc"><a href="/en/nepal/mun/admin/west_rukum/5404__musikot/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5405')"><td class="rname" data-area="133.79" data-density="185.0587" data-wd="Q60765483" data-wiki="Sani Bheri Rural Municipality" id="i5405"><a href="javascript:sym('5405')"><span itemprop="name">Sani Bheri</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Sānī Bhērī</span></td><td class="rnative"><span itemprop="name">सानी भेरी गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">22,194</td><td class="rpop">24,759</td><td class="sc"><a href="/en/nepal/mun/admin/west_rukum/5405__sani_bheri/" itemprop="url">→</a></td></tr>
#  <tr itemscope="" itemtype="http://schema.org/AdministrativeArea" onclick="javascript:sym('5406')"><td class="rname" data-area="85.502" data-density="240.0529" data-wd="Q60766214" data-wiki="Triveni Rural Municipality, Western Rukum" id="i5406"><a href="javascript:sym('5406')"><span itemprop="name">Triveni</span></a></td><td class="rstatus">Rural Municipality</td><td class="rnative"><span itemprop="name">Trivēṇī</span></td><td class="rnative"><span itemprop="name">त्रिवेणी गाउँपालिका</span></td><td class="rpop">...</td><td class="rpop">19,404</td><td class="rpop">20,525</td><td class="sc"><a href="/en/nepal/mun/admin/west_rukum/5406__triveni/" itemprop="url">→</a></td></tr>
#  </tbody>
#  <tbody class="admin0">
#  <tr><td class="rname">Nepal</td><td class="rstatus">Federal Republic</td><td class="rnative"><span itemprop="name">Nēpāla</span></td><td class="rnative"><span itemprop="name">नेपाल</span></td><td class="rpop">23,151,423</td><td class="rpop">26,494,504</td><td class="rpop">29,164,578</td><td class="sc"></td></tr>
#  </tbody>
#  </table>,
#  <table class="data"><thead><tr><th colspan="2">Gender (C 2021)</th></tr></thead><tbody>
#  <tr onclick="setMapMode('gender',cp.maps.GENDER_MODE)"><td><a href="javascript:setMapMode('gender',cp.maps.GENDER_MODE)">Males</a></td><td class="rpop">14,253,551</td></tr>
#  <tr onclick="setMapMode('gender',cp.maps.GENDER_MODE)"><td><a href="javascript:setMapMode('gender',cp.maps.GENDER_MODE)">Females</a></td><td class="rpop">14,911,027</td></tr>
#  </tbody></table>,
#  <table class="data"><thead><tr><th colspan="2">Age Groups (C 2021)</th></tr></thead><tbody>
#  <tr onclick="setUserMode('T00_14',0)"><td><a href="javascript:setUserMode('T00_14',0)">0-14 years</a></td><td class="rpop">8,115,575</td></tr>
#  <tr onclick="setUserMode('T15_64',1)"><td><a href="javascript:setUserMode('T15_64',1)">15-64 years</a></td><td class="rpop">19,027,289</td></tr>
#  <tr onclick="setMapMode('oldage',cp.maps.OLDAGE_MODE)"><td><a href="javascript:setMapMode('oldage',cp.maps.OLDAGE_MODE)">65+ years</a></td><td class="rpop">2,021,714</td></tr>
#  </tbody></table>,
#  <table class="data"><thead><tr><th colspan="2">Age Distribution (C 2021)</th></tr></thead><tbody>
#  <tr onclick="setUserMode('T90_xx',0)"><td><a href="javascript:setUserMode('T90_xx',0)">90+ years</a></td><td class="rpop">47,640</td></tr>
#  <tr onclick="setUserMode('T80_89',0)"><td><a href="javascript:setUserMode('T80_89',0)">80-89 years</a></td><td class="rpop">239,883</td></tr>
#  <tr onclick="setUserMode('T70_79',0)"><td><a href="javascript:setUserMode('T70_79',0)">70-79 years</a></td><td class="rpop">962,573</td></tr>
#  <tr onclick="setUserMode('T60_69',0)"><td><a href="javascript:setUserMode('T60_69',0)">60-69 years</a></td><td class="rpop">1,727,222</td></tr>
#  <tr onclick="setUserMode('T50_59',0)"><td><a href="javascript:setUserMode('T50_59',0)">50-59 years</a></td><td class="rpop">2,489,796</td></tr>
#  <tr onclick="setUserMode('T40_49',0)"><td><a href="javascript:setUserMode('T40_49',0)">40-49 years</a></td><td class="rpop">3,183,872</td></tr>
#  <tr onclick="setUserMode('T30_39',0)"><td><a href="javascript:setUserMode('T30_39',0)">30-39 years</a></td><td class="rpop">4,189,204</td></tr>
#  <tr onclick="setUserMode('T20_29',0)"><td><a href="javascript:setUserMode('T20_29',0)">20-29 years</a></td><td class="rpop">5,242,409</td></tr>
#  <tr onclick="setUserMode('T10_19',0)"><td><a href="javascript:setUserMode('T10_19',0)">10-19 years</a></td><td class="rpop">5,876,269</td></tr>
#  <tr onclick="setUserMode('T00_09',0)"><td><a href="javascript:setUserMode('T00_09',0)">0-9 years</a></td><td class="rpop">5,205,710</td></tr>
#  </tbody></table>,
#  <table class="data"><thead><tr><th colspan="2">Citizenhip (C 2021)</th></tr></thead><tbody>
#  <tr onclick="setUserMode('N_NPL',0)"><td><a href="javascript:setUserMode('N_NPL',0)">Nepal</a></td><td class="rpop">29,027,171</td></tr>
#  <tr onclick="setUserMode('N_IND',1)"><td><a href="javascript:setUserMode('N_IND',1)">India</a></td><td class="rpop">132,781</td></tr>
#  <tr onclick="setUserMode('N_X',2)"><td><a href="javascript:setUserMode('N_X',2)">Other Citizenship</a></td><td class="rpop">4,437</td></tr>
#  </tbody></table>,
#  <table class="data"><thead><tr><th colspan="2">Place of Birth (C 2021)</th></tr></thead><tbody>
#  <tr onclick="setUserMode('B_LOC',0)"><td><a href="javascript:setUserMode('B_LOC',0)">Same local unit</a></td><td class="rpop">20,117,395</td></tr>
#  <tr onclick="setUserMode('B_DIS',1)"><td><a href="javascript:setUserMode('B_DIS',1)">Other local unit in same district</a></td><td class="rpop">2,612,713</td></tr>
#  <tr onclick="setUserMode('B_NPL',2)"><td><a href="javascript:setUserMode('B_NPL',2)">Other district</a></td><td class="rpop">5,690,225</td></tr>
#  <tr onclick="setUserMode('B_X',3)"><td><a href="javascript:setUserMode('B_X',3)">Other country</a></td><td class="rpop">734,663</td></tr>
#  </tbody></table>,
#  <table class="data"><thead><tr><th colspan="2">Literacy (A5+) (C 2021)</th></tr></thead><tbody>
#  <tr onclick="setMapMode('literacy',cp.maps.LITERACY_MODE)"><td><a href="javascript:setMapMode('literacy',cp.maps.LITERACY_MODE)">Yes</a></td><td class="rpop">20,377,980</td></tr>
#  <tr onclick="setMapMode('literacy',cp.maps.LITERACY_MODE)"><td><a href="javascript:setMapMode('literacy',cp.maps.LITERACY_MODE)">Only reading</a></td><td class="rpop">114,331</td></tr>
#  <tr onclick="setMapMode('literacy',cp.maps.LITERACY_MODE)"><td><a href="javascript:setMapMode('literacy',cp.maps.LITERACY_MODE)">No</a></td><td class="rpop">6,223,061</td></tr>
#  </tbody></table>]

# %% [markdown]
# #### Title of the table

# %%
table_title = soup.find_all('th')[:7]

# %%
table_title
# Out:
# [<th class="rname" data-coltype="name" onclick="javascript:sort('tl',0,false)"><a href="javascript:sort('tl',0,false)">Name</a></th>,
#  <th class="rstatus" data-coltype="status" onclick="javascript:sort('tl',1,false)"><a href="javascript:sort('tl',1,false)">Status</a></th>,
#  <th class="rnative" data-coltype="othername" onclick="javascript:sort('tl',2,false)"><a href="javascript:sort('tl',2,false)">Transcription</a></th>,
#  <th class="rnative" data-coltype="othername" onclick="javascript:sort('tl',3,false)"><a href="javascript:sort('tl',3,false)">Native</a></th>,
#  <th class="rpop" data-coldate="2001-05-28" data-colhead="C 2001-05-28" data-coltype="pop" onclick="javascript:sort('tl',4,true)"><a href="javascript:sort('tl',4,true)">Population</a><br/><span class="unit">Census<br/>2001-05-28</span></th>,
#  <th class="rpop" data-coldate="2011-06-22" data-colhead="C 2011-06-22" data-coltype="pop" onclick="javascript:sort('tl',5,true)"><a href="javascript:sort('tl',5,true)">Population</a><br/><span class="unit">Census<br/>2011-06-22</span></th>,
#  <th class="rpop" data-coldate="2021-11-25" data-colhead="C 2021-11-25" data-coltype="pop" onclick="javascript:sort('tl',6,true)"><a href="javascript:sort('tl',6,true)">Population</a><br/><span class="unit">Census<br/>2021-11-25</span></th>]

# %%
table_data = [title.text for title in table_title][0:7]
table_data
# Out:
# ['Name',
#  'Status',
#  'Transcription',
#  'Native',
#  'PopulationCensus2001-05-28',
#  'PopulationCensus2011-06-22',
#  'PopulationCensus2021-11-25']

# %%
df = pd.DataFrame(columns = table_data)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Name, Status, Transcription, Native, PopulationCensus2001-05-28, PopulationCensus2011-06-22, PopulationCensus2021-11-25]
# Index: []

# %% [markdown]
# ### District Informations

# %%
district_names_table = soup.find_all('tr', class_ = 'rname')
for dis_names in district_names_table:
    district_names = dis_names.find_all('td')[:7]
    individual_dis_names = [data.text for data in district_names]
    print(individual_dis_names)
    length = len(df)
    df.loc[length] = individual_dis_names
# Out:
# ['Achham', 'District', 'Achāma', 'अछाम जिल्ला', '231,285', '257,477', '228,852']
# ['Arghakhanchi', 'District', 'Arghākhā̃cī', 'अर्घाखाँची जिल्ला', '208,391', '197,632', '177,086']
# ['Baglung', 'District', 'Bāgaluṅa', 'बागलुङ जिल्ला', '268,937', '268,613', '249,211']
# ['Baitadi', 'District', 'Baitaḍī', 'बैतडी जिल्ला', '234,418', '250,898', '242,157']
# ['Bajhang', 'District', 'Bajhāṅa', 'बझाङ जिल्ला', '167,026', '195,159', '189,085']
# ['Bajura', 'District', 'Bājurā', 'बाजुरा जिल्ला', '108,781', '134,912', '138,523']
# ['Banke', 'District', 'Bā̃kē', 'बाँके जिल्ला', '385,840', '491,313', '603,194']
# ['Bara', 'District', 'Bārā', 'बारा जिल्ला', '559,135', '687,708', '763,137']
# ['Bardiya', 'District', 'Bardiyā', 'बर्दिया जिल्ला', '382,649', '426,576', '459,900']
# ['Bhaktapur', 'District', 'Bhaktapura', 'भक्तपुर जिल्ला', '225,461', '304,651', '432,132']
# ['Bhojpur', 'District', 'Bhōjapura', 'भोजपुर जिल्ला', '203,018', '182,459', '157,923']
# ['Chitwan', 'District', 'Citavana', 'चितवन जिल्ला', '472,048', '579,984', '719,859']
# ['Dadeldhura', 'District', 'Ḍaḍēladhurā', 'डडेलधुरा जिल्ला', '126,162', '142,094', '139,602']
# ['Dailekh', 'District', 'Dailēkha', 'दैलेख जिल्ला', '225,201', '261,770', '252,313']
# ['Dang Deukhuri', 'District', 'Dāṅa', 'दाङ जिल्ला', '462,380', '552,583', '674,993']
# ['Darchula', 'District', 'Dārculā', 'दार्चुला जिल्ला', '121,996', '133,274', '133,310']
# ['Dhading', 'District', 'Dhādiṅa', 'धादिङ जिल्ला', '338,658', '336,067', '325,710']
# ['Dhankuta', 'District', 'Dhanakuṭā', 'धनकुटा जिल्ला', '166,479', '163,412', '150,599']
# ['Dhanusa', 'District', 'Dhanuṣā', 'धनुषा जिल्ला', '671,364', '754,777', '867,747']
# ['Dolakha', 'District', 'Dōlakhā', 'दोलखा जिल्ला', '204,229', '186,557', '172,767']
# ['Dolpa', 'District', 'Ḍōlpā', 'डोल्पा जिल्ला', '29,545', '36,700', '42,774']
# ['Doti', 'District', 'Ḍōṭī', 'डोटी जिल्ला', '207,066', '211,746', '204,831']
# ['East Rukum', 'District', 'Purvī Rukuma', 'पुर्वी रुकुम जिल्ला', '48,051', '53,184', '56,786']
# ['Gorkha', 'District', 'Gōrakhā', 'गोरखा जिल्ला', '288,134', '271,061', '251,027']
# ['Gulmi', 'District', 'Gulmī', 'गुल्मी जिल्ला', '296,654', '280,160', '246,494']
# ['Humla', 'District', 'Humlā', 'हुम्ला जिल्ला', '40,595', '50,858', '55,394']
# ['Ilam', 'District', 'Ilāma', 'इलाम जिल्ला', '282,806', '290,254', '279,534']
# ['Jajarkot', 'District', 'Jājarakōṭa', 'जाजरकोट जिल्ला', '134,868', '171,304', '189,360']
# ['Jhapa', 'District', 'Jhāpā', 'झापा जिल्ला', '688,109', '812,650', '998,054']
# ['Jumla', 'District', 'Jumlā', 'जुम्ला जिल्ला', '89,427', '108,921', '118,349']
# ['Kailali', 'District', 'Kailālī', 'कैलाली जिल्ला', '616,697', '775,709', '904,666']
# ['Kalikot', 'District', 'Kālikōṭa', 'कालिकोट जिल्ला', '105,580', '136,948', '145,292']
# ['Kanchanpur [Dodhara Chandani]', 'District', 'Kañcanapura', 'कञ्\u200dचनपुर जिल्ला', '377,899', '451,248', '513,757']
# ['Kapilvastu', 'District', 'Kapilavastu', 'कपिलवस्तु जिल्ला', '481,976', '571,936', '682,961']
# ['Kaski', 'District', 'Kāskī', 'कास्की जिल्ला', '380,527', '492,098', '600,051']
# ['Kathmandu', 'District', 'Kāṭhamāḍaũ', 'काठमाडौँ जिल्ला', '1,081,845', '1,744,240', '2,041,587']
# ['Kavrepalanchok', 'District', 'Kābhrēpalāñcōka', 'काभ्रेपलाञ्चोक जिल्ला', '385,672', '381,937', '364,039']
# ['Khotang', 'District', 'Khōṭāṅa', 'खोटाङ जिल्ला', '231,385', '206,312', '175,298']
# ['Lalitpur', 'District', 'Lalitapura', 'ललितपुर जिल्ला', '337,785', '468,132', '551,667']
# ['Lamjung', 'District', 'Lamajuṅa', 'लमजुङ जिल्ला', '177,149', '167,724', '155,852']
# ['Mahottari', 'District', 'Mahōttarī', 'महोत्तरी जिल्ला', '553,481', '627,580', '706,994']
# ['Makwanpur', 'District', 'Makavānapura', 'मकवानपुर जिल्ला', '392,604', '420,477', '466,073']
# ['Manang', 'District', 'Manāṅa', 'मनाङ जिल्ला', '9,587', '6,538', '5,658']
# ['Morang', 'District', 'Mōraṅa', 'मोरङ जिल्ला', '843,220', '965,370', '1,148,156']
# ['Mugu', 'District', 'Mugu', 'मुगु जिल्ला', '43,937', '55,286', '64,549']
# ['Mustang', 'District', 'Mustāṅa', 'मुस्ताङ जिल्ला', '14,981', '13,452', '14,452']
# ['Myagdi', 'District', 'Myāgdī', 'म्याग्दी जिल्ला', '114,447', '113,641', '107,033']
# ['Nawalpur [Nawalparasi East]', 'District', 'Navalapura', 'नवलपुर जिल्ला', '272,557', '311,604', '378,079']
# ['Nuwakot', 'District', 'Nuvākōṭa', 'नुवाकोट जिल्ला', '288,478', '277,471', '263,391']
# ['Okhaldhunga', 'District', 'Ōkhalaḍhuṅgā', 'ओखलढुङ्गा जिल्ला', '156,702', '147,984', '139,552']
# ['Palpa', 'District', 'Pālpā', 'पाल्पा जिल्ला', '268,558', '261,180', '245,027']
# ['Panchthar', 'District', 'Pā̃cathara', 'पाँचथर जिल्ला', '202,056', '191,817', '172,400']
# ['Parasi [Nawalparasi West]', 'District', 'Parāsī', 'परासी जिल्ला', '290,313', '331,904', '386,868']
# ['Parbat', 'District', 'Parvata', 'पर्वत जिल्ला', '157,826', '146,590', '130,887']
# ['Parsa', 'District', 'Parsā', 'पर्सा जिल्ला', '497,219', '601,017', '654,471']
# ['Pyuthan', 'District', 'Pyuṭhāna', 'प्युठान जिल्ला', '212,484', '228,102', '232,019']
# ['Ramechhap', 'District', 'Rāmēchāpa', 'रामेछाप जिल्ला', '212,408', '202,646', '170,302']
# ['Rasuwa', 'District', 'Rasuvā', 'रसुवा जिल्ला', '44,731', '43,300', '46,689']
# ['Rautahat', 'District', 'Rautahaṭa', 'रौतहट जिल्ला', '545,132', '686,722', '813,573']
# ['Rolpa', 'District', 'Rōlpā', 'रोल्पा जिल्ला', '210,004', '224,506', '234,793']
# ['Rupandehi', 'District', 'Rupandēhī', 'रुपन्देही जिल्ला', '708,419', '880,196', '1,121,957']
# ['Salyan', 'District', 'Salyāna', 'सल्यान जिल्ला', '213,500', '242,444', '238,515']
# ['Sankhuwasabha', 'District', 'Saṅkhuvāsabhā', 'संखुवासभा जिल्ला', '159,203', '158,742', '158,041']
# ['Saptari', 'District', 'Saptarī', 'सप्तरी जिल्ला', '570,282', '639,284', '706,255']
# ['Sarlahi', 'District', 'Sarlāhī', 'सर्लाही जिल्ला', '635,701', '769,729', '862,470']
# ['Sindhuli', 'District', 'Sindhulī', 'सिन्धुली जिल्ला', '279,821', '296,192', '300,026']
# ['Sindhupalchowk', 'District', 'Sindhupālcōka', 'सिन्धुपाल्चोक जिल्ला', '305,857', '287,798', '262,624']
# ['Siraha', 'District', 'Sirāhā', 'सिराहा जिल्ला', '572,399', '637,328', '739,953']
# ['Solukhumbu', 'District', 'Sōlukhumbu', 'सोलुखुम्बु जिल्ला', '107,686', '105,886', '104,851']
# ['Sunsari', 'District', 'Sunasarī', 'सुनसरी जिल्ला', '625,633', '763,487', '926,962']
# ['Surkhet', 'District', 'Surkhēta', 'सुर्खेत जिल्ला', '288,527', '350,804', '415,126']
# ['Syangja', 'District', 'Syāṅjā', 'स्याङ्जा जिल्ला', '317,320', '289,148', '253,024']
# ['Tanahun', 'District', 'Tanahũ', 'तनहुँ जिल्ला', '315,237', '323,288', '321,153']
# ['Taplejung', 'District', 'Tāplējuṅa', 'ताप्लेजुङ जिल्ला', '134,698', '127,461', '120,590']
# ['Tehrathum', 'District', 'Tēhrathuma', 'तेह्रथुम जिल्ला', '113,111', '101,577', '88,731']
# ['Udayapur', 'District', 'Udayapura', 'उदयपुर जिल्ला', '287,689', '317,532', '340,721']
# ['West Rukum', 'District', 'Paścima Rukuma', 'पश्चिम रुकुम जिल्ला', '140,387', '155,383', '166,740']

# %%
df
# Out:
#             Name    Status   Transcription               Native  \
# 0         Achham  District          Achāma          अछाम जिल्ला
# 1   Arghakhanchi  District     Arghākhā̃cī    अर्घाखाँची जिल्ला
# 2        Baglung  District        Bāgaluṅa        बागलुङ जिल्ला
# 3        Baitadi  District         Baitaḍī         बैतडी जिल्ला
# 4        Bajhang  District         Bajhāṅa          बझाङ जिल्ला
# ..           ...       ...             ...                  ...
# 72       Tanahun  District          Tanahũ         तनहुँ जिल्ला
# 73     Taplejung  District       Tāplējuṅa     ताप्लेजुङ जिल्ला
# 74     Tehrathum  District      Tēhrathuma      तेह्रथुम जिल्ला
# 75      Udayapur  District       Udayapura        उदयपुर जिल्ला
# 76    West Rukum  District  Paścima Rukuma  पश्चिम रुकुम जिल्ला
#
#    PopulationCensus2001-05-28 PopulationCensus2011-06-22  \
# 0                     231,285                    257,477
# 1                     208,391                    197,632
# 2                     268,937                    268,613
# 3                     234,418                    250,898
# 4                     167,026                    195,159
# ..                        ...                        ...
# 72                    315,237                    323,288
# 73                    134,698                    127,461
# 74                    113,111                    101,577
# 75                    287,689                    317,532
# 76                    140,387                    155,383
#
#    PopulationCensus2021-11-25
# 0                     228,852
# 1                     177,086
# 2                     249,211
# 3                     242,157
# 4                     189,085
# ..                        ...
# 72                    321,153
# 73                    120,590
# 74                     88,731
# 75                    340,721
# 76                    166,740
#
# [77 rows x 7 columns]

# %% [markdown]
# ### Scraping the municipalities from the table

# %%
admin2_data = soup.find_all('tbody', class_ = 'admin2')
for admin2 in admin2_data:
    municipality_data = admin2.find_all('tr')
    for names in municipality_data:
        municipality_rows = names.find_all('td')
        municipality_names = [data.text for data in municipality_rows][:7]
        print(municipality_names)
        length = len(df)
        df.loc[length] = municipality_names
        
        
        
    # print(x_data)
# Out:
# ['Bannigadhi Jaygadh', 'Rural Municipality', 'Bānnigaḍhī Jayagaḍha', 'बान्निगढी जयगढ गाउँपालिका', '17,102', '17,426', '13,519']
# ['Chaurpati', 'Rural Municipality', 'Caurapāṭī', 'चौरपाटी गाउँपालिका', '23,323', '25,215', '21,681']
# ['Dhakari', 'Rural Municipality', 'Ḍhakārī', 'ढकारी गाउँपालिका', '...', '21,570', '21,998']
# ['Kamalbazar', 'Municipality', 'Kamalabajāra', 'कमलबजार नगरपालिका', '...', '23,770', '21,032']
# ['Khaptad National Park', 'National Park', 'Khaptaḍa Rāṣṭriya Nikuñja', 'खप्तड राष्ट्रिय निकुञ्ज', '0', '0', '0']
# ['Mangalsen', 'Municipality', 'Maṅgalasēna', 'मंगलसेन नगरपालिका', '...', '33,191', '26,557']
# ['Mellekh', 'Rural Municipality', 'Mēllēkha', 'मेल्लेख गाउँपालिका', '21,219', '24,728', '22,785']
# ['Panchadewal Binayak', 'Municipality', 'Pañcadēvala Vināyaka', 'पञ्चदेवल विनायक नगरपालिका', '...', '27,495', '26,088']
# ['Ramaroshan', 'Rural Municipality', 'Rāmārōśana', 'रामारोशन गाउँपालिका', '20,749', '25,172', '23,600']
# ['Sanphebagar', 'Municipality', 'Sā̃phēbagara', 'साँफेबगर नगरपालिका', '...', '34,128', '25,891']
# ['Turmakhad', 'Rural Municipality', 'Turmākhā̃da', 'तुर्माखाँद गाउँपालिका', '21,520', '24,782', '24,574']
# ['Bhumikasthan', 'Municipality', 'Bhūmikāsthāna', 'भूमिकास्थान नगरपालिका', '35,250', '32,640', '28,192']
# ['Chhatradev', 'Rural Municipality', 'Chatradēva', 'छत्रदेव गाउँपालिका', '...', '25,343', '21,611']
# ['Malarani', 'Rural Municipality', 'Mālārānī', 'मालारानी गाउँपालिका', '...', '28,044', '24,150']
# ['Panini', 'Rural Municipality', 'Pāṇinī', 'पाणिनी गाउँपालिका', '...', '26,432', '22,291']
# ['Sandhikharka', 'Municipality', 'Sandhikharka', 'सन्धिखर्क नगरपालिका', '...', '41,772', '42,492']
# ['Shitaganga', 'Municipality', 'Śitagaṅgā', 'शितगंगा नगरपालिका', '44,679', '43,401', '37,691']
# ['Badigad', 'Rural Municipality', 'Vaḍigāḍa', 'वडिगाड गाउँपालिका', '29,618', '30,906', '28,839']
# ['Baglung', 'Municipality', 'Bāgaluṅa', 'बागलुङ नगरपालिका', '...', '59,192', '56,102']
# ['Bareng', 'Rural Municipality', 'Varēṅa', 'वरेङ गाउँपालिका', '16,678', '14,511', '11,158']
# ['Dhorpatan', 'Municipality', 'Ḍhōrapāṭana', 'ढोरपाटन नगरपालिका', '...', '26,438', '30,068']
# ['Dhorpatan Hunting Reserve', 'Hunting Reserve', 'Ḍhōrapāṭana Śikāra Ārakṣa', 'ढोरपाटन शिकार आरक्ष', '0', '0', '0']
# ['Galkot', 'Municipality', 'Galkōṭa', 'गल्कोट नगरपालिका', '35,893', '33,330', '30,588']
# ['Jaimini', 'Municipality', 'Jaiminī', 'जैमिनी नगरपालिका', '36,392', '32,069', '24,628']
# ['Kathekhola', 'Rural Municipality', 'Kāṭhēkhōlā', 'काठेखोला गाउँपालिका', '...', '26,174', '22,526']
# ['Nisikhola', 'Rural Municipality', 'Nisīkhōlā', 'निसीखोला गाउँपालिका', '...', '23,325', '23,119']
# ['Taman Khola', 'Rural Municipality', 'Tamānakhōlā', 'तमानखोला गाउँपालिका', '11,103', '10,659', '9,982']
# ['Tara Khola', 'Rural Municipality', 'Tārākhōlā', 'ताराखोला गाउँपालिका', '12,754', '12,009', '10,120']
# ['Dasharathchand', 'Municipality', 'Daśarathacanda', 'दशरथचन्द नगरपालिका', '...', '35,211', '31,567']
# ['Dilashaini', 'Rural Municipality', 'Ḍilāśainī', 'डिलाशैनी गाउँपालिका', '21,198', '22,924', '22,966']
# ['Dogdakedar', 'Rural Municipality', 'Dōgaḍākēdāra', 'दोगडाकेदार गाउँपालिका', '...', '24,632', '23,104']
# ['Melauli', 'Municipality', 'Mēlaulī', 'मेलौली नगरपालिका', '...', '22,545', '20,658']
# ['Pancheshwar', 'Rural Municipality', 'Pañcēśvara', 'पञ्चेश्वर गाउँपालिका', '...', '18,766', '17,796']
# ['Patan', 'Municipality', 'Pāṭana', 'पाटन नगरपालिका', '29,250', '30,456', '29,230']
# ['Purchaudi', 'Municipality', 'Purcauḍī', 'पुर्चौडी नगरपालिका', '34,374', '39,190', '38,281']
# ['Shivanath', 'Rural Municipality', 'Śivanātha', 'शिवनाथ गाउँपालिका', '...', '17,115', '18,064']
# ['Sigas', 'Rural Municipality', 'Sigāsa', 'सिगास गाउँपालिका', '...', '21,510', '21,814']
# ['Surnaya', 'Rural Municipality', 'Surnayā', 'सुर्नया गाउँपालिका', '...', '18,549', '17,945']
# ['Bitthadchir', 'Rural Municipality', 'Vitthaḍacira', 'वित्थडचिर गाउँपालिका', '14,164', '17,163', '17,812']
# ['Bungal', 'Municipality', 'Buṅgala', 'बुंगल नगरपालिका', '27,284', '33,224', '33,812']
# ['Chhabispathibhera', 'Rural Municipality', 'Chabisapāthibhērā', 'छबिसपाथिभेरा गाउँपालिका', '14,569', '16,296', '14,474']
# ['Durgathali', 'Rural Municipality', 'Durgāthalī', 'दुर्गाथली गाउँपालिका', '12,022', '12,980', '11,318']
# ['Jaya Prithvi', 'Municipality', 'Jayapr̥thvī', 'जयपृथ्वी नगरपालिका', '19,093', '22,553', '21,933']
# ['Kedarsyu', 'Rural Municipality', 'Kēdārasyũ', 'केदारस्युँ गाउँपालिका', '18,490', '21,316', '21,312']
# ['Khaptadchhanna', 'Rural Municipality', 'Khaptaḍachānnā', 'खप्तडछान्ना गाउँपालिका', '15,715', '15,903', '13,419']
# ['Khaptad National Park', 'National Park', 'Khaptaḍa Rāṣṭriya Nikuñja', 'खप्तड राष्ट्रिय निकुञ्ज', '0', '0', '0']
# ['Masta', 'Rural Municipality', 'Maṣṭā', 'मष्टा गाउँपालिका', '12,114', '14,951', '13,265']
# ['Saipal [Kanda]', 'Rural Municipality', 'Sāipāla', 'साइपाल गाउँपालिका', '1,715', '2,193', '2,625']
# ['Surma', 'Rural Municipality', 'Sūrmā', 'सूर्मा गाउँपालिका', '6,523', '9,033', '11,082']
# ['Talkot', 'Rural Municipality', 'Talakōṭa', 'तलकोट गाउँपालिका', '9,130', '11,569', '11,719']
# ['Thalara', 'Rural Municipality', 'Thalārā', 'थलारा गाउँपालिका', '16,028', '17,978', '15,958']
# ['Badimalika', 'Municipality', 'Baḍīmālikā', 'बडीमालिका नगरपालिका', '...', '17,259', '18,414']
# ['Budhiganga', 'Municipality', 'Buḍhīgaṅgā', 'बुढीगंगा नगरपालिका', '18,697', '21,700', '20,185']
# ['Budhinanda', 'Municipality', 'Buḍhīnandā', 'बुढीनन्दा नगरपालिका', '...', '18,883', '20,072']
# ['Chhededaha', 'Rural Municipality', 'Chēḍēdaha', 'छेडेदह गाउँपालिका', '15,812', '18,741', '19,307']
# ['Gaumul', 'Rural Municipality', 'Gaumula', 'गौमुल गाउँपालिका', '...', '8,515', '8,913']
# ['Himali', 'Rural Municipality', 'Himālī', 'हिमाली गाउँपालिका', '...', '9,229', '10,309']
# ['Jagannath [Pandav Gupha]', 'Rural Municipality', 'Jagannātha', 'जगन्\u200dनाथ गाउँपालिका', '...', '9,432', '10,158']
# ['Khaptad National Park', 'National Park', 'Khaptaḍa Rāṣṭriya Nikuñja', 'खप्तड राष्ट्रिय निकुञ्ज', '0', '0', '0']
# ['Swamikartik Khapar', 'Rural Municipality', 'Svāmīkārtika Khāpara', 'स्वामीकार्तिक खापर गाउँपालिका', '10,889', '12,790', '12,576']
# ['Triveni', 'Municipality', 'Trivēṇī', 'त्रिवेणी नगरपालिका', '14,938', '18,363', '17,798']
# ['Baijanath', 'Rural Municipality', 'Baijanātha', 'बैजनाथ गाउँपालिका', '45,481', '54,987', '69,472']
# ['Duduwa', 'Rural Municipality', 'Ḍuḍuvā', 'डुडुवा गाउँपालिका', '...', '37,533', '43,135']
# ['Janaki', 'Rural Municipality', 'Jānakī', 'जानकी गाउँपालिका', '31,447', '37,847', '46,141']
# ['Khajura', 'Rural Municipality', 'Khajurā', 'खजुरा गाउँपालिका', '45,605', '50,990', '62,789']
# ['Kohalpur', 'Municipality', 'Kōhalapura', 'कोहलपुर नगरपालिका', '41,999', '72,748', '101,667']
# ['Narainapur', 'Rural Municipality', 'Naraināpura', 'नरैनापुर गाउँपालिका', '30,130', '35,042', '43,206']
# ['Nepalganj', 'Sub-Metropolis', 'Nēpālagañja', 'नेपालगञ्ज उपमहानगरपालिका', '...', '141,241', '164,444']
# ['Rapti Sonari', 'Rural Municipality', 'Rāptī Sōnārī', 'राप्ती सोनारी गाउँपालिका', '53,009', '60,925', '66,445']
# ['Adarsha Kotwal', 'Rural Municipality', 'Ādarśa Kōṭavāla', 'आदर्श कोटवाल गाउँपालिका', '21,590', '27,552', '31,364']
# ['Baragadhi', 'Rural Municipality', 'Bārāgaḍhīgāũpālikā', 'बारागढीगाउँपालिका', '...', '27,191', '29,555']
# ['Bishrampur', 'Rural Municipality', 'Viśrāmapura', 'विश्रामपुर गाउँपालिका', '18,912', '23,814', '24,892']
# ['Devtal', 'Rural Municipality', 'Dēvatāla', 'देवताल गाउँपालिका', '...', '23,011', '25,361']
# ['Jitpur Simara', 'Sub-Metropolis', 'Jītapura Simarā', 'जीतपुर सिमरा उपमहानगरपालिका', '...', '118,398', '127,307']
# ['Kalaiya', 'Sub-Metropolis', 'Kalaiyā', 'कलैया उपमहानगरपालिका', '...', '123,575', '136,222']
# ['Karaiyamai', 'Rural Municipality', 'Karaiyāmāī', 'करैयामाई गाउँपालिका', '...', '26,496', '29,165']
# ['Kolhabi', 'Municipality', 'Kōlhavī', 'कोल्हवी नगरपालिका', '40,213', '44,082', '51,182']
# ['Mahagadhimai', 'Municipality', 'Mahāgaḍhīmāī', 'महागढीमाई नगरपालिका', '...', '52,396', '59,424']
# ['Nijgadh', 'Municipality', 'Nijagaḍha', 'निजगढ नगरपालिका', '30,693', '35,403', '37,687']
# ['Pachrauta', 'Municipality', 'Pacarautā', 'पचरौता नगरपालिका', '...', '34,194', '40,524']
# ['Parawanipur', 'Rural Municipality', 'Paravānīpura', 'परवानीपुर गाउँपालिका', '...', '22,787', '24,745']
# ['Parsa Wildlife Reserve', 'Wildlife Reserve', 'Parsā Vanyajantu Ārakṣa', 'पर्सा वन्यजन्तु आरक्ष', '0', '0', '0']
# ['Pheta', 'Rural Municipality', 'Phēṭā', 'फेटा गाउँपालिका', '...', '25,653', '28,395']
# ['Prasauni', 'Rural Municipality', 'Prasaunī', 'प्रसौनी गाउँपालिका', '...', '25,049', '25,414']
# ['Simraungadh', 'Municipality', 'Simraunagaḍha', 'सिम्रौनगढ नगरपालिका', '...', '48,570', '54,878']
# ['Suwarna', 'Rural Municipality', 'Suvarṇa', 'सुवर्ण गाउँपालिका', '...', '29,537', '35,141']
# ['Badhaiyatal', 'Rural Municipality', 'Baḍhaiyātāla', 'बढैयाताल गाउँपालिका', '42,892', '47,948', '52,818']
# ['Bansgadhi', 'Municipality', 'Bā̃sagaḍhī', 'बाँसगढी नगरपालिका', '48,617', '55,875', '63,252']
# ['Barbardiya', 'Municipality', 'Bārabardiyā', 'बारबर्दिया नगरपालिका', '59,737', '68,031', '72,533']
# ['Bardiya National Park', 'National Park', 'Bardiyā Rāṣṭriya Nikuñja', 'बर्दिया राष्ट्रिय निकुञ्ज', '0', '0', '0']
# ['Geruwa', 'Rural Municipality', 'Gēruvā', 'गेरुवा गाउँपालिका', '34,088', '34,885', '33,514']
# ['Gulariya', 'Municipality', 'Gulariyā', 'गुलरिया नगरपालिका', '56,532', '68,164', '74,505']
# ['Madhuwan', 'Municipality', 'Madhuvana', 'मधुवन नगरपालिका', '42,606', '46,682', '50,739']
# ['Rajapur', 'Municipality', 'Rājāpura', 'राजापुर नगरपालिका', '58,820', '59,818', '60,831']
# ['Thakurbaba', 'Municipality', 'Ṭhākurabābā', 'ठाकुरबाबा नगरपालिका', '38,601', '45,173', '49,420']
# ['Bhaktapur', 'Municipality', 'Bhaktapura', 'भक्तपुर नगरपालिका', '72,543', '83,658', '79,136']
# ['Changunarayan', 'Municipality', 'Cā̃gunārāyaṇa', 'चाँगुनारायण नगरपालिका', '...', '58,006', '88,083']
# ['Madhyapur Thimi', 'Municipality', 'Madhyapura Thimī', 'मध्यपुर थिमी नगरपालिका', '47,751', '84,142', '119,756']
# ['Suryabinayak', 'Municipality', 'Sūryavināyaka', 'सूर्यविनायक नगरपालिका', '55,744', '78,845', '140,085']
# ['Aamchok', 'Rural Municipality', 'Āmacōka', 'आमचोक गाउँपालिका', '20,753', '18,777', '14,968']
# ['Arun', 'Rural Municipality', 'Aruṇa', 'अरुण गाउँपालिका', '19,574', '17,768', '14,591']
# ['Bhojpur', 'Municipality', 'Bhōjapura', 'भोजपुर नगरपालिका', '...', '28,107', '26,007']
# ['Hatuwagadhi', 'Rural Municipality', 'Hatuvāgaḍhī', 'हतुवागढी गाउँपालिका', '24,252', '20,543', '16,175']
# ['Pauwadungma', 'Rural Municipality', 'Pauvāduṅamā', 'पौवादुङमा गाउँपालिका', '17,976', '15,414', '12,107']
# ['Ramprasad Rai', 'Rural Municipality', 'Rāmaprasāda Rāī', 'रामप्रसाद राई गाउँपालिका', '21,493', '18,894', '15,673']
# ['Salpasilichho', 'Rural Municipality', 'Sālpāsilichō', 'साल्पासिलिछो गाउँपालिका', '13,870', '13,111', '12,284']
# ['Shadananda', 'Municipality', 'Ṣaḍānanda', 'षडानन्द नगरपालिका', '33,560', '31,612', '29,342']
# ['Tyamkemaiyung', 'Rural Municipality', 'Ṭēmkēmaiyuṅa', 'टेम्केमैयुङ गाउँपालिका', '22,027', '18,233', '15,464']
# ['Bharatpur', 'Metropolis', 'Bharatapura', 'भरतपुर महानगरपालिका', '210,593', '285,167', '369,268']
# ['Chitawan National Park', 'National Park', 'Citavana Rāṣṭriya Nikuñja', 'चितवन राष्ट्रिय निकुञ्ज', '0', '0', '0']
# ['Ichchhakamana', 'Rural Municipality', 'Icchākāmanā', 'इच्छाकामना गाउँपालिका', '21,924', '25,067', '27,643']
# ['Kalika', 'Municipality', 'Kālikā', 'कालिका नगरपालिका', '...', '44,898', '52,164']
# ['Khairhani', 'Municipality', 'Khairahanī', 'खैरहनी नगरपालिका', '50,372', '56,925', '67,385']
# ['Madi', 'Municipality', 'Māḍī', 'माडी नगरपालिका', '41,344', '37,764', '38,295']
# ['Rapti', 'Municipality', 'Rāptī', 'राप्ती नगरपालिका', '...', '59,937', '66,617']
# ['Ratnanagar', 'Municipality', 'Ratnanagara', 'रत्ननगर नगरपालिका', '58,824', '70,226', '89,905']
# ['Aalital', 'Rural Municipality', 'Ālitāla', 'आलिताल गाउँपालिका', '14,157', '18,531', '18,112']
# ['Ajaymeru', 'Rural Municipality', 'Ajayamēru', 'अजयमेरु गाउँपालिका', '17,503', '17,066', '15,161']
# ['Amargadhi', 'Municipality', 'Amaragaḍhī', 'अमरगढी नगरपालिका', '18,390', '22,241', '24,149']
# ['Bhageshwar', 'Rural Municipality', 'Bhāgēśvara', 'भागेश्वर गाउँपालिका', '13,356', '14,132', '13,132']
# ['Ganyapadhura', 'Rural Municipality', 'Ganyāpadhurā', 'गन्यापधुरा गाउँपालिका', '14,277', '15,109', '13,722']
# ['Navadurga', 'Rural Municipality', 'Navadurgā', 'नवदुर्गा गाउँपालिका', '17,987', '19,985', '18,672']
# ['Parshuram', 'Municipality', 'Paraśurāma', 'परशुराम नगरपालिका', '30,093', '35,030', '35,590']
# ['Aathabis', 'Municipality', 'Āṭhabīsa', 'आठबीस नगरपालिका', '22,169', '29,257', '31,092']
# ['Bhagawatimai', 'Rural Municipality', 'Bhagavatīmāī', 'भगवतीमाई गाउँपालिका', '15,887', '18,778', '18,206']
# ['Bhairabi', 'Rural Municipality', 'Bhairavī', 'भैरवी गाउँपालिका', '...', '21,233', '18,767']
# ['Chamunda Bindrasaini', 'Municipality', 'Cāmuṇḍā Bindrāsainī', 'चामुण्डा बिन्द्रासैनी नगरपालिका', '20,801', '26,149', '26,559']
# ['Dullu', 'Municipality', 'Dullu', 'दुल्लु नगरपालिका', '...', '41,540', '39,143']
# ['Dungeshwar', 'Rural Municipality', 'Ḍuṅgēśvara', 'डुङ्गेश्वर गाउँपालिका', '15,424', '15,883', '14,533']
# ['Gurans', 'Rural Municipality', 'Gurā̃sa', 'गुराँस गाउँपालिका', '19,781', '22,033', '21,189']
# ['Mahabu', 'Rural Municipality', 'Mahābu', 'महाबु गाउँपालिका', '...', '19,277', '18,059']
# ['Narayan', 'Municipality', 'Nārāyaṇa', 'नारायण नगरपालिका', '...', '27,922', '26,111']
# ['Naumule', 'Rural Municipality', 'Naumulē', 'नौमुले गाउँपालिका', '19,704', '20,802', '19,687']
# ['Thantikandh', 'Rural Municipality', 'Ṭhā̃ṭīkā̃dha', 'ठाँटीकाँध गाउँपालिका', '14,801', '18,896', '18,301']
# ['Babai', 'Rural Municipality', 'Babaī', 'बबई गाउँपालिका', '23,670', '27,469', '30,968']
# ['Banglachuli', 'Rural Municipality', 'Baṅgalāculī', 'बंगलाचुली गाउँपालिका', '...', '24,245', '22,373']
# ['Dangisharan', 'Rural Municipality', 'Daṅgīśaraṇa', 'दंगीशरण गाउँपालिका', '21,003', '21,484', '23,668']
# ['Gadhawa', 'Rural Municipality', 'Gaḍhavā', 'गढवा गाउँपालिका', '34,724', '38,663', '45,898']
# ['Ghorahi', 'Sub-Metropolis', 'Ghōrāhī', 'घोराही उपमहानगरपालिका', '125,119', '158,628', '200,530']
# ['Lamahi', 'Municipality', 'Lamahī', 'लमही नगरपालिका', '38,632', '48,012', '59,050']
# ['Rajpur', 'Rural Municipality', 'Rājapura', 'राजपुर गाउँपालिका', '21,564', '25,061', '28,346']
# ['Rapti', 'Rural Municipality', 'Rāptī', 'राप्ती गाउँपालिका', '...', '40,949', '52,123']
# ['Shantinagar', 'Rural Municipality', 'Śāntinagara', 'शान्तिनगर गाउँपालिका', '24,716', '25,203', '27,641']
# ['Tulsipur', 'Sub-Metropolis', 'Tulsīpura', 'तुल्सीपुर उपमहानगरपालिका', '115,759', '142,869', '179,755']
# ['Apihimal', 'Rural Municipality', 'Apihimāla', 'अपिहिमाल गाउँपालिका', '...', '6,779', '6,798']
# ['Byans', 'Rural Municipality', 'Byā̃sa', 'ब्याँस गाउँपालिका', '10,346', '10,347', '9,668']
# ['Duhun', 'Rural Municipality', 'Duhũ', 'दुहुँ गाउँपालिका', '10,607', '10,818', '9,842']
# ['Lekam', 'Rural Municipality', 'Lēkama', 'लेकम गाउँपालिका', '15,137', '14,838', '13,743']
# ['Mahakali', 'Municipality', 'Mahākālī', 'महाकाली नगरपालिका', '...', '21,881', '24,081']
# ['Malikarjun', 'Rural Municipality', 'Mālikārjuna', 'मालिकार्जुन गाउँपालिका', '15,889', '15,581', '15,635']
# ['Marma', 'Rural Municipality', 'Mārmā', 'मार्मा गाउँपालिका', '...', '14,956', '15,124']
# ['Naugad', 'Rural Municipality', 'Naugāḍa', 'नौगाड गाउँपालिका', '13,143', '15,874', '15,528']
# ['Shailyashikhar', 'Municipality', 'Śailyaśikhara', 'शैल्यशिखर नगरपालिका', '19,829', '22,200', '21,807']
# ['Benighat Rorang', 'Rural Municipality', 'Bēnīghāṭa Rōrāṅga', 'बेनीघाट रोराङ्ग गाउँपालिका', '27,699', '31,475', '33,854']
# ['Dhunibeshi', 'Municipality', 'Dhunivēśī', 'धुनिवेशी नगरपालिका', '31,029', '31,029', '29,149']
# ['Gajuri', 'Rural Municipality', 'Gajurī', 'गजुरी गाउँपालिका', '...', '27,841', '28,634']
# ['Galchhi', 'Rural Municipality', 'Galchī', 'गल्छी गाउँपालिका', '...', '26,215', '23,733']
# ['Gangajamuna', 'Rural Municipality', 'Gaṅgājamunā', 'गङ्गाजमुना गाउँपालिका', '25,591', '21,784', '19,265']
# ['Jwalamukhi', 'Rural Municipality', 'Jvālāmūkhī', 'ज्वालामूखी गाउँपालिका', '26,225', '23,966', '21,338']
# ['Khaniyabas', 'Rural Municipality', 'Khaniyābāsa', 'खनियाबास गाउँपालिका', '13,530', '12,749', '10,287']
# ['Netrawati Dabjong', 'Rural Municipality', 'Nētrāvatī Ḍabajōṅa', 'नेत्रावती डबजोङ गाउँपालिका', '15,699', '12,870', '11,310']
# ['Nilkantha', 'Municipality', 'Nīlakaṇṭha', 'नीलकण्ठ नगरपालिका', '55,696', '58,876', '58,828']
# ['Rubi Bhyali [Rubi Valley]', 'Rural Municipality', 'Ruvī Bhyālī', 'रुवी भ्याली गाउँपालिका', '10,376', '9,562', '10,781']
# ['Siddhalek', 'Rural Municipality', 'Siddhalēka', 'सिद्धलेक गाउँपालिका', '24,594', '23,729', '22,214']
# ['Thakre', 'Rural Municipality', 'Thākrē', 'थाक्रे गाउँपालिका', '...', '32,979', '32,374']
# ['Tripurasundari', 'Rural Municipality', 'Tripurāsundarī', 'त्रिपुरासुन्दरी गाउँपालिका', '25,096', '22,992', '21,937']
# ['Chaubise', 'Rural Municipality', 'Cauvisē', 'चौविसे गाउँपालिका', '21,794', '19,283', '17,677']
# ['Chhathar Jorpati', 'Rural Municipality', 'Chathara Jōrapāṭī', 'छथर जोरपाटी गाउँपालिका', '19,693', '18,322', '16,456']
# ['Dhankuta', 'Municipality', 'Dhanakuṭā', 'धनकुटा नगरपालिका', '30,994', '38,629', '35,983']
# ['Mahalaxmi', 'Municipality', 'Mahālakṣmī', 'महालक्ष्मी नगरपालिका', '26,324', '24,800', '22,182']
# ['Pakhribas', 'Municipality', 'Pākhrībāsa', 'पाख्रीबास नगरपालिका', '24,273', '22,078', '19,104']
# ['Sahidbhumi [Khalsachhintang Shahidbhumi]', 'Rural Municipality', 'Sahidabhūmi', 'सहिदभूमि गाउँपालिका', '18,911', '18,763', '17,767']
# ['Sangurigadhi', 'Rural Municipality', 'Sāgurīgaḍhī', 'सागुरीगढी गाउँपालिका', '23,080', '21,537', '19,561']
# ['Aurahi', 'Rural Municipality', 'Aurahī', 'औरही गाउँपालिका', '20,963', '22,578', '24,053']
# ['Bateshwar', 'Rural Municipality', 'Baṭēśvara', 'बटेश्वर गाउँपालिका', '18,405', '21,530', '21,742']
# ['Bidehi', 'Municipality', 'Vidēha', 'विदेह नगरपालिका', '31,266', '32,266', '37,697']
# ['Chhireshwarnath', 'Municipality', 'Chirēśvaranātha', 'छिरेश्वरनाथ नगरपालिका', '...', '42,155', '51,075']
# ['Dhanauji', 'Rural Municipality', 'Dhanaujī', 'धनौजी गाउँपालिका', '18,964', '21,395', '21,942']
# ['Dhanushadham', 'Municipality', 'Dhanuṣādhāma', 'धनुषाधाम नगरपालिका', '...', '45,585', '52,024']
# ['Ganeshman Charnath', 'Municipality', 'Gaṇēśamāna Cāranātha', 'गणेशमान चारनाथ नगरपालिका', '...', '36,338', '44,082']
# ['Hansapur', 'Municipality', 'Haṃsapura', 'हंसपुर नगरपालिका', '...', '38,216', '44,949']
# ['Janaknandini', 'Rural Municipality', 'Janakanandinī', 'जनकनन्दिनी गाउँपालिका', '23,716', '25,338', '28,208']
# ['Janakpur', 'Sub-Metropolis', 'Janakapura', 'जनकपुर उपमहानगरपालिका', '...', '162,842', '194,556']
# ['Kamala', 'Municipality', 'Kamalā', 'कमला नगरपालिका', '37,723', '38,624', '44,597']
# ['Lakshminiya', 'Rural Municipality', 'Lakṣmīniyā', 'लक्ष्मीनिया गाउँपालिका', '26,095', '28,251', '31,881']
# ['Mithila', 'Municipality', 'Mithilā', 'मिथिला नगरपालिका', '...', '45,227', '48,676']
# ['Mithila Bihari', 'Municipality', 'Mithilā Bihārī', 'मिथिला बिहारी नगरपालिका', '...', '33,556', '38,273']
# ['Mukhiyapatti Musharmiya', 'Rural Municipality', 'Mukhiyāpaṭṭī Musaharamiyā', 'मुखियापट्टी मुसहरमिया गाउँपालिका', '...', '25,482', '28,208']
# ['Nagrain', 'Municipality', 'Nagarāina', 'नगराइन नगरपालिका', '33,485', '35,583', '38,037']
# ['Sabaila', 'Municipality', 'Sabailā', 'सबैला नगरपालिका', '...', '52,389', '62,282']
# ['Shahidnagar', 'Municipality', 'Śahīdanagara', 'शहीदनगर नगरपालिका', '...', '47,422', '53,812']
# ['Baiteshwar', 'Rural Municipality', 'Vaitēśvara', 'वैतेश्वर गाउँपालिका', '21,826', '19,876', '17,896']
# ['Bhimeshwar', 'Municipality', 'Bhīmēśvara', 'भीमेश्वर नगरपालिका', '33,677', '33,324', '34,712']
# ['Bigu', 'Rural Municipality', 'Vigu', 'विगु गाउँपालिका', '18,536', '18,592', '16,490']
# ['Gaurishankar', 'Rural Municipality', 'Gaurīśaṅkara', 'गौरीशङ्कर गाउँपालिका', '18,626', '17,140', '15,995']
# ['Jiri', 'Municipality', 'Jirī', 'जिरी नगरपालिका', '...', '15,837', '16,109']
# ['Kalinchok', 'Rural Municipality', 'Kāliñcōka', 'कालिञ्चोक गाउँपालिका', '23,274', '22,954', '21,097']
# ['Melung', 'Rural Municipality', 'Mēluṅga', 'मेलुङ्ग गाउँपालिका', '18,043', '20,287', '15,893']
# ['Shailung', 'Rural Municipality', 'Śailuṅga', 'शैलुङ्ग गाउँपालिका', '19,561', '19,698', '17,923']
# ['Tamakoshi', 'Rural Municipality', 'Tāmākōśī', 'तामाकोशी गाउँपालिका', '20,214', '18,849', '15,163']
# ['Chharka Tangsong', 'Rural Municipality', 'Chārkā Tāṅasōṅa', 'छार्का ताङसोङ गाउँपालिका', '1,283', '1,451', '1,672']
# ['Dolpo Buddha', 'Rural Municipality', 'Ḍōlpō Buddha', 'डोल्पो बुद्ध गाउँपालिका', '1,897', '2,137', '2,420']
# ['Jagdulla', 'Rural Municipality', 'Jagadullā', 'जगदुल्ला गाउँपालिका', '...', '2,322', '2,575']
# ['Kaike', 'Rural Municipality', 'Kāīkē', 'काईके गाउँपालिका', '...', '3,303', '3,965']
# ['Mudkechula', 'Rural Municipality', 'Muḍkēculā', 'मुड्केचुला गाउँपालिका', '3,933', '5,165', '5,803']
# ['She Phoksundo', 'Rural Municipality', 'Śē Phōksunḍō', 'शे फोक्सुन्डो गाउँपालिका', '...', '3,136', '3,635']
# ['Thuli Bheri', 'Municipality', 'Ṭhūlī Bhērī', 'ठूली भेरी नगरपालिका', '...', '8,571', '9,861']
# ['Tripurasundari', 'Municipality', 'Tripurāsundarī', 'त्रिपुरासुन्दरी नगरपालिका', '...', '10,615', '12,233']
# ['Aadarsha', 'Rural Municipality', 'Ādarśa', 'आदर्श गाउँपालिका', '24,208', '24,482', '24,495']
# ['Badikedar', 'Rural Municipality', 'Baḍīkēdāra', 'बडीकेदार गाउँपालिका', '16,572', '16,731', '14,902']
# ['Bogtan Phudsil', 'Rural Municipality', 'Bōgaṭāna Phuḍsila', 'बोगटान फुड्सिल गाउँपालिका', '19,638', '17,906', '15,540']
# ['Dipayal Silgadhi', 'Municipality', 'Dipāyala Silagaḍhī', 'दिपायल सिलगढी नगरपालिका', '...', '36,038', '33,968']
# ['Jorayal', 'Rural Municipality', 'Jōrāyala', 'जोरायल गाउँपालिका', '...', '21,296', '19,788']
# ['Khaptad National Park', 'National Park', 'Khaptaḍa Rāṣṭriya Nikuñja', 'खप्तड राष्ट्रिय निकुञ्ज', '0', '0', '0']
# ['K.I. Singh', 'Rural Municipality', 'K.Ī. Siṃha', 'के.आई.सिंह गाउँपालिका', '21,073', '20,903', '20,736']
# ['Purbichauki', 'Rural Municipality', 'Pūrvīcaukī', 'पूर्वीचौकी गाउँपालिका', '...', '22,489', '21,494']
# ['Sayal', 'Rural Municipality', 'Sāyala', 'सायल गाउँपालिका', '...', '19,575', '20,456']
# ['Shikhar', 'Municipality', 'Śikhara', 'शिखर नगरपालिका', '32,462', '32,326', '30,399']
# ['Bhume', 'Rural Municipality', 'Bhūmē', 'भूमे गाउँपालिका', '...', '18,641', '19,829']
# ['Dhorpatan Hunting Reserve', 'Hunting Reserve', 'Ḍhōrapāṭana Śikāra Ārakṣa', 'ढोरपाटन शिकार आरक्ष', '0', '0', '0']
# ['Putha Uttarganga', 'Rural Municipality', 'Puthā Uttaragaṅgā', 'पुथा उत्तरगंगा गाउँपालिका', '16,842', '17,999', '18,308']
# ['Sisne', 'Rural Municipality', 'Sisnē', 'सिस्ने गाउँपालिका', '...', '16,544', '18,534']
# ['Aarughat', 'Rural Municipality', 'Ārūghāṭa', 'आरूघाट गाउँपालिका', '24,337', '23,915', '21,572']
# ['Ajirkot', 'Rural Municipality', 'Ajirakōṭa', 'अजिरकोट गाउँपालिका', '17,737', '15,602', '12,832']
# ['Bhimsen', 'Rural Municipality', 'Bhimasēnathāpā', 'भिमसेनथापा गाउँपालिका', '24,885', '22,053', '16,986']
# ['Chumanuwri', 'Rural Municipality', 'Cumanuvrī', 'चुमनुव्री गाउँपालिका', '...', '7,417', '5,932']
# ['Dharche', 'Rural Municipality', 'Dhārcē', 'धार्चे गाउँपालिका', '13,553', '13,264', '14,263']
# ['Gandaki', 'Rural Municipality', 'Gaṇḍakī', 'गण्डकी गाउँपालिका', '25,122', '23,262', '21,394']
# ['Gorkha', 'Municipality', 'Gōrakhā', 'गोरखा नगरपालिका', '44,433', '50,684', '52,468']
# ['Palungtar', 'Municipality', 'Pāluṅaṭāra', 'पालुङटार नगरपालिका', '42,117', '38,244', '37,409']
# ['Shahid Lakhan', 'Rural Municipality', 'Śahida Lakhana', 'शहिद लखन गाउँपालिका', '31,649', '27,555', '23,076']
# ['Siranchok', 'Rural Municipality', 'Sirānacōka', 'सिरानचोक गाउँपालिका', '28,010', '23,666', '19,719']
# ['Sulikot', 'Rural Municipality', 'Sulīkōṭa', 'सुलीकोट गाउँपालिका', '27,415', '25,399', '22,636']
# ['Chandrakot', 'Rural Municipality', 'Candrakōṭa', 'चन्द्रकोट गाउँपालिका', '24,502', '21,907', '18,662']
# ['Chhatrakot', 'Rural Municipality', 'Chatrakōṭa', 'छत्रकोट गाउँपालिका', '23,461', '21,504', '19,357']
# ['Dhurkot', 'Rural Municipality', 'Dhurkōṭa', 'धुर्कोट गाउँपालिका', '...', '22,468', '18,814']
# ['Gulmi Darbar', 'Rural Municipality', 'Gulmī Darabāra', 'गुल्मी दरबार गाउँपालिका', '24,373', '22,047', '19,296']
# ['Isma', 'Rural Municipality', 'Īsmā', 'ईस्मा गाउँपालिका', '21,925', '21,030', '18,529']
# ['Kaligandaki', 'Rural Municipality', 'Kālīgaṇḍakī', 'कालीगण्डकी गाउँपालिका', '22,140', '18,885', '15,044']
# ['Madane', 'Rural Municipality', 'Madānē', 'मदाने गाउँपालिका', '21,949', '21,948', '20,022']
# ['Malika', 'Rural Municipality', 'Mālikā', 'मालिका गाउँपालिका', '...', '21,729', '20,075']
# ['Musikot', 'Municipality', 'Musikōṭa', 'मुसिकोट नगरपालिका', '...', '33,000', '28,454']
# ['Resunga', 'Municipality', 'Rēsuṅagā', 'रेसुङगा नगरपालिका', '...', '33,225', '31,551']
# ['Ruru', 'Rural Municipality', 'Rurukṣētra', 'रुरुक्षेत्र गाउँपालिका', '20,914', '18,610', '16,597']
# ['Satyawati', 'Rural Municipality', 'Satyavatī', 'सत्यवती गाउँपालिका', '26,932', '23,807', '19,473']
# ['Adanchuli', 'Rural Municipality', 'Adānaculī', 'अदानचुली गाउँपालिका', '...', '7,140', '8,265']
# ['Chankheli', 'Rural Municipality', 'Caṅkhēlī', 'चंखेली गाउँपालिका', '...', '5,541', '6,579']
# ['Kharpunath', 'Rural Municipality', 'Khārpunātha', 'खार्पुनाथ गाउँपालिका', '5,139', '6,045', '6,736']
# ['Namkha', 'Rural Municipality', 'Nāmkhā', 'नाम्खा गाउँपालिका', '...', '4,250', '3,589']
# ['Sarkegad', 'Rural Municipality', 'Sarkēgāḍa', 'सर्केगाड गाउँपालिका', '...', '9,868', '10,688']
# ['Simkot', 'Rural Municipality', 'Simakōṭa', 'सिमकोट गाउँपालिका', '...', '12,038', '11,935']
# ['Tanjakot', 'Rural Municipality', 'Tā̃jākōṭa', 'ताँजाकोट गाउँपालिका', '4,280', '5,976', '6,092']
# ['Chulachuli', 'Rural Municipality', 'Culāculī', 'चुलाचुली गाउँपालिका', '...', '21,413', '23,157']
# ['Deumai', 'Municipality', 'Dēumāī', 'देउमाई नगरपालिका', '...', '32,386', '30,969']
# ['Ilam', 'Municipality', 'Ilāma', 'इलाम नगरपालिका', '44,940', '49,330', '50,085']
# ['Mai', 'Municipality', 'Māī', 'माई नगरपालिका', '...', '33,210', '30,732']
# ['Maijogmai', 'Rural Municipality', 'Māījōgamāī', 'माईजोगमाई गाउँपालिका', '...', '21,064', '19,131']
# ['Mangsebung', 'Rural Municipality', 'Māṅasēbuṅa', 'माङसेबुङ गाउँपालिका', '16,028', '18,534', '16,810']
# ['Phakphokthum', 'Rural Municipality', 'Phākaphōkathuma', 'फाकफोकथुम गाउँपालिका', '...', '22,160', '19,706']
# ['Rong', 'Rural Municipality', 'Rōṅa', 'रोङ गाउँपालिका', '18,983', '19,135', '17,367']
# ['Sandakpur', 'Rural Municipality', 'Sandakapura', 'सन्दकपुर गाउँपालिका', '...', '16,065', '15,444']
# ['Suryodaya', 'Municipality', 'Sūryōdaya', 'सूर्योदय नगरपालिका', '...', '56,957', '54,727']
# ['Barekot', 'Rural Municipality', 'Bārēkōṭa', 'बारेकोट गाउँपालिका', '13,929', '18,083', '22,005']
# ['Bheri', 'Municipality', 'Bhērī', 'भेरी नगरपालिका', '...', '34,713', '37,892']
# ['Chhedagad', 'Municipality', 'Chēḍāgāḍa', 'छेडागाड नगरपालिका', '...', '35,295', '37,877']
# ['Junichande', 'Rural Municipality', 'Junīcā̃dē', 'जुनीचाँदे गाउँपालिका', '16,344', '21,733', '23,771']
# ['Kuse', 'Rural Municipality', 'Kusē', 'कुसे गाउँपालिका', '...', '20,621', '23,058']
# ['Nalgad [Triveni Nalgad]', 'Municipality', 'Nalagāḍa', 'नलगाड नगरपालिका', '20,065', '25,590', '28,922']
# ['Shivalaya', 'Rural Municipality', 'Śivālaya', 'शिवालय गाउँपालिका', '12,764', '15,269', '14,776']
# ['Arjundhara', 'Municipality', 'Arjunadhārā', 'अर्जुनधारा नगरपालिका', '50,513', '60,480', '84,018']
# ['Bahradashi', 'Rural Municipality', 'Bāhradaśī', 'बाह्रदशी गाउँपालिका', '32,502', '33,674', '37,946']
# ['Bhadrapur', 'Municipality', 'Bhadrapura', 'भद्रपुर नगरपालिका', '56,841', '66,629', '70,913']
# ['Birtamod', 'Municipality', 'Birtāmōḍa', 'बिर्तामोड नगरपालिका', '58,001', '82,592', '116,192']
# ['Buddhashanti', 'Rural Municipality', 'Buddhaśānti', 'बुद्धशान्ति गाउँपालिका', '37,179', '41,624', '53,010']
# ['Damak', 'Municipality', 'Damaka', 'दमक नगरपालिका', '35,009', '75,743', '107,227']
# ['Gauradaha', 'Municipality', 'Gaurādaha', 'गौरादह नगरपालिका', '50,793', '53,049', '60,451']
# ['Gaurigunj', 'Rural Municipality', 'Gaurīgañja', 'गौरीगंज गाउँपालिका', '30,759', '33,085', '35,506']
# ['Haldibari', 'Rural Municipality', 'Haldībārī', 'हल्दीबारी गाउँपालिका', '28,129', '28,951', '32,722']
# ['Jhapa', 'Rural Municipality', 'Jhāpā', 'झापा गाउँपालिका', '31,008', '34,622', '39,302']
# ['Kachankawal', 'Rural Municipality', 'Kacanakavala', 'कचनकवल गाउँपालिका', '30,229', '39,593', '41,317']
# ['Kamal', 'Rural Municipality', 'Kamala', 'कमल गाउँपालिका', '34,530', '44,679', '53,894']
# ['Kankai', 'Municipality', 'Kanakāī', 'कनकाई नगरपालिका', '32,801', '40,294', '53,148']
# ['Mechinagar', 'Municipality', 'Mēcīnagara', 'मेचीनगर नगरपालिका', '97,422', '112,997', '133,073']
# ['Shivasatakshi', 'Municipality', 'Śivasatākṣī', 'शिवसताक्षी नगरपालिका', '43,632', '64,638', '74,077']
# ['Chandannath', 'Municipality', 'Candananātha', 'चन्दननाथ नगरपालिका', '...', '20,371', '21,036']
# ['Guthichaur', 'Rural Municipality', 'Guṭhicaura', 'गुठिचौर गाउँपालिका', '5,353', '9,920', '10,922']
# ['Hima', 'Rural Municipality', 'Himā', 'हिमा गाउँपालिका', '4,933', '10,553', '12,191']
# ['Kankasundari', 'Rural Municipality', 'Kanakāsundarī', 'कनकासुन्दरी गाउँपालिका', '8,419', '13,216', '13,625']
# ['Patarasi', 'Rural Municipality', 'Pātārāsī', 'पातारासी गाउँपालिका', '11,400', '14,608', '16,824']
# ['Sinja', 'Rural Municipality', 'Siñjā', 'सिंजा गाउँपालिका', '4,765', '12,008', '12,556']
# ['Tatopani', 'Rural Municipality', 'Tātōpānī', 'तातोपानी गाउँपालिका', '11,208', '14,638', '15,575']
# ['Tila', 'Rural Municipality', 'Tilā', 'तिला गाउँपालिका', '11,431', '13,607', '14,539']
# ['Bardagoriya', 'Rural Municipality', 'Bardagōriyā', 'बर्दगोरिया गाउँपालिका', '24,770', '32,683', '37,682']
# ['Bhajani', 'Municipality', 'Bhajanī', 'भजनी नगरपालिका', '45,768', '52,128', '53,494']
# ['Chure', 'Rural Municipality', 'Curē', 'चुरे गाउँपालिका', '16,652', '19,157', '21,400']
# ['Dhangadhi', 'Sub-Metropolis', 'Dhanagaḍhī', 'धनगढी उपमहानगरपालिका', '105,586', '149,818', '198,792']
# ['Gauriganga', 'Municipality', 'Gaurīgaṅgā', 'गौरीगङ्गा नगरपालिका', '...', '58,286', '64,558']
# ['Ghodaghodi', 'Municipality', 'Ghōḍāghōḍī', 'घोडाघोडी नगरपालिका', '55,579', '75,965', '86,034']
# ['Godawari', 'Municipality', 'Gōdāvarī', 'गोदावरी नगरपालिका', '...', '79,686', '98,746']
# ['Janaki', 'Rural Municipality', 'Jānakī', 'जानकी गाउँपालिका', '50,114', '48,540', '49,860']
# ['Joshipur', 'Rural Municipality', 'Jōśīpura', 'जोशीपुर गाउँपालिका', '32,571', '36,459', '37,187']
# ['Kailari', 'Rural Municipality', 'Kailārī', 'कैलारी गाउँपालिका', '...', '47,987', '49,917']
# ['Lamkichuha', 'Municipality', 'Lamkīcuhā', 'लम्कीचुहा नगरपालिका', '61,074', '76,007', '90,971']
# ['Mohanyal', 'Rural Municipality', 'Mōhanyāla', 'मोहन्याल गाउँपालिका', '20,975', '22,053', '21,082']
# ['Tikapur', 'Municipality', 'Ṭīkāpura', 'टीकापुर नगरपालिका', '59,917', '76,940', '89,835']
# ['Khandachakra', 'Municipality', 'Khā̃ḍācakra', 'खाँडाचक्र नगरपालिका', '...', '20,618', '22,274']
# ['Mahawai', 'Rural Municipality', 'Mahāvai', 'महावै गाउँपालिका', '...', '8,339', '8,177']
# ['Narharinath', 'Rural Municipality', 'Naraharinātha', 'नरहरिनाथ गाउँपालिका', '17,006', '21,381', '22,458']
# ['Pachaljharana', 'Rural Municipality', 'Pacālajharanā', 'पचालझरना गाउँपालिका', '...', '12,343', '13,687']
# ['Palata', 'Rural Municipality', 'Palātā', 'पलाता गाउँपालिका', '12,101', '15,303', '17,346']
# ['Raskot', 'Municipality', 'Rāskōṭa', 'रास्कोट नगरपालिका', '...', '16,272', '17,425']
# ['Sanni Triveni', 'Rural Municipality', 'Sānnī Trivēṇī', 'सान्नी त्रिवेणी गाउँपालिका', '...', '12,846', '13,491']
# ['Shubha Kalika', 'Rural Municipality', 'Śubha Kālīkā', 'शुभ कालीका गाउँपालिका', '...', '14,080', '13,773']
# ['Tilagufa', 'Municipality', 'Tilāguphā', 'तिलागुफा नगरपालिका', '...', '15,766', '16,197']
# ['Bedkot', 'Municipality', 'Bēdakōṭa', 'बेदकोट नगरपालिका', '40,742', '49,490', '57,680']
# ['Belauri', 'Municipality', 'Bēlaurī', 'बेलौरी नगरपालिका', '45,869', '53,609', '53,910']
# ['Beldandi', 'Rural Municipality', 'Bēlaḍāḍī', 'बेलडाडी गाउँपालिका', '24,771', '21,949', '21,888']
# ['Bhimdatta', 'Municipality', 'Bhīmadatta', 'भीमदत्त नगरपालिका', '80,839', '106,666', '122,320']
# ['Krishnapur', 'Municipality', 'Kr̥ṣṇapura', 'कृष्णपुर नगरपालिका', '...', '56,643', '71,500']
# ['Laljhadi', 'Rural Municipality', 'Lālajhāḍī', 'लालझाडी गाउँपालिका', '...', '22,569', '25,037']
# ['Mahakali', 'Municipality', 'Mahākālī', 'महाकाली नगरपालिका', '35,403', '39,290', '42,974']
# ['Punarbas', 'Municipality', 'Punarvāsa', 'पुनर्वास नगरपालिका', '...', '53,672', '61,748']
# ['Shuklaphanta', 'Municipality', 'Śuklāphā̃ṭā', 'शुक्लाफाँटा नगरपालिका', '...', '47,360', '53,969']
# ['Shuklaphanta National Park', 'National Park', 'Śuklāphā̃ṭa Rāṣṭriya Nikuñja', 'शुक्लाफाँट राष्ट्रिय निकुञ्ज', '0', '0', '0']
# ['Banganga', 'Municipality', 'Vāṇagaṅgā', 'वाणगंगा नगरपालिका', '63,449', '75,354', '96,714']
# ['Bijaynagar', 'Rural Municipality', 'Vijayanagara', 'विजयनगर गाउँपालिका', '32,060', '37,013', '43,291']
# ['Buddhabhumi', 'Municipality', 'Buddhavāṭikā', 'बुद्धवाटिका नगरपालिका', '54,590', '65,458', '76,507']
# ['Kapilvastu', 'Municipality', 'Kapilavastu', 'कपिलवस्तु नगरपालिका', '68,059', '76,894', '88,874']
# ['Krishnanagar', 'Municipality', 'Kr̥ṣṇanagara', 'कृष्णनगर नगरपालिका', '52,748', '62,422', '70,111']
# ['Maharajgunj', 'Municipality', 'Mahārājagañja', 'महाराजगंज नगरपालिका', '46,590', '54,901', '64,645']
# ['Mayadevi', 'Rural Municipality', 'Māyādēvī', 'मायादेवी गाउँपालिका', '40,894', '48,479', '55,972']
# ['Shivraj', 'Municipality', 'Śivarāja', 'शिवराज नगरपालिका', '50,886', '67,162', '84,810']
# ['Shuddhodhan', 'Rural Municipality', 'Śuddhōdhana', 'शुद्धोधन गाउँपालिका', '38,468', '45,301', '52,861']
# ['Yasodhara', 'Rural Municipality', 'Yasōdharā', 'यसोधरा गाउँपालिका', '33,540', '38,952', '44,900']
# ['Annapurna', 'Rural Municipality', 'Annapūrṇa', 'अन्नपूर्ण गाउँपालिका', '...', '23,565', '22,099']
# ['Machhapuchchhre', 'Rural Municipality', 'Māchāpucchrē', 'माछापुच्छ्रे गाउँपालिका', '24,765', '21,920', '22,898']
# ['Madi', 'Rural Municipality', 'Mādī', 'मादी गाउँपालिका', '...', '18,153', '16,142']
# ['Pokhara', 'Metropolis', 'Pōkharā', 'पोखरा महानगरपालिका', '283,137', '413,934', '513,504']
# ['Rupa', 'Rural Municipality', 'Rūpā', 'रूपा गाउँपालिका', '...', '14,526', '14,891']
# ['Budhanilkantha', 'Municipality', 'Buḍhānilakaṇṭha', 'बुढानिलकण्ठ नगरपालिका', '...', '112,281', '177,557']
# ['Chandragiri', 'Municipality', 'Candrāgirī', 'चन्द्रागिरी नगरपालिका', '55,032', '87,553', '136,860']
# ['Dakshinkali', 'Municipality', 'Dakṣiṇakālī', 'दक्षिणकाली नगरपालिका', '...', '25,684', '26,372']
# ['Gokarneshwar', 'Municipality', 'Gōkarṇēśvara', 'गोकर्णेश्वर नगरपालिका', '57,698', '110,452', '149,366']
# ['Kageshwari Manohara', 'Municipality', 'Kāgēśvarī Manōharā', 'कागेश्वरी मनोहरा नगरपालिका', '32,077', '60,553', '130,433']
# ['Kathmandu', 'Metropolis', 'Kāṭhamāḍaũ', 'काठमाडौँ महानगरपालिका', '671,846', '1,003,285', '862,400']
# ['Kirtipur', 'Municipality', 'Kīrtipura', 'कीर्तिपुर नगरपालिका', '40,835', '67,171', '81,578']
# ['Nagarjun', 'Municipality', 'Nāgārjuna', 'नागार्जुन नगरपालिका', '33,055', '68,863', '115,437']
# ['Shankharapur', 'Municipality', 'Śaṅkharāpura', 'शंखरापुर नगरपालिका', '24,260', '25,558', '29,318']
# ['Tarakeshwar', 'Municipality', 'Tārakēśvara', 'तारकेश्वर नगरपालिका', '37,268', '82,060', '151,479']
# ['Tokha', 'Municipality', 'Ṭōkhā', 'टोखा नगरपालिका', '42,308', '100,780', '133,755']
# ['Banepa', 'Municipality', 'Banēpā', 'बनेपा नगरपालिका', '...', '57,722', '67,690']
# ['Bethanchok', 'Rural Municipality', 'Bēthānacōka', 'बेथानचोक गाउँपालिका', '...', '15,622', '14,959']
# ['Bhumlu', 'Rural Municipality', 'Bhumlu', 'भुम्लु गाउँपालिका', '...', '19,298', '15,678']
# ['Chaurideurali', 'Rural Municipality', 'Cauṃrīdēurālī', 'चौंरीदेउराली गाउँपालिका', '27,113', '21,130', '14,076']
# ['Dhulikhel', 'Municipality', 'Dhulikhēla', 'धुलिखेल नगरपालिका', '...', '33,981', '33,726']
# ['Khanikhola', 'Rural Municipality', 'Khānīkhōlā', 'खानीखोला गाउँपालिका', '14,190', '14,398', '12,201']
# ['Mahabharat', 'Rural Municipality', 'Mahābhārata', 'महाभारत गाउँपालिका', '18,097', '18,283', '16,079']
# ['Mandandeupur', 'Municipality', 'Maṇḍanadēupura', 'मण्डनदेउपुर नगरपालिका', '...', '32,768', '30,381']
# ['Namobuddha', 'Municipality', 'Namōbuddha', 'नमोबुद्ध नगरपालिका', '32,489', '29,926', '26,160']
# ['Panauti', 'Municipality', 'Panautī', 'पनौती नगरपालिका', '...', '47,549', '51,504']
# ['Panchkhal', 'Municipality', 'Pā̃cakhāla', 'पाँचखाल नगरपालिका', '...', '39,788', '35,521']
# ['Roshi', 'Rural Municipality', 'Rōśī', 'रोशी गाउँपालिका', '30,180', '28,760', '23,790']
# ['Temal', 'Rural Municipality', 'Tēmāla', 'तेमाल गाउँपालिका', '26,362', '22,712', '16,957']
# ['Aiselukharka', 'Rural Municipality', 'Aisēlukharka', 'ऐसेलुखर्क गाउँपालिका', '18,648', '16,098', '13,217']
# ['Barahapokhari', 'Rural Municipality', 'Varāhapōkharī', 'वराहपोखरी गाउँपालिका', '15,033', '14,349', '11,397']
# ['Diktel Rupakot Majhuwagadhi', 'Municipality', 'Diktēla Rupākōṭa Majhuvāgaḍhī', 'दिक्तेल रुपाकोट मझुवागढी नगरपालिका', '50,942', '47,860', '43,008']
# ['Diprung', 'Rural Municipality', 'Dipruṅa Cuicummā', 'दिप्रुङ चुइचुम्मा गाउँपालिका', '...', '19,392', '16,305']
# ['Halesi Tuwachung', 'Municipality', 'Halēsī Tuvācuṅa', 'हलेसी तुवाचुङ नगरपालिका', '30,863', '29,575', '27,078']
# ['Jantedhunga', 'Rural Municipality', 'Jantēḍhuṅgā', 'जन्तेढुंगा गाउँपालिका', '17,881', '15,519', '12,016']
# ['Kepilasgadhi', 'Rural Municipality', 'Kēpilāsagaḍhī', 'केपिलासगढी गाउँपालिका', '...', '16,071', '13,231']
# ['Khotehang', 'Rural Municipality', 'Khōṭēhāṅa', 'खोटेहाङ गाउँपालिका', '26,327', '22,485', '16,846']
# ['Rawa Besi [Lamidanda]', 'Rural Municipality', 'Rāvā Bēsī', 'रावा बेसी गाउँपालिका', '15,340', '13,369', '11,199']
# ['Sakela', 'Rural Municipality', 'Sākēlā', 'साकेला गाउँपालिका', '14,185', '11,594', '9,623']
# ['Bagmati', 'Rural Municipality', 'Bāgamatī', 'बागमती गाउँपालिका', '14,155', '13,049', '11,353']
# ['Godawari', 'Municipality', 'Gōdāvarī', 'गोदावरी नगरपालिका', '66,240', '80,376', '97,633']
# ['Konjyosom', 'Rural Municipality', 'Kōnjyōsōma', 'कोन्ज्योसोम गाउँपालिका', '9,871', '9,709', '8,989']
# ['Lalitpur', 'Metropolis', 'Lalitapura', 'ललितपुर महानगरपालिका', '200,020', '292,848', '294,098']
# ['Mahalaxmi', 'Municipality', 'Mahālakṣmī', 'महालक्ष्मी नगरपालिका', '35,802', '62,624', '123,116']
# ['Mahankal', 'Rural Municipality', 'Mahāṅkāla', 'महाङ्काल गाउँपालिका', '10,539', '9,526', '8,122']
# ['Besishahar', 'Municipality', 'Bēsīsahara', 'बेसीसहर नगरपालिका', '...', '40,599', '38,232']
# ['Dordi', 'Rural Municipality', 'Dōrdī', 'दोर्दी गाउँपालिका', '...', '18,252', '16,050']
# ['Dudhpokhari', 'Rural Municipality', 'Dūdhapōkharī', 'दूधपोखरी गाउँपालिका', '13,814', '10,975', '8,592']
# ['Kwholasothar', 'Rural Municipality', 'Kvhōlāsōthāra', 'क्व्होलासोथार गाउँपालिका', '...', '10,067', '7,960']
# ['Madhyanepal', 'Municipality', 'Madhyanēpāla', 'मध्यनेपाल नगरपालिका', '25,675', '23,474', '21,971']
# ['Marsyangdi', 'Rural Municipality', 'Marsyāṅadī', 'मर्स्याङदी गाउँपालिका', '20,475', '18,811', '17,080']
# ['Rainas', 'Municipality', 'Rāīnāsa', 'राईनास नगरपालिका', '20,161', '18,527', '17,402']
# ['Sundarbazar', 'Municipality', 'Sundarabajāra', 'सुन्दरबजार नगरपालिका', '26,890', '27,019', '27,043']
# ['Aurahi', 'Municipality', 'Aurahī', 'औरही नगरपालिका', '...', '31,851', '37,361']
# ['Balwa', 'Municipality', 'Balavā', 'बलवा नगरपालिका', '38,863', '42,368', '49,473']
# ['Bardibas', 'Municipality', 'Bardibāsa', 'बर्दिबास नगरपालिका', '57,008', '64,721', '74,361']
# ['Bhangaha', 'Municipality', 'Bhãgāhā', 'भँगाहा नगरपालिका', '42,612', '46,832', '55,354']
# ['Ekdara', 'Rural Municipality', 'Ēkaḍārā', 'एकडारा गाउँपालिका', '25,195', '29,315', '31,770']
# ['Gaushala', 'Municipality', 'Gauśālā', 'गौशाला नगरपालिका', '56,182', '66,715', '72,481']
# ['Jaleshwar', 'Municipality', 'Jalēśvara', 'जलेश्वर नगरपालिका', '51,838', '59,261', '63,802']
# ['Loharpatti', 'Municipality', 'Lōhārapaṭṭī', 'लोहारपट्टी नगरपालिका', '36,884', '39,883', '45,773']
# ['Mahottari', 'Rural Municipality', 'Mahōttarī', 'महोत्तरी गाउँपालिका', '26,343', '27,430', '28,807']
# ['Manra Shisawa', 'Municipality', 'Manarā Śisavā', 'मनरा शिसवा नगरपालिका', '44,263', '49,692', '52,191']
# ['Matihani', 'Municipality', 'Maṭihānī', 'मटिहानी नगरपालिका', '26,542', '31,026', '36,136']
# ['Pipra', 'Rural Municipality', 'Piparā', 'पिपरा गाउँपालिका', '32,874', '35,524', '40,535']
# ['Ramgopalpur', 'Municipality', 'Rāmagōpālapura', 'रामगोपालपुर नगरपालिका', '...', '30,412', '36,201']
# ['Samsi', 'Rural Municipality', 'Sāmsī', 'साम्सी गाउँपालिका', '29,451', '33,803', '38,585']
# ['Sonma', 'Rural Municipality', 'Sōnamā', 'सोनमा गाउँपालिका', '31,925', '38,747', '43,082']
# ['Bagmati', 'Rural Municipality', 'Bāgmati', 'बाग्मति गाउँपालिका', '30,677', '30,587', '30,425']
# ['Bakaiya', 'Rural Municipality', 'Bakaiyā', 'बकैया गाउँपालिका', '39,846', '39,642', '40,907']
# ['Bhimphedi', 'Rural Municipality', 'Bhīmaphēdī', 'भीमफेदी गाउँपालिका', '...', '24,960', '21,516']
# ['Chitawan National Park', 'National Park', 'Citavana Rāṣṭriya Nikuñja', 'चितवन राष्ट्रिय निकुञ्ज', '0', '0', '0']
# ['Hetauda', 'Sub-Metropolis', 'Hēṭauṇḍā', 'हेटौंडा उपमहानगरपालिका', '129,872', '154,660', '193,576']
# ['Indrasarowar', 'Rural Municipality', 'Indrasarōvara', 'इन्द्रसरोवर गाउँपालिका', '15,325', '13,891', '13,534']
# ['Kailash', 'Rural Municipality', 'Kailāśa', 'कैलाश गाउँपालिका', '...', '23,922', '21,856']
# ['Makawanpurgadhi', 'Rural Municipality', 'Makavānapuragaḍhī', 'मकवानपुरगढी गाउँपालिका', '26,959', '25,379', '24,461']
# ['Manahari', 'Rural Municipality', 'Manaharī', 'मनहरी गाउँपालिका', '...', '39,122', '47,353']
# ['Parsa Wildlife Reserve', 'Wildlife Reserve', 'Parsā Vanyajantu Ārakṣa', 'पर्सा वन्यजन्तु आरक्ष', '0', '0', '0']
# ['Raksirang', 'Rural Municipality', 'Rāksirāṅga', 'राक्सिराङ्ग गाउँपालिका', '25,675', '26,192', '25,996']
# ['Thaha', 'Municipality', 'Thāhā', 'थाहा नगरपालिका', '42,230', '42,122', '38,870']
# ['Chame', 'Rural Municipality', 'Cāmē', 'चामे गाउँपालिका', '...', '1,476', '1,276']
# ['Manang Ngisyang [Neshyang]', 'Rural Municipality', 'Manāṅa Ṅisyāṅa', 'मनाङ ङिस्याङ गाउँपालिका', '...', '2,414', '1,595']
# ['Narpa Bhumi [Narphu]', 'Rural Municipality', 'Nārpā Bhūmi', 'नार्पा भूमि गाउँपालिका', '...', '554', '396']
# ['Nasong', 'Rural Municipality', 'Nāśōṅa', 'नाशोङ गाउँपालिका', '...', '2,094', '1,671']
# ['Belbari', 'Municipality', 'Bēlavārī', 'बेलवारी नगरपालिका', '58,397', '65,974', '81,771']
# ['Biratnagar', 'Metropolis', 'Virāṭanagara', 'विराटनगर महानगरपालिका', '...', '218,526', '243,927']
# ['Budhiganga', 'Rural Municipality', 'Buḍhīgaṅgā', 'बुढीगंगा गाउँपालिका', '34,193', '41,971', '51,497']
# ['Dhanpalthan', 'Rural Municipality', 'Dhanapālathāna', 'धनपालथान गाउँपालिका', '35,217', '39,470', '45,348']
# ['Gramthan', 'Rural Municipality', 'Grāmathāna', 'ग्रामथान गाउँपालिका', '31,374', '32,717', '36,024']
# ['Jahada', 'Rural Municipality', 'Jahadā', 'जहदा गाउँपालिका', '...', '41,819', '47,639']
# ['Kanepokhari', 'Rural Municipality', 'Kānēpōkharī', 'कानेपोखरी गाउँपालिका', '37,359', '38,041', '43,193']
# ['Katahari', 'Rural Municipality', 'Kaṭaharī', 'कटहरी गाउँपालिका', '32,539', '39,775', '48,510']
# ['Kerabari', 'Rural Municipality', 'Kērāvārī', 'केरावारी गाउँपालिका', '...', '30,918', '34,504']
# ['Letang', 'Municipality', 'Lēṭāṅa', 'लेटाङ नगरपालिका', '...', '32,782', '38,152']
# ['Miklajung', 'Rural Municipality', 'Miklājuṅa', 'मिक्लाजुङ गाउँपालिका', '...', '28,709', '33,167']
# ['Pathari Shanishchare', 'Municipality', 'Patharī Śaniścarē', 'पथरी शनिश्चरे नगरपालिका', '56,012', '61,132', '72,451']
# ['Rangeli', 'Municipality', 'Raṅgēlī', 'रंगेली नगरपालिका', '51,186', '51,357', '57,494']
# ['Ratuwamai', 'Municipality', 'Ratuvāmāī', 'रतुवामाई नगरपालिका', '...', '55,418', '61,139']
# ['Sunawarshi', 'Municipality', 'Sunavarṣi', 'सुनवर्षि नगरपालिका', '...', '51,444', '56,034']
# ['Sundarharaicha', 'Municipality', 'Sundaraharaicā', 'सुन्दरहरैचा नगरपालिका', '62,221', '80,621', '120,213']
# ['Urlabari', 'Municipality', 'Urlāvārī', 'उर्लावारी नगरपालिका', '...', '54,696', '70,908']
# ['Chhayanath Rara', 'Municipality', 'Chāyā̃nātha Rārā', 'छायाँनाथ रारा नगरपालिका', '...', '20,457', '24,527']
# ['Khatyad', 'Rural Municipality', 'Khatyāḍa', 'खत्याड गाउँपालिका', '12,326', '17,146', '18,832']
# ['Mugum Karmarong', 'Rural Municipality', 'Muguma Kārmārōṅga', 'मुगुम कार्मारोंग गाउँपालिका', '5,105', '5,423', '6,222']
# ['Soru', 'Rural Municipality', 'Sōru', 'सोरु गाउँपालिका', '...', '12,260', '14,277']
# ['Gharapjhong', 'Rural Municipality', 'Gharapajhōṅa', 'घरपझोङ गाउँपालिका', '...', '3,736', '3,712']
# ['Lo-Ghekar Damodarkunda [Dalome]', 'Rural Municipality', 'Lokeghara Dāmodarakuṇḍa', 'लोकेघर दामोदरकुण्ड गाउँपालिका', '...', '1,569', '1,292']
# ['Lomanthang', 'Rural Municipality', 'Lōmanthāṅa', 'लोमन्थाङ गाउँपालिका', '...', '2,350', '1,430']
# ['Thasang', 'Rural Municipality', 'Thāsāṅa', 'थासाङ गाउँपालिका', '...', '3,093', '2,856']
# ['Varagung Muktikshetra', 'Rural Municipality', 'Vārāguṅa Muktikṣētra', 'वारागुङ मुक्तिक्षेत्र गाउँपालिका', '...', '2,704', '2,036']
# ['Annapurna', 'Rural Municipality', 'Annapurṇa', 'अन्नपुर्ण गाउँपालिका', '...', '13,337', '12,323']
# ['Beni', 'Municipality', 'Bēnī', 'बेनी नगरपालिका', '...', '34,878', '32,697']
# ['Dhaulagiri', 'Rural Municipality', 'Dhavalāgirī', 'धवलागिरी गाउँपालिका', '14,754', '14,112', '12,616']
# ['Dhorpatan Hunting Reserve', 'Hunting Reserve', 'Ḍhōrapāṭana Śikāra Ārakṣa', 'ढोरपाटन शिकार आरक्ष', '0', '0', '0']
# ['Malika', 'Rural Municipality', 'Mālikā', 'मालिका गाउँपालिका', '...', '19,208', '18,332']
# ['Mangala', 'Rural Municipality', 'Maṅgalā', 'मंगला गाउँपालिका', '...', '16,334', '14,688']
# ['Raghuganga', 'Rural Municipality', 'Raghugaṅgā', 'रघुगंगा गाउँपालिका', '17,984', '15,772', '14,114']
# ['Baudikali', 'Rural Municipality', 'Baudīkālī', 'बौदीकाली गाउँपालिका', '...', '15,734', '11,338']
# ['Binayi Tribeni', 'Rural Municipality', 'Vinayī Trivēṇī', 'विनयी त्रिवेणी गाउँपालिका', '...', '33,119', '38,370']
# ['Bulingtar', 'Rural Municipality', 'Buliṅaṭāra', 'बुलिङटार गाउँपालिका', '...', '19,122', '14,637']
# ['Chitawan National Park', 'National Park', 'Citavana Rāṣṭriya Nikuñja', 'चितवन राष्ट्रिय निकुञ्ज', '0', '0', '0']
# ['Devchuli', 'Municipality', 'Dēvaculī', 'देवचुली नगरपालिका', '36,301', '42,667', '58,003']
# ['Gaindakot', 'Municipality', 'Gaiṇḍākōṭa', 'गैंडाकोट नगरपालिका', '43,060', '58,890', '79,349']
# ['Hupsekot', 'Rural Municipality', 'Hupsēkōṭa', 'हुप्सेकोट गाउँपालिका', '22,378', '25,065', '26,583']
# ['Kawasoti', 'Municipality', 'Kāvāsōtī', 'कावासोती नगरपालिका', '51,413', '62,583', '86,821']
# ['Madhyabindu', 'Municipality', 'Madhyabindu', 'मध्यबिन्दु नगरपालिका', '...', '54,424', '61,091']
# ['Belkotgadhi', 'Municipality', 'Bēlakōṭagaḍhī', 'बेलकोटगढी नगरपालिका', '...', '40,706', '35,224']
# ['Bidur', 'Municipality', 'Bidura', 'बिदुर नगरपालिका', '...', '55,650', '59,227']
# ['Dupcheshwar', 'Rural Municipality', 'Dupcēśvara', 'दुप्चेश्वर गाउँपालिका', '21,110', '22,106', '21,005']
# ['Kakani', 'Rural Municipality', 'Kakanī', 'ककनी गाउँपालिका', '...', '26,509', '24,504']
# ['Kispang', 'Rural Municipality', 'Kispāṅa', 'किस्पाङ गाउँपालिका', '15,578', '14,861', '14,235']
# ['Langtang National Park', 'National Park', 'Lāṅaṭāṅa Rāṣṭriya Nikuñja', 'लाङटाङ राष्ट्रिय निकुञ्ज', '0', '0', '0']
# ['Likhu', 'Rural Municipality', 'Likhu', 'लिखु गाउँपालिका', '...', '16,966', '17,728']
# ['Meghang', 'Rural Municipality', 'Myagaṅa', 'म्यगङ गाउँपालिका', '15,194', '13,484', '12,668']
# ['Panchkanya', 'Rural Municipality', 'Pañcakanyā', 'पञ्चकन्या गाउँपालिका', '...', '15,945', '13,818']
# ['Shivapuri', 'Rural Municipality', 'Śivapurī', 'शिवपुरी गाउँपालिका', '25,119', '20,783', '17,203']
# ['Shivapuri Nagarjuna National Park', 'National Park', 'Śivapurī Nāgārjuna Rāṣṭriya Nikuñja', 'शिवपुरी नागार्जुन राष्ट्रिय निकुञ्ज', '0', '0', '0']
# ['Suryagadhi', 'Rural Municipality', 'Suryagaḍhī', 'सुर्यगढी गाउँपालिका', '17,328', '16,800', '14,919']
# ['Tadi', 'Rural Municipality', 'Tādī', 'तादी गाउँपालिका', '18,785', '17,942', '15,933']
# ['Tarkeshwar', 'Rural Municipality', 'Tārakēśvara', 'तारकेश्वर गाउँपालिका', '...', '15,719', '14,184']
# ['Champadevi', 'Rural Municipality', 'Campādēvī', 'चम्पादेवी गाउँपालिका', '19,058', '18,661', '16,311']
# ['Chishankhugadhi', 'Rural Municipality', 'Ciśaṅkhugaḍhī', 'चिशंखुगढी गाउँपालिका', '17,978', '15,206', '13,844']
# ['Khijidemba', 'Rural Municipality', 'Khijidēmbā', 'खिजिदेम्बा गाउँपालिका', '...', '15,291', '15,559']
# ['Likhu', 'Rural Municipality', 'Likhu', 'लिखु गाउँपालिका', '...', '14,057', '12,104']
# ['Manebhanjyang', 'Rural Municipality', 'Mānēbhañjyāṅa', 'मानेभञ्ज्याङ गाउँपालिका', '22,094', '21,093', '19,597']
# ['Molung', 'Rural Municipality', 'Mōluṅa', 'मोलुङ गाउँपालिका', '...', '16,274', '16,440']
# ['Siddhicharan', 'Municipality', 'Siddhicaraṇa', 'सिद्धिचरण नगरपालिका', '...', '28,844', '27,351']
# ['Sunkoshi', 'Rural Municipality', 'Sunakōśī', 'सुनकोशी गाउँपालिका', '19,431', '18,558', '17,783']
# ...
# ['Savahapokhari', 'Rural Municipality', 'Sabhāpōkharī', 'सभापोखरी गाउँपालिका', '11,231', '10,492', '9,970']
# ['Silichong', 'Rural Municipality', 'Silīcōṅa', 'सिलीचोङ गाउँपालिका', '...', '11,812', '10,296']
# ['Agnisair Krishnasawaran', 'Rural Municipality', 'Agnisāira Kr̥ṣṇāsaravana', 'अग्निसाइर कृष्णासरवन गाउँपालिका', '...', '27,129', '31,634']
# ['Balan-Bihul', 'Rural Municipality', 'Valāna-Vihula', 'वलान-विहुल गाउँपालिका', '...', '21,842', '23,527']
# ['Bishnupur', 'Rural Municipality', 'Viṣṇupura', 'विष्णुपुर गाउँपालिका', '...', '23,166', '27,703']
# ['Bodebarsain', 'Municipality', 'Bōdēbarasāina', 'बोदेबरसाइन नगरपालिका', '...', '43,293', '46,017']
# ['Chhinnamasta', 'Rural Municipality', 'Chinnamastā', 'छिन्नमस्ता गाउँपालिका', '25,054', '28,437', '29,946']
# ['Dakneshwori', 'Municipality', 'Ḍāknēśvōrī', 'डाक्नेश्वोरी नगरपालिका', '39,258', '42,833', '47,739']
# ['Hanumannagar Kankalini', 'Municipality', 'Hanumānanagara Kaṅkālinī', 'हनुमाननगर कंकालिनी नगरपालिका', '39,199', '45,840', '52,796']
# ['Kanchanrup', 'Municipality', 'Kañcanarūpa', 'कञ्चनरूप नगरपालिका', '47,099', '53,366', '58,466']
# ['Khadak', 'Municipality', 'Khaḍaka', 'खडक नगरपालिका', '...', '45,428', '52,778']
# ['Koshi Tappu Wildlife Reserve', 'Wildlife Reserve', 'Kōśī Ṭappu Vanyajantu Ārakṣa', 'कोशी टप्पु वन्यजन्तु आरक्ष', '0', '0', '0']
# ['Mahadeva', 'Rural Municipality', 'Mahādēvā', 'महादेवा गाउँपालिका', '25,419', '28,542', '30,315']
# ['Rajbiraj', 'Municipality', 'Rājavirāja', 'राजविराज नगरपालिका', '...', '68,899', '70,803']
# ['Rajgadh [Belhi Chapena]', 'Rural Municipality', 'Rājagaḍha', 'राजगढ गाउँपालिका', '...', '29,498', '32,462']
# ['Rupani', 'Rural Municipality', 'Rupanī', 'रुपनी गाउँपालिका', '...', '26,490', '29,877']
# ['Saptakoshi', 'Municipality', 'Saptakōśī', 'सप्तकोशी नगरपालिका', '19,197', '21,237', '23,510']
# ['Shambhunath', 'Municipality', 'Śambhunātha', 'शम्भुनाथ नगरपालिका', '30,746', '35,222', '39,634']
# ['Surunga', 'Municipality', 'Suruṅgā', 'सुरुङ्गा नगरपालिका', '...', '44,222', '49,460']
# ['Tilathi Koiladi', 'Rural Municipality', 'Tilāṭhī Kōīlāḍī', 'तिलाठी कोईलाडी गाउँपालिका', '...', '31,803', '33,658']
# ['Tirhut', 'Rural Municipality', 'Tirahuta', 'तिरहुत गाउँपालिका', '20,780', '22,037', '24,034']
# ['Bagmati', 'Municipality', 'Bāgamatī', 'बागमती नगरपालिका', '...', '40,399', '47,106']
# ['Balra', 'Municipality', 'Balarā', 'बलरा नगरपालिका', '...', '45,194', '47,912']
# ['Barhathawa', 'Municipality', 'Barahathavā', 'बरहथवा नगरपालिका', '...', '69,822', '81,120']
# ['Basbariya', 'Rural Municipality', 'Basabarīyā', 'बसबरीया गाउँपालिका', '18,872', '23,568', '25,905']
# ['Bishnu', 'Rural Municipality', 'Viṣṇu', 'विष्णु गाउँपालिका', '...', '24,748', '28,570']
# ['Brahmapuri', 'Rural Municipality', 'Brahmapurī', 'ब्रह्मपुरी गाउँपालिका', '24,905', '29,832', '31,378']
# ['Chakraghatta', 'Rural Municipality', 'Cakraghaṭṭā', 'चक्रघट्टा गाउँपालिका', '22,951', '27,952', '29,550']
# ['Chandranagar', 'Rural Municipality', 'Candranagara', 'चन्द्रनगर गाउँपालिका', '26,179', '33,345', '36,908']
# ['Dhankaul', 'Rural Municipality', 'Dhanakaula', 'धनकौल गाउँपालिका', '...', '24,788', '27,974']
# ['Godaita', 'Municipality', 'Gōḍaiṭā', 'गोडैटा नगरपालिका', '39,130', '47,687', '54,270']
# ['Haripur', 'Municipality', 'Haripura', 'हरिपुर नगरपालिका', '...', '37,445', '43,233']
# ['Haripurwa', 'Municipality', 'Haripurvā', 'हरिपुर्वा नगरपालिका', '...', '36,042', '38,714']
# ['Hariwan', 'Municipality', 'Harivana', 'हरिवन नगरपालिका', '...', '43,924', '49,988']
# ['Ishworpur', 'Municipality', 'Īśvarapura', 'ईश्वरपुर नगरपालिका', '51,243', '60,000', '68,377']
# ['Kaudena', 'Rural Municipality', 'Kauḍēnā', 'कौडेना गाउँपालिका', '21,182', '26,085', '28,702']
# ['Kawilasi', 'Municipality', 'Kavilāsī', 'कविलासी नगरपालिका', '34,495', '42,336', '44,204']
# ['Lalbandi', 'Municipality', 'Lālabandī', 'लालबन्दी नगरपालिका', '51,448', '59,628', '66,419']
# ['Malangwa', 'Municipality', 'Malaṅvā', 'मलङ्वा नगरपालिका', '36,380', '46,557', '54,550']
# ['Parsa', 'Rural Municipality', 'Parsā', 'पर्सा गाउँपालिका', '16,905', '21,650', '24,005']
# ['Ramnagar', 'Rural Municipality', 'Rāmanagara', 'रामनगर गाउँपालिका', '...', '28,727', '31,366']
# ['Dudhauli', 'Municipality', 'Dudhaulī', 'दुधौली नगरपालिका', '59,545', '65,644', '70,207']
# ['Ghyanglekh', 'Rural Municipality', 'Ghyāṅalēkha', 'घ्याङलेख गाउँपालिका', '13,781', '13,761', '12,652']
# ['Golanjor', 'Rural Municipality', 'Gōlanjara', 'गोलन्जर गाउँपालिका', '19,184', '19,490', '18,737']
# ['Hariharpurgadhi', 'Rural Municipality', 'Hariharapuragaḍhī', 'हरिहरपुरगढी गाउँपालिका', '26,214', '27,727', '26,505']
# ['Kamalamai', 'Municipality', 'Kamalāmāī', 'कमलामाई नगरपालिका', '58,485', '66,391', '71,016']
# ['Marin', 'Rural Municipality', 'Mariṇa', 'मरिण गाउँपालिका', '25,108', '27,822', '28,808']
# ['Phikkal', 'Rural Municipality', 'Phikkala', 'फिक्कल गाउँपालिका', '16,788', '16,968', '15,910']
# ['Sunkoshi', 'Rural Municipality', 'Sunakōśī', 'सुनकोशी गाउँपालिका', '...', '21,969', '18,375']
# ['Tinpatan', 'Rural Municipality', 'Tīnapāṭana', 'तीनपाटन गाउँपालिका', '34,801', '36,420', '34,889']
# ['Bahrabise', 'Municipality', 'Bāhrabisē', 'बाह्रबिसे नगरपालिका', '...', '26,960', '24,109']
# ['Balephi', 'Rural Municipality', 'Balēphī', 'बलेफी गाउँपालिका', '20,191', '19,084', '17,085']
# ['Bhotekoshi', 'Rural Municipality', 'Bhōṭēkōśī', 'भोटेकोशी गाउँपालिका', '15,176', '16,772', '14,318']
# ['Chautara Sangachokgadhi', 'Municipality', 'Cautārā Sā̃gācōkagaḍhī', 'चौतारा साँगाचोकगढी नगरपालिका', '49,159', '47,104', '42,668']
# ['Helambu', 'Rural Municipality', 'Hēlambu', 'हेलम्बु गाउँपालिका', '19,571', '17,964', '17,497']
# ['Indrawati', 'Rural Municipality', 'Īndrāvatī', 'ईन्द्रावती गाउँपालिका', '31,177', '28,544', '25,365']
# ['Jugal', 'Rural Municipality', 'Jugala', 'जुगल गाउँपालिका', '19,837', '19,231', '18,303']
# ['Lisankhu Pakhar', 'Rural Municipality', 'Lisaṅkhu Pākhara', 'लिसङ्खु पाखर गाउँपालिका', '12,656', '15,144', '11,750']
# ['Melamchi', 'Municipality', 'Mēlamcī', 'मेलम्ची नगरपालिका', '47,290', '45,473', '41,063']
# ['Panchpokhari Thangpal', 'Rural Municipality', 'Pā̃capōkharī Thāṅapāla', 'पाँचपोखरी थाङपाल गाउँपालिका', '22,127', '20,986', '20,997']
# ['Sunkoshi', 'Rural Municipality', 'Sunakōśī', 'सुनकोशी गाउँपालिका', '20,294', '17,311', '15,176']
# ['Tripurasundari', 'Rural Municipality', 'Tripurāsundarī', 'त्रिपुरासुन्दरी गाउँपालिका', '...', '13,225', '12,014']
# ['Arnama', 'Rural Municipality', 'Arnamā', 'अर्नमा गाउँपालिका', '21,158', '22,912', '27,899']
# ['Aurahi', 'Rural Municipality', 'Aurahī', 'औरही गाउँपालिका', '21,629', '23,084', '26,478']
# ['Bariyarpatti', 'Rural Municipality', 'Bariyārapaṭṭī', 'बरियारपट्टी गाउँपालिका', '22,317', '25,313', '29,712']
# ['Bhagwanpur', 'Rural Municipality', 'Bhagavānapura', 'भगवानपुर गाउँपालिका', '17,468', '20,999', '23,380']
# ['Bishnupur', 'Rural Municipality', 'Viṣṇupura', 'विष्णुपुर गाउँपालिका', '17,144', '18,543', '22,781']
# ['Dhangadhimai', 'Municipality', 'Dhanagaḍhīmāī', 'धनगढीमाई नगरपालिका', '42,337', '47,449', '53,355']
# ['Golbazar', 'Municipality', 'Gōlabajāra', 'गोलबजार नगरपालिका', '47,208', '52,137', '63,885']
# ['Kalyanpur', 'Municipality', 'Kalyāṇapura', 'कल्याणपुर नगरपालिका', '45,812', '49,344', '58,872']
# ['Karjanha', 'Municipality', 'Karjanhā', 'कर्जन्हा नगरपालिका', '26,346', '31,357', '38,557']
# ['Lahan', 'Municipality', 'Lahāna', 'लहान नगरपालिका', '81,918', '92,040', '102,031']
# ['Laksmipur Patari', 'Rural Municipality', 'Lakṣmīpura Patārī', 'लक्ष्मीपुर पतारी गाउँपालिका', '...', '28,073', '31,118']
# ['Mirchaiya', 'Municipality', 'Mircaiyā', 'मिर्चैया नगरपालिका', '...', '49,131', '59,425']
# ['Naraha', 'Rural Municipality', 'Narahā', 'नरहा गाउँपालिका', '16,834', '19,369', '22,760']
# ['Nawarajpur', 'Rural Municipality', 'Navarājapura', 'नवराजपुर गाउँपालिका', '16,636', '19,056', '20,788']
# ['Sakhuwanankarkatti', 'Rural Municipality', 'Sakhuvānānkārakaṭṭī', 'सखुवानान्कारकट्टी गाउँपालिका', '16,778', '18,574', '20,844']
# ['Siraha', 'Municipality', 'Sirāhā', 'सिराहा नगरपालिका', '75,171', '82,920', '95,410']
# ['Sukhipur', 'Municipality', 'Sukhipura', 'सुखिपुर नगरपालिका', '34,771', '37,027', '42,033']
# ['Dudhkoshi', 'Rural Municipality', 'Dudhakōśī', 'दुधकोशी गाउँपालिका', '...', '13,420', '12,648']
# ['Khumbu Pasanglhamu', 'Rural Municipality', 'Khumbu Pāsāṅalhāmu', 'खुम्बु पासाङल्हामु गाउँपालिका', '...', '9,133', '8,720']
# ['Likhupike', 'Rural Municipality', 'Likhupikē', 'लिखुपिके गाउँपालिका', '...', '5,534', '5,334']
# ['Mahakulung', 'Rural Municipality', 'Māhākuluṅa', 'माहाकुलुङ गाउँपालिका', '...', '11,452', '11,847']
# ['Nechasalyan', 'Rural Municipality', 'Nēcāsalyāna', 'नेचासल्यान गाउँपालिका', '17,366', '16,149', '11,381']
# ['Solududhkunda', 'Municipality', 'Sōlududhakuṇḍa', 'सोलुदुधकुण्ड नगरपालिका', '...', '20,977', '25,678']
# ['Sotang', 'Rural Municipality', 'Sōtāṅa', 'सोताङ गाउँपालिका', '...', '9,530', '9,025']
# ['Thulung Dudhkoshi', 'Rural Municipality', 'Thuluṅa Dudhakōśī', 'थुलुङ दुधकोशी गाउँपालिका', '20,938', '19,691', '18,354']
# ['Barah', 'Municipality', 'Barāhakṣētra', 'बराहक्षेत्र नगरपालिका', '71,327', '77,604', '91,087']
# ['Barju', 'Rural Municipality', 'Barju', 'बर्जु गाउँपालिका', '27,908', '31,180', '36,249']
# ['Bhokraha', 'Rural Municipality', 'Bhōkrāhā Narasiṃha', 'भोक्राहा नरसिंह  गाउँपालिका', '33,928', '40,636', '49,280']
# ['Dewanganj', 'Rural Municipality', 'Dēvānagañja', 'देवानगञ्ज गाउँपालिका', '31,222', '35,283', '39,030']
# ['Dharan', 'Sub-Metropolis', 'Dharāna', 'धरान उपमहानगरपालिका', '114,571', '141,439', '166,531']
# ['Duhabi', 'Municipality', 'Duhabī', 'दुहबी नगरपालिका', '49,008', '56,573', '66,074']
# ['Gadhi', 'Rural Municipality', 'Gaḍhī', 'गढी गाउँपालिका', '32,498', '34,852', '38,739']
# ['Harinagara', 'Rural Municipality', 'Harinagarā', 'हरिनगरा गाउँपालिका', '36,190', '41,070', '49,845']
# ['Inaruwa', 'Municipality', 'Inarūvā', 'इनरूवा नगरपालिका', '...', '64,749', '74,914']
# ['Itahari', 'Sub-Metropolis', 'Iṭaharī', 'इटहरी उपमहानगरपालिका', '90,364', '143,786', '197,241']
# ['Koshi', 'Rural Municipality', 'Kōśī', 'कोशी गाउँपालिका', '35,811', '43,987', '48,804']
# ['Koshi Tappu Wildlife Reserve', 'Wildlife Reserve', 'Kōśī Ṭappu Vanyajantu Ārakṣa', 'कोशी टप्पु वन्यजन्तु आरक्ष', '0', '0', '0']
# ['Ramdhuni', 'Municipality', 'Rāmadhunī', 'रामधुनी नगरपालिका', '...', '52,328', '63,452']
# ['Barahatal', 'Rural Municipality', 'Barāhatāla', 'बराहताल गाउँपालिका', '24,303', '26,820', '25,943']
# ['Bheriganga', 'Municipality', 'Bhērīgaṅgā', 'भेरीगंगा नगरपालिका', '...', '41,865', '48,203']
# ['Birendranagar', 'Municipality', 'Vīrēndranagara', 'वीरेन्द्रनगर नगरपालिका', '67,649', '105,107', '153,863']
# ['Chaukune', 'Rural Municipality', 'Caukunē', 'चौकुने गाउँपालिका', '23,072', '25,240', '26,950']
# ['Chingad', 'Rural Municipality', 'Ciṅgāḍa', 'चिङ्गाड गाउँपालिका', '15,633', '17,275', '15,600']
# ['Gurbhakot', 'Municipality', 'Gurbhākōṭa', 'गुर्भाकोट नगरपालिका', '39,484', '44,359', '48,216']
# ['Lekbeshi', 'Municipality', 'Lēkavēśī', 'लेकवेशी नगरपालिका', '...', '31,583', '31,710']
# ['Panchapuri', 'Municipality', 'Pañcapurī', 'पञ्चपुरी नगरपालिका', '26,911', '32,236', '35,839']
# ['Simta', 'Rural Municipality', 'Simtā', 'सिम्ता गाउँपालिका', '...', '26,319', '24,083']
# ['Aandhikhola', 'Rural Municipality', 'Ā̃dhīkhōlā', 'आँधीखोला गाउँपालिका', '...', '16,595', '13,094']
# ['Arjunchaupari', 'Rural Municipality', 'Arjunacaupārī', 'अर्जुनचौपारी गाउँपालिका', '...', '16,179', '14,045']
# ['Bhirkot', 'Municipality', 'Bhīrakōṭa', 'भीरकोट नगरपालिका', '...', '25,584', '22,645']
# ['Biruwa', 'Rural Municipality', 'Biruvā', 'बिरुवा गाउँपालिका', '...', '18,413', '14,001']
# ['Chapakot', 'Municipality', 'Cāpākōṭa', 'चापाकोट नगरपालिका', '29,400', '26,101', '22,969']
# ['Galyang', 'Municipality', 'Galyāṅa', 'गल्याङ नगरपालिका', '...', '37,821', '31,034']
# ['Harinas', 'Rural Municipality', 'Harināsa', 'हरिनास गाउँपालिका', '...', '17,343', '13,191']
# ['Kaligandaki', 'Rural Municipality', 'Kālīgaṇḍakī', 'कालीगण्डकी गाउँपालिका', '26,598', '21,824', '17,955']
# ['Phedikhola', 'Rural Municipality', 'Phēdīkhōlā', 'फेदीखोला गाउँपालिका', '13,885', '12,341', '10,899']
# ['Putalibazar', 'Municipality', 'Putalībajāra', 'पुतलीबजार नगरपालिका', '...', '45,510', '41,743']
# ['Waling', 'Municipality', 'Vāliṅa', 'वालिङ नगरपालिका', '...', '51,437', '50,488']
# ['Anbukhaireni', 'Rural Municipality', 'Ā̃bukhairēnī', 'आँबुखैरेनी गाउँपालिका', '18,489', '20,840', '22,252']
# ['Bandipur', 'Rural Municipality', 'Bandīpura', 'बन्दीपुर गाउँपालिका', '...', '20,077', '18,532']
# ['Bhanu', 'Municipality', 'Bhānu', 'भानु नगरपालिका', '...', '46,179', '42,794']
# ['Bhimad', 'Municipality', 'Bhimāda', 'भिमाद नगरपालिका', '...', '31,362', '29,248']
# ['Devghat', 'Rural Municipality', 'Dēvaghāṭa', 'देवघाट गाउँपालिका', '...', '16,478', '14,584']
# ['Ghiring', 'Rural Municipality', 'Ghiriṅa', 'घिरिङ गाउँपालिका', '...', '19,318', '14,334']
# ['Myagde', 'Rural Municipality', 'Myāgdē', 'म्याग्दे गाउँपालिका', '23,370', '22,502', '23,578']
# ['Rhishing', 'Rural Municipality', 'R̥ṣiṅga', 'ऋषिङ्ग गाउँपालिका', '...', '25,870', '17,918']
# ['Shuklagandaki', 'Municipality', 'Śuklagaṇḍakī', 'शुक्लगण्डकी नगरपालिका', '...', '49,611', '55,620']
# ['Vyas', 'Municipality', 'Vyāsa', 'व्यास नगरपालिका', '...', '71,051', '78,939']
# ['Aathrai Tribeni', 'Rural Municipality', 'Āṭharāī Trivēṇī', 'आठराई त्रिवेणी गाउँपालिका', '15,978', '13,784', '12,296']
# ['Maiwakhola', 'Rural Municipality', 'Maivākhōlā', 'मैवाखोला गाउँपालिका', '12,485', '11,094', '10,213']
# ['Meringden', 'Rural Municipality', 'Mēriṅadēna', 'मेरिङदेन गाउँपालिका', '...', '13,284', '11,838']
# ['Mikwakhola', 'Rural Municipality', 'Mikvākhōlā', 'मिक्वाखोला गाउँपालिका', '9,561', '9,160', '7,964']
# ['Pathibhara Yangwarak', 'Rural Municipality', 'Pāthībharā Yāṅavaraka', 'पाथीभरा याङवरक गाउँपालिका', '15,509', '13,591', '11,806']
# ['Phaktanglung', 'Rural Municipality', 'Phaktāṅaluṅa', 'फक्ताङलुङ गाउँपालिका', '12,938', '12,017', '11,791']
# ['Phungling', 'Municipality', 'Phuṅaliṅa', 'फुङलिङ नगरपालिका', '23,651', '26,626', '28,449']
# ['Sidingwa', 'Rural Municipality', 'Sidiṅvā', 'सिदिङ्वा गाउँपालिका', '13,477', '12,099', '10,979']
# ['Sirijangha', 'Rural Municipality', 'Sirījaṅghā', 'सिरीजङ्घा गाउँपालिका', '17,134', '15,806', '14,114']
# ['Aathrai', 'Rural Municipality', 'Āṭharāī', 'आठराई गाउँपालिका', '25,374', '21,747', '18,156']
# ['Chhathar', 'Rural Municipality', 'Chathara', 'छथर गाउँपालिका', '19,398', '16,715', '14,197']
# ['Laligurans', 'Municipality', 'Lālīgurā̃sa', 'लालीगुराँस नगरपालिका', '18,205', '17,000', '15,329']
# ['Menchhayayem', 'Rural Municipality', 'Mēnchayāyēma', 'मेन्छयायेम गाउँपालिका', '9,694', '8,078', '6,678']
# ['Myanglung', 'Municipality', 'Myāṅaluṅa', 'म्याङलुङ नगरपालिका', '...', '20,337', '18,750']
# ['Phedap', 'Rural Municipality', 'Phēdāpa', 'फेदाप गाउँपालिका', '20,596', '17,700', '15,169']
# ['Belaka', 'Municipality', 'Bēlakā', 'बेलका नगरपालिका', '38,727', '42,450', '51,043']
# ['Chaudandigadhi', 'Municipality', 'Caudaṇḍīgaḍhī', 'चौदण्डीगढी नगरपालिका', '45,023', '48,750', '53,631']
# ['Katari', 'Municipality', 'Kaṭārī', 'कटारी नगरपालिका', '50,505', '56,545', '59,507']
# ['Koshi Tappu Wildlife Reserve', 'Wildlife Reserve', 'Kōśī Ṭappu Vanyajantu Ārakṣa', 'कोशी टप्पु वन्यजन्तु आरक्ष', '0', '0', '0']
# ['Limchungbung [Sunkoshi]', 'Rural Municipality', 'Limcuṅbuṅa', 'लिम्चुङ्बुङ गाउँपालिका', '13,800', '11,992', '9,689']
# ['Rautamai', 'Rural Municipality', 'Rautāmāī', 'रौतामाई गाउँपालिका', '23,113', '23,481', '20,324']
# ['Tapli', 'Rural Municipality', 'Tāplī', 'ताप्ली गाउँपालिका', '14,643', '14,567', '13,344']
# ['Triyuga', 'Municipality', 'Triyugā', 'त्रियुगा नगरपालिका', '71,131', '88,967', '102,725']
# ['Udayapurgadhi', 'Rural Municipality', 'Udayapuragaḍhī', 'उदयपुरगढी गाउँपालिका', '29,741', '30,780', '28,926']
# ['Aathbiskot', 'Municipality', 'Āṭhavisakōṭa', 'आठविसकोट नगरपालिका', '...', '33,624', '35,917']
# ['Banphikot', 'Rural Municipality', 'Bā̃phikōṭa', 'बाँफिकोट गाउँपालिका', '...', '18,696', '21,033']
# ['Chaurjahari', 'Municipality', 'Caurajahārī', 'चौरजहारी नगरपालिका', '...', '27,583', '28,956']
# ['Musikot', 'Municipality', 'Musikōṭa', 'मुसिकोट नगरपालिका', '...', '33,882', '34,270']
# ['Sani Bheri', 'Rural Municipality', 'Sānī Bhērī', 'सानी भेरी गाउँपालिका', '...', '22,194', '24,759']
# ['Triveni', 'Rural Municipality', 'Trivēṇī', 'त्रिवेणी गाउँपालिका', '...', '19,404', '20,525']

# %%
df.head()
# Out:
#            Name    Status Transcription             Native  \
# 0        Achham  District        Achāma        अछाम जिल्ला
# 1  Arghakhanchi  District   Arghākhā̃cī  अर्घाखाँची जिल्ला
# 2       Baglung  District      Bāgaluṅa      बागलुङ जिल्ला
# 3       Baitadi  District       Baitaḍī       बैतडी जिल्ला
# 4       Bajhang  District       Bajhāṅa        बझाङ जिल्ला
#
#   PopulationCensus2001-05-28 PopulationCensus2011-06-22  \
# 0                    231,285                    257,477
# 1                    208,391                    197,632
# 2                    268,937                    268,613
# 3                    234,418                    250,898
# 4                    167,026                    195,159
#
#   PopulationCensus2021-11-25
# 0                    228,852
# 1                    177,086
# 2                    249,211
# 3                    242,157
# 4                    189,085

# %%
df.tail()
# Out:
#             Name              Status Transcription                Native  \
# 845    Banphikot  Rural Municipality    Bā̃phikōṭa   बाँफिकोट गाउँपालिका
# 846  Chaurjahari        Municipality   Caurajahārī    चौरजहारी नगरपालिका
# 847      Musikot        Municipality      Musikōṭa     मुसिकोट नगरपालिका
# 848   Sani Bheri  Rural Municipality    Sānī Bhērī  सानी भेरी गाउँपालिका
# 849      Triveni  Rural Municipality       Trivēṇī   त्रिवेणी गाउँपालिका
#
#     PopulationCensus2001-05-28 PopulationCensus2011-06-22  \
# 845                        ...                     18,696
# 846                        ...                     27,583
# 847                        ...                     33,882
# 848                        ...                     22,194
# 849                        ...                     19,404
#
#     PopulationCensus2021-11-25
# 845                     21,033
# 846                     28,956
# 847                     34,270
# 848                     24,759
# 849                     20,525

# %% [markdown]
# ## Scraping the overall table data as it is

# %%
current_district = None
rows = []

get_body = soup.find_all('tbody')
for tbody in get_body:
    cls = tbody.get("class", [])

    if "admin1" in cls:
        district_row = tbody.find("tr", class_ = 'rname')
        district_names = district_row.find_all("td")

        current_district = district_names[0].get_text(strip=True)

        rows.append({
            "District": current_district,
            "Name": current_district,
            "Level": "District",
            "Status": district_names[1].get_text(strip=True),
            "PopulationCensus2001-05-28": district_names[4].get_text(strip=True),
            "PopulationCensus2011-06-22": district_names[5].get_text(strip=True),
            "PopulationCensus2021-11-25": district_names[6].get_text(strip=True),
        })

    elif "admin2" in cls:
        municipality_rows = tbody.find_all("tr")
        for names in municipality_rows:
            municipality_name = names.find_all("td")

            rows.append({
                "District": current_district,   
                "Name": municipality_name[0].get_text(strip=True),
                "Level": municipality_name[1].get_text(strip=True),
                "Status": municipality_name[1].get_text(strip=True),
                "PopulationCensus2001-05-28": municipality_name[4].get_text(strip=True),
                "PopulationCensus2011-06-22": municipality_name[5].get_text(strip=True),
                "PopulationCensus2021-11-25": municipality_name[6].get_text(strip=True),
            })

df = pd.DataFrame(rows)

# %%
df.tail(20)
# Out:
#        District                          Name               Level  \
# 830   Tehrathum                  Menchhayayem  Rural Municipality
# 831   Tehrathum                     Myanglung        Municipality
# 832   Tehrathum                        Phedap  Rural Municipality
# 833    Udayapur                      Udayapur            District
# 834    Udayapur                        Belaka        Municipality
# 835    Udayapur                Chaudandigadhi        Municipality
# 836    Udayapur                        Katari        Municipality
# 837    Udayapur  Koshi Tappu Wildlife Reserve    Wildlife Reserve
# 838    Udayapur        Limchungbung[Sunkoshi]  Rural Municipality
# 839    Udayapur                      Rautamai  Rural Municipality
# 840    Udayapur                         Tapli  Rural Municipality
# 841    Udayapur                       Triyuga        Municipality
# 842    Udayapur                 Udayapurgadhi  Rural Municipality
# 843  West Rukum                    West Rukum            District
# 844  West Rukum                    Aathbiskot        Municipality
# 845  West Rukum                     Banphikot  Rural Municipality
# 846  West Rukum                   Chaurjahari        Municipality
# 847  West Rukum                       Musikot        Municipality
# 848  West Rukum                    Sani Bheri  Rural Municipality
# 849  West Rukum                       Triveni  Rural Municipality
#
#                  Status PopulationCensus2001-05-28 PopulationCensus2011-06-22  \
# 830  Rural Municipality                      9,694                      8,078
# 831        Municipality                        ...                     20,337
# 832  Rural Municipality                     20,596                     17,700
# 833            District                    287,689                    317,532
# 834        Municipality                     38,727                     42,450
# 835        Municipality                     45,023                     48,750
# 836        Municipality                     50,505                     56,545
# 837    Wildlife Reserve                          0                          0
# 838  Rural Municipality                     13,800                     11,992
# 839  Rural Municipality                     23,113                     23,481
# 840  Rural Municipality                     14,643                     14,567
# 841        Municipality                     71,131                     88,967
# 842  Rural Municipality                     29,741                     30,780
# 843            District                    140,387                    155,383
# 844        Municipality                        ...                     33,624
# 845  Rural Municipality                        ...                     18,696
# 846        Municipality                        ...                     27,583
# 847        Municipality                        ...                     33,882
# 848  Rural Municipality                        ...                     22,194
# 849  Rural Municipality                        ...                     19,404
#
#     PopulationCensus2021-11-25
# 830                      6,678
# 831                     18,750
# 832                     15,169
# 833                    340,721
# 834                     51,043
# 835                     53,631
# 836                     59,507
# 837                          0
# 838                      9,689
# 839                     20,324
# 840                     13,344
# 841                    102,725
# 842                     28,926
# 843                    166,740
# 844                     35,917
# 845                     21,033
# 846                     28,956
# 847                     34,270
# 848                     24,759
# 849                     20,525

# %% [markdown]
# ### Cleaning Populations data

# %%
def clean_pop(x):
    return None if x == "..." else int(x.replace(",", ""))

df['PopulationCensus2001-05-28'] = df['PopulationCensus2001-05-28'].apply(clean_pop)
df['PopulationCensus2011-06-22'] = df['PopulationCensus2011-06-22'].apply(clean_pop)
df['PopulationCensus2021-11-25'] = df['PopulationCensus2021-11-25'].apply(clean_pop)

# %%
df.head(10)
# Out:
#   District                   Name               Level              Status  \
# 0   Achham                 Achham            District            District
# 1   Achham     Bannigadhi Jaygadh  Rural Municipality  Rural Municipality
# 2   Achham              Chaurpati  Rural Municipality  Rural Municipality
# 3   Achham                Dhakari  Rural Municipality  Rural Municipality
# 4   Achham             Kamalbazar        Municipality        Municipality
# 5   Achham  Khaptad National Park       National Park       National Park
# 6   Achham              Mangalsen        Municipality        Municipality
# 7   Achham                Mellekh  Rural Municipality  Rural Municipality
# 8   Achham    Panchadewal Binayak        Municipality        Municipality
# 9   Achham             Ramaroshan  Rural Municipality  Rural Municipality
#
#    PopulationCensus2001-05-28  PopulationCensus2011-06-22  \
# 0                    231285.0                      257477
# 1                     17102.0                       17426
# 2                     23323.0                       25215
# 3                         NaN                       21570
# 4                         NaN                       23770
# 5                         0.0                           0
# 6                         NaN                       33191
# 7                     21219.0                       24728
# 8                         NaN                       27495
# 9                     20749.0                       25172
#
#    PopulationCensus2021-11-25
# 0                      228852
# 1                       13519
# 2                       21681
# 3                       21998
# 4                       21032
# 5                           0
# 6                       26557
# 7                       22785
# 8                       26088
# 9                       23600

# %% [markdown]
# ### Exporting tabular data to Excel file

# %%
df.to_excel("DetailedCityPopulation.xlsx", index=False)

# %% [markdown]
# #### We have successfully performed web scraping to extract valuable information from webpage
